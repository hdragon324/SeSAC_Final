# %% [markdown]
# # [예비창업패키지]

# %%
import os
import json
from getpass import getpass
from openai import OpenAI

# %% [markdown]
# ## 1. 입력 값 수집

# %%
창업아이템_명 = input("창업아이템 명 입력해주세요.: ")
범주 = input("범주 작성해주세요.: ")
창업아이템_개요 = input("아이템 개요 작성해주세요.: ")
배경_및_필요성 = input("배경 및 필요성 작성해주세요.: ")
현황_및_구체화_방안 = input("현황 및 구체화 방안 작성해주세요.: ")
목표시장_및_사업화_전략 = input("목표시장 및 사업화 전략 작성해주세요.: ")
팀_구성1 = input('대표자 이름과 보유기술 및 역량을 적어주세요.: ')
팀_구성2 = input('팀원 이름과 보유기술 및 역량을 적어주세요.: ')

# %% [markdown]
# ## 2. startups_info 딕셔너리 생성

# %%
startups_info = {
    '창업아이템 명' : 창업아이템_명,
    '범주' : 범주,
    '창업아이템 개요' : 창업아이템_개요,
    '문제인식' : 배경_및_필요성,
    '실현가능성' : 현황_및_구체화_방안,
    '성장전략' : 목표시장_및_사업화_전략,
    '팀 구성' : [팀_구성1, 팀_구성2]
}
startups_info = {k: v for k, v in startups_info.items() if v}
startups_info
# Out:
# {'창업아이템 명': '헬스메이트',
#  '범주': '디지털 헬스케어 / 피트니스',
#  '창업아이템 개요': '사용자의 건강 상태와 목표에 따라 맞춤형 운동 및 식단을 추천하는 AI 기반 헬스케어 앱',
#  '문제인식': '건강 관리에 대한 관심 증가. 하지만 개인별 맞춤형 피드백을 제공하는 서비스가 부족하여, 비효율적인 운동 및 식단 관리 문제 발생.',
#  '실현가능성': 'AI 기반 체성분 분석 및 운동/식단 추천 알고리즘 개발 완료. 웨어러블 기기 연동 기능 추가 예정.',
#  '성장전략': '헬스장 및 피트니스 센터와의 제휴를 통해 초기 사용자를 확보하고, 이후 프리미엄 구독 모델을 도입하여 수익 창출.',
#  '팀 구성': ['이지훈 (헬스 트레이너 & 스타트업 창업 경험 보유)', '윤다혜 (AI 개발자), 정민우 (디지털 마케팅 전문가)']}

# %% [markdown]
# ## 3. 폴더-파일(json) 경로 설정 및 파일 저장

# %% [markdown]
# - 폴더 생성과 json파일 경로 설정 후, 파일 저장

# %%
# 폴더 경로 설정
folder_path = "c:/Users/tjdrb/project01/25.02.03/금융정부지원 사업 추천 및 사업계획서 초안 작성 AI 서비스/예비창업사업 개요 정보"
os.makedirs(folder_path, exist_ok=True)

# 파일 경로 설정
file_path = os.path.join(folder_path, f"{창업아이템_명}_data.json")

# JSON 파일로 저장
with open(file_path, 'w', encoding='utf-8') as f:
    json.dump(startups_info, f, ensure_ascii=False, indent=4)

print(f"입력된 값이 {file_path}에 저장되었습니다.")

# JSON 파일 불러오기
with open(file_path, 'r', encoding='utf-8') as f:
    loaded_data = json.load(f)

print("불러온 데이터:")
print(loaded_data)
# Out:
# 입력된 값이 c:/Users/tjdrb/project01/25.02.03/금융정부지원 사업 추천 및 사업계획서 초안 작성 AI 서비스/예비창업사업 개요 정보\헬스메이트_data.json에 저장되었습니다.
# 불러온 데이터:
# {'창업아이템 명': '헬스메이트', '범주': '디지털 헬스케어 / 피트니스', '창업아이템 개요': '사용자의 건강 상태와 목표에 따라 맞춤형 운동 및 식단을 추천하는 AI 기반 헬스케어 앱', '문제인식': '건강 관리에 대한 관심 증가. 하지만 개인별 맞춤형 피드백을 제공하는 서비스가 부족하여, 비효율적인 운동 및 식단 관리 문제 발생.', '실현가능성': 'AI 기반 체성분 분석 및 운동/식단 추천 알고리즘 개발 완료. 웨어러블 기기 연동 기능 추가 예정.', '성장전략': '헬스장 및 피트니스 센터와의 제휴를 통해 초기 사용자를 확보하고, 이후 프리미엄 구독 모델을 도입하여 수익 창출.', '팀 구성': ['이지훈 (헬스 트레이너 & 스타트업 창업 경험 보유)', '윤다혜 (AI 개발자), 정민우 (디지털 마케팅 전문가)']}

# %% [markdown]
# - 폴더에 저장된 json파일이 있을 경우 셀 실행

# %%
# # 폴더 경로 설정
# folder_path = "c:/Users/tjdrb/project01/25.02.03/금융정부지원 사업 추천 및 사업계획서 초안 작성 AI 서비스/예비창업사업 개요 정보"

# # 폴더 내의 모든 JSON 파일 불러오기
# json_files = [f for f in os.listdir(folder_path) if f.endswith('.json')]

# for json_file in json_files:
#     file_path = os.path.join(folder_path, json_file)
#     with open(file_path, 'r', encoding='utf-8') as f:
#         loaded_data = json.load(f)
#         print(f"불러온 데이터 ({json_file}):")
#         print(loaded_data)

# %% [markdown]
# ## 4. API_KEY 입력

# %%
MY_API_KEY = getpass('OpenAI API Key:')

# %%
client = OpenAI(api_key=MY_API_KEY)

# %%
template = """
1. 항목 제목
1-1. 제목
    1) 소제목
     -      
     -
     -
     
    2) 소제목
     -
     -
     -
     
2. 항목 제목        
2-1. 제목
    1) 소제목
     -
     -
     -
        
    2) 소제목
     -  
     -
     -
"""

# %% [markdown]
# ## 5. Template & Prompt 작성 및 결과

# %%
# 1. 문제인식(Problem)
template_test1 = """
1. 문제인식(Problem)
1-1. 창업아이템 배경 및 필요성
    - 창업 아이템(제품, 서비스 등)을 개발(개선) 배경과 이를 뒷받침할 근거, 동기 등을 제시하여 작성하세요.
    - 국내·외 시장에서 발생하는 주요 문제점과 새로운 기술 도입 필요성을 설명하세요.
    - 산업 변화, 정책 변화, 소비자 니즈 변화 등을 작성하세요.
    - 배경 및 필요성에서 발견한 문제점과 해결방안, 필요성, 제품·서비스를 개발하려는 목적과 사업을 통해 이루고자 하는 목표를 작성해주세요.
1-2. 창업아이템 목표시장(고객) 설정 및 요구사항 분석
    - 창업 아이템 배경 및 필요성에 따라 정의된 시장(고객)에 대해 제공할 혜택과 행위를 제공할 시장(고객)을 설정하고 구체화하여 작성하세요.
    - 진출하려는 시장의 규모, 상황 및 특성, 경쟁 강도, 향후 전망, 고객 특성을 작성하세요.
    - 정의된 목표시장 요구사항에 대한 조사를 하고 분석 결과 및 문제의 객관적 근거들을 작성하세요."""
    
# 2. 실현가능성(Solution)
template_test2 = """
2. 실현가능성(Solution)
2-1. 창업 아이템 현황 및 준비 정도
    - 제품·서비스의 필요성에 대한 문제를 인식하고, 해당 제품·서비스 개발·개선을 위해 본 사업에 신청하기 이전까지 기획, 추진한 이력 등에 대해 작성하세요.
    - 사업 신청 시점의 아이템 개발 단계별 현황, 목표한 시장 및 고객의 반응, 현재까지의 주요 사업화 성과 등 전반적인 현황을 작성하세요.
2-2. 창업 아이템 실현 및 구체화 방안
    - 협약 기간 내 실현 및 구체화하고자 하는 개선 방안을 작성해주세요.
    - 목표시장 요구사항 등 분석을 통해 파악된 문제점 및 개선점에 대해 핵심 기능·성능, 디자인 개선, 기타 사업화 활동을 실현 및 구체적인 개선 방안을 작성하세요.
    - 경쟁사 제품·서비스와의 비교를 통해 파악된 문제점에 대해 자사의 보유역량을 기반으로 경쟁력, 차별성 등을 확보하기 위한 방안을 작성하세요.
    - 기타 개선·구체화하고자 하는 제품·서비스 관련 기술 보호 계획 등을 작성하세요."""

# 3.성장전략(Scale-up)
template_test3 = """
3. 성장전략(Scale-up)
3-1. 비즈니스 모델 및 사업화 추친 성과
    - 제품·서비스 비즈니스 모델 중 수익창출을 위한 수익 모델을 작성하세요.
    - 현재 진입한 목표시장(고객)을 진입 현황과 그간 사업화 추진성과(매출, 투자, 고용 등)를 작성하세요.
        (예시) 생산·출시, 홍보·마케팅 및 유통·판매 현황과 매출 실적 등 작성하세요.
    - 서비스의 경우 회원(이용자) 확보 및 다운로드 수 등 작성하세요.    
3-2. 아이템 시장 확대 등 사업화 전략
    - 목표시장 내 세부 고객, 경쟁사, 시장 내 대체하고자 하는 제품, 서비스의 주요 정보 분석등을 통해 국내외 시장 확대 전략 수립을 작성하세요.
    - 목표시장에 진출 및 확대하기 위한 구체적인 방안과 고객 확보 전략, 수익 확대 전략 등을 작성하세요.
    - 협약기간 내 달성하고자 하는 성과(매출, 투자, 고용 등)을 기재하세요.
3-3. 사업추진 일정 및 자금운용 계획
    - 사업 전체 로드맵(일정)
        예시) 표로 작성해주세요.("예시"라는 문구를 보여주세요.)
        |구분|추진 내용|추진 기간|세부 내용|
        |1|시제품 제작|2023년 2월 - 2023년 4월|시제품 설계|
        
        <사업추진 일정(전체 사업단계)>
        예시) 표로 작성해주세요.("예시"라는 문구를 보여주세요.)
        |구분|추진 내용|추진 기간|세부 내용|
        |1|시장 조사 및 초기 마케팅 활동|2023년 4월 - 2023년 6월|SNS 캠페인, 온라인 광고 진행|
        
    - 협약기간 내 목표 및 달성 방안
        - 협약기간 내 추진하고자 하는 주요 내용과 목표, 일정, 최종결과물 등을 작성하세요. 
        <사업추진 일정(협약기간 내)>
        예시) 표로 작성해주세요.
        |구분|추진 내용|추진 기간|세부 내용|

    - 정부지원사업비 집행계획 
        - 사업의 협약기간 동안 사업화를 수행하기 위해 필요한 필요 예산 및 계획서를 작성하세요.
        <사업추진 일정(협약기간 내)>
        예시) 표로 작성해주세요.
        |구분|추진 내용|추진 기간|세부 내용|

<사업비 집행 계획>
*"정부지원사업비는 총 사업비의 70%이하, 현금은 10%이상, 현물은 20% 이하로 작성하세요.(최대 1억원 한도 이내)"라고 적어주세요.
예시)
|      |          |           총 사업비(원)             |
|비 목 | 집행 계획 |정부지원 사업비|자기부담사업비 | 합계 |
|      |          |              | 현 금 | 현 물 |      |
|------|----------|--------------|-------|------|-------|
|개발비|           | 95,000,000  |       |       |      |
|       합 계      |             |       |       |      |
- 정부지원사업비가 총 사업비의 규정을 초과하지 않도록 주의하세요.

    - 기타 자금 필요성 및 조달계획: 
        - 사업화 자금 외에 추가자금(투자유치 등) 조달에 대한 필요성과 세부 조달방안을 작성하세요."""

## 팀구성(Team)      
template_test4 = """
4.팀구성(Team)
4-1. 대표자&팀원 현황 및 보유역량
    1) 대표자 현황 및 역량
        - "[예시 작성]" 라는 문구와 같이 내용을 작성합니다.(대표자&팀원 등이 보유 중인 역량, 주요 경력과 경험, 교육 이수, 기타 수상 실적 등 작성하세요. **(팀원이 없는 경우: 대표자만 작성)**)
    
    <팀 구성 예정>
    예시) 표로 작성.
    |순번|직위|담당 업무|보유역량(경력 및 학력 등)|구성 상태|
    
    2) 협약 기간 내 인력 고용 및 활용 계획:
        - "[예시 작성]" 라는 문구와 같이 내용을 작성합니다.
        - 협약기간 내 채용 예정인 추가인력에 대해서만 작성하세요.
        - 채용 예정이 없는 기업의 경우, 대표자의 역량, 보유 장비, 시설 등을 중심으로 작성하세요.
    
    <추가 고용 및 활용 계획>
    예시) 표로 작성.
    |순번|주요 담당 업무|요구역량(경력 및 학력 등)|채용 시기|
    
    3) 외부 협력 현황 및 활용방안
        - 제품 및 서비스와 관련하여 협력(또는 예정)인 파트너, 협력 기간(기업)이 보유하고 있는 역량과 주요 협업 내용을 작성하세요.
        예시) 표로 작성.
        |순번|파트너명|보유역량|협업방안|협력 시기|
        
4-2. 중장기적 ESG 경영 도입계획
    - 재무적 성과 이외에 사회적 가치, 환경 보호, 지역 활성화 등의 구체적인 실천 계획을 작성하세요.
    - 실행 전략: 각 목표를 달성하기 위한 구체적인 실행 전략을 작성하세요.
    - 성과 측정: 각 전략의 성과를 측정할 수 있는 지표와 방법을 제시하세요.
    - 지속 가능성: 도입 계획의 지속 가능성을 보장하기 위한 방안을 작성하세요.
    - 파트너십: 사회적 가치를 도입하기 위해 협력할 수 있는 외부 파트너 또는 기관을 제시하세요."""

# %% [markdown]
# ### 1. 문제인식(Problem)

# %%
prompt1 = f"""
당신은 예비창업자를 위한 사업계획서 전문가입니다.  
논리적이고 설득력 있는 사업계획서를 작성하세요.  
문장은 간결하게, 핵심을 강조하며, 투자자 및 심사위원이 주목할 수 있도록 수치, 데이터, 시장 반응을 명확히 표현하세요.
이 작업은 창업자의 생계와 미래가 걸린 **절대적으로 중요한 프로젝트**입니다.
작성된 사업계획서의 완성도가 곧 **합격과 실패를 결정**하며, 이를 통해 창업자는 사업을 현실화하고 생존할 기회를 얻게 됩니다.
초안을 **작성할 때는 {loaded_data['문제인식']}내용 기반으로만** 쓰며, **{template_test1}**에 내용들을 순서에 맞게 참고해주세요.
양식은 아래 제공하는 제공하는 템플릿 양식을 참고하여 작성해주세요.

제공하는 템플릿 양식 : {template}

**반드시 지켜야 할 출력 규칙**
    1. 절대 #, * 기호 및 마크다운 스타일 절대 금지
    2. 항목 표시 시 "1)", "2)" 형식만 사용 (숫자+닫는 괄호)
    3. 데이터 출처 명시 : 모든 통계 수치에 출처를 포함. (ex. 출처: 통계청)
    4. 사업 개요는 작성에서 제외.
"""
# completion1 = client.chat.completions.create(model='gpt-4o',
#                                             messages=[{'role':'user', 'content':prompt1}],
#                                             temperature=0.7,
#                                             presence_penalty=0.8,
#                                             frequency_penalty=0.5)
# print(completion1.choices[0].message.content)

# %%
# # 1. 문제인식(Problem)
# template_test1 = """
# 1. 문제인식(Problem)
# 1) 창업 아이템 배경 및 필요성: 
#     - 현재 시장에서 해결되지 않은 문제점과 해당 문제는 국내·외에서 어떤 영향을 미치는지 작성하세요.
#     - 현재 시장에서 사용되는 
#     - 시장 설정 및 정의, 문제점 또는 애로사항 해결 방법과 방안을 통한 고객들에게 제공할 가치가 무엇인지 작성하세요.
# 2) 창업아이템 목표시장(고객) 현황 분석: 
#     - 실현하고자 하는 제품이 진입할 시장을 정의, 시장 수요, 제공하고자 하는 가치와 해당 제품이 왜 유망한지 등 설명하세요.
#     - 제품과 서비스에 대한 과제, 고객 요구사항에 대한 과제, 대비 개선과제 등을 종합적으로 고려하여 작성하세요."""

# %% [markdown]
# ### 2. 실현가능성(solution)

# %%
# # 2. 실현가능성(Solution)
# template_test2 = """
# 2. 실현가능성(Solution)
# 2-1. 창업 아이템 현황 및 준비 정도
#     - 문제인식에서 정의된 시장 수요, 제품 및 서비스의 필요성을 기반으로 현재까지 진행된 기획 또는 경과를 작성하세요.
#     - 현재까지 진행된 이력 등을 바탕으로 기술의 개발과 성과, 시장 반응 등 제품 및 서비스 실현 가능성에 대한 근거를 제시하세요.
# 2-2. 창업 아이템 실현 및 구체화 방안
#     - 구체화할 제품 또는 서비스의 핵심 기능, 성능, 디자인, 기타 활동을 통해 세부적인 개발 및 구체화 방안, 최종 산출물 등을 작성하세요.
#     - 보유역량을 기반으로 경쟁자와의 차별화 요인을 설명하되, 스펙, 핵심 기능, 성능, 고객 제공 혜택 등 다양한 측면에서 표현해주세요.
#     - 차별화를 실현할 수 있는 보유역량은 특허 등(구성, 공정 등) 물리적 역량뿐만 아니라 콘텐츠 등 소프트웨어적 역량도 모두 포함해주세요."""

# %%
prompt2 = f"""
당신은 예비창업자를 위한 사업계획서 전문가입니다.  
논리적이고 설득력 있는 사업계획서를 작성하세요.  
문장은 간결하게, 핵심을 강조하며, 투자자 및 심사위원이 주목할 수 있도록 수치, 데이터, 시장 반응을 명확히 표현하세요.
이 작업은 창업자의 생계와 미래가 걸린 **절대적으로 중요한 프로젝트**입니다.
작성된 사업계획서의 완성도가 곧 **합격과 실패를 결정**하며, 이를 통해 창업자는 사업을 현실화하고 생존할 기회를 얻게 됩니다.
초안을 작성할 때는 **{loaded_data['실현가능성']}내용 기반으로만** 쓰며, **{template_test2}**에 내용들을 순서에 맞게 참고해주세요.
양식은 아래 제공하는 템플릿 양식을 참고하여 작성해주세요.

제공하는 템플릿 양식 : {template}

**반드시 지켜야 할 출력 규칙**
    1. 절대 #, * 기호 및 마크다운 스타일 절대 금지
    2. 항목 표시 시 "1)", "2)" 형식만 사용 (숫자+닫는 괄호)
    3. 데이터 출처 명시 : 모든 통계 수치에 출처를 포함. (ex. 출처: 통계청)
    4. 사업 개요는 작성에서 제외.
"""
# completion2 = client.chat.completions.create(model='gpt-4o',
#                                         messages=[{'role':'user', 'content':prompt2}],
#                                         temperature=0.7,
#                                         presence_penalty=0.8,
#                                         frequency_penalty=0.5)
# print(completion2.choices[0].message.content)

# %% [markdown]
# ### 3. 성장전략(Scale-up)

# %%
# # 3.성장전략(Scale-up)
# template_test3 = """
# 3. 성장전략(Scale-up)
# 3-1. 비즈니스 모델 및 사업화 추친 성과
#     - 비즈니스모델: How to Make&Sale 등 통해 이윤을 확보하는 구조에 대한 전반을 설명하세요.
#     - 통상적인 경영활동과 관련된 재화의 판매 또는 용역의 제공의 활동을 자유롭게 작성하세요.
#     - 창업 아이템에 대한 목표 시장 정의, 신청 시점까지 실적(매출, 투자 고용 등)에 대한 내용을 정리하세요.
# 3-2. 아이템 시장 확대 등 사업화 전략
#     - 목표시장 내 세부 고객, 경쟁사, 시장 내 대체하고자 하는 제품, 서비스의 주요 정보 분석등을 통해 국내외 시장 확대 전략 수립을 작성하세요.
#     - 목표시장에 진출 및 확대하기 위한 구체적인 방안과 고객 확보 전략, 수익 확대 전략 등을 작성하세요.
#     - 협약기간 내 달성하고자 하는 성과(매출, 투자, 고용 등)을 기재하세요.
# 3-3. 사업추진 일정 및 자금운용 계획:
#     - 사업 전체 로드맵(일정)
#     예시) 표로 작성해주세요.("예시"라는 문구를 보여주세요.)
#     |구분|추진 내용|추진 기간|세부 내용|
#     |1|시제품 제작|2023년 2월 - 2023년 4월|시제품 설계|
    
#     - 협약기간 내 목표 및 달성 방안
#         - 협약기간 내 추진하고자 하는 주요 내용과 목표, 일정, 최종결과물 등을 작성하세요. 
#     - 정부지원사업비 집행계획
#         - 사업의 협약기간 동안 사업화를 수행하기 위해 필요한 필요 예산 및 계획서를 작성하세요.
#     - 기타 자금 필요성 및 조달계획
#         - 사업화 자금 외에 추가자금(투자유치 등) 조달에 대한 필요성과 세부 조달바안을 작성하세요."""

# %%
prompt3 = f"""
당신은 예비창업자를 위한 사업계획서 전문가입니다.  
논리적이고 설득력 있는 사업계획서를 작성하세요.  
문장은 간결하게, 핵심을 강조하며, 투자자 및 심사위원이 주목할 수 있도록 수치, 데이터, 시장 반응을 명확히 표현하세요.
이 작업은 창업자의 생계와 미래가 걸린 **절대적으로 중요한 프로젝트**입니다.
작성된 사업계획서의 완성도가 곧 **합격과 실패를 결정**하며, 이를 통해 창업자는 사업을 현실화하고 생존할 기회를 얻게 됩니다.
초안을 작성할 때는 **{loaded_data['성장전략']}내용 기반으로만** 쓰며, **{template_test3}**에 있는 내용들을 순서에 맞게 참고해주세요.
양식은 아래 제공하는 제공하는 템플릿 양식을 참고하여 작성해주세요.

제공하는 템플릿 양식 : {template}

**반드시 지켜야 할 출력 규칙**
    1. 절대 #, * 기호 및 마크다운 스타일 절대 금지
    2. 항목 표시 시 "1)", "2)" 형식만 사용 (숫자+닫는 괄호)
    3. 데이터 출처 명시 : 모든 통계 수치에 출처를 포함. (ex. 출처: 통계청)
    4. 사업 개요는 작성에서 제외.
"""
# completion3 = client.chat.completions.create(model='gpt-4o',
#                                         messages=[{'role':'user', 'content':prompt3}],
#                                         temperature=0.7,
#                                         presence_penalty=0.8,
#                                         frequency_penalty=0.5)
# print(completion3.choices[0].message.content)

# %% [markdown]
# ### 4. 팀구성(Team)

# %%
prompt4 = f"""
당신은 예비창업자를 위한 사업계획서 전문가입니다.  
논리적이고 설득력 있는 사업계획서를 작성하세요.  
문장은 간결하게, 핵심을 강조하며, 투자자 및 심사위원이 주목할 수 있도록 수치, 데이터, 시장 반응을 명확히 표현하세요.
이 작업은 창업자의 생계와 미래가 걸린 **절대적으로 중요한 프로젝트**입니다.
작성된 사업계획서의 완성도가 곧 **합격과 실패를 결정**하며, 이를 통해 창업자는 사업을 현실화하고 생존할 기회를 얻게 됩니다.
초안을 작성할 때는 **{loaded_data['팀 구성']}내용을 기반으로** 쓰며, **{template_test4}**에 내용들을 순서에 맞게 참고해주세요.
양식은 아래 제공하는 제공하는 템플릿 양식을 참고하여 작성해주세요.

제공하는 템플릿 양식 : {template}

**반드시 지켜야 할 출력 규칙**
    1. 절대 #, * 기호 및 마크다운 스타일 절대 금지
    2. 항목 표시 시 "1)", "2)" 형식만 사용 (숫자+닫는 괄호)
    3. 데이터 출처 명시 : 모든 통계 수치에 출처를 포함. (ex. 출처: 통계청)
    4. 사업 개요는 작성에서 제외.
"""
# completion4 = client.chat.completions.create(model='gpt-4o',
#                                         messages=[{'role':'user', 'content':prompt4}],
#                                         temperature=0.7,
#                                         presence_penalty=0.8,
#                                         frequency_penalty=0.5)
# print(completion4.choices[0].message.content)

# %%
from tqdm import tqdm

prompts = [prompt1, prompt2, prompt3, prompt4]

results = []

for prompt in tqdm(prompts, desc="Processing Prompts"):
    completion = client.chat.completions.create(
        model='gpt-4o',
        messages=[{'role': 'user', 'content': prompt}],
        temperature=0.7,
        presence_penalty=0.8,
        frequency_penalty=0.5)
    
    results.append(completion.choices[0].message.content)
    
for result in results:
    print(result)
# Out:
# Processing Prompts: 100%|██████████| 4/4 [01:00<00:00, 15.05s/it]
# 1. 문제인식
# 1-1. 창업아이템 배경 및 필요성
#     1) 창업 아이템 개발 배경
#      - 건강 관리에 대한 전 세계적 관심 증대와 함께 개인 맞춤형 피드백 제공 서비스의 부족으로 인한 비효율적인 운동과 식단 관리 문제 발생
#      - 현재 시장에는 일반적인 건강 정보는 많지만, 개인별 특성을 고려한 맞춤형 솔루션은 제한적임
#      - 국내외 건강 관련 앱 사용자 중 70%가 개인화된 피드백을 원한다고 응답 (출처: 통계청)
#
#     2) 주요 문제점 및 기술 도입 필요성
#      - 일반적인 건강 관리 서비스는 사용자 개개인의 생활 패턴이나 신체 상태를 충분히 반영하지 못함
#      - AI 및 빅데이터 기술을 활용하여 사용자의 개별 데이터를 분석하고 맞춤형 솔루션을 제공할 필요성이 증가
#      - 소비자 니즈 변화: 빠르고 효율적인 결과를 원하는 현대 소비자들은 개인화된 서비스를 선호함
#
# 1-2. 창업아이템 목표시장(고객) 설정 및 요구사항 분석
#     1) 목표시장 정의 및 특성
#      - 목표 시장은 20대에서 40대 사이의 도시 거주 직장인들로, 이들은 시간 제약 내에서 효과적으로 건강 관리를 하고자 함
#      - 한국의 전체 헬스케어 시장 규모는 약 25조 원 이상이며 매년 평균 5%씩 성장 중 (출처: 산업통상자원부)
#      - 경쟁 강도는 높으나, 차별화된 개인 맞춤형 서비스 제공 시 높은 수익 가능성 존재
#
#     2) 고객 요구사항 분석 결과
#      - 설문 조사에 따르면, 응답자의 60%가 기존 서비스가 제공하는 정보의 신뢰성과 적합성에 불만족 (출처: 자체 설문조사)
#      - 고객들은 편리하게 접근할 수 있는 모바일 플랫폼과 실시간 피드백 기능을 선호하며, 지속 가능한 동기 부여 시스템도 중요시함
#
# 2. 실현가능성(Solution)
#
# 2-1. 창업 아이템 현황 및 준비 정도
#
# 1) 제품·서비스의 필요성 인식 및 개발 이력
#    - 현대인의 건강관리에 대한 관심 증가로 체성분 분석과 맞춤형 운동/식단 추천 서비스의 수요가 높아지고 있습니다.
#    - AI 기반 체성분 분석 알고리즘을 개발하여 사용자에게 개인화된 건강관리 솔루션을 제공합니다.
#    - 웨어러블 기기 연동 기능을 연구 중이며, 이를 통해 실시간 데이터 수집과 분석이 가능해질 예정입니다.
#
# 2) 현재 아이템 개발 단계 및 시장 반응
#    - 현재 AI 알고리즘은 테스트 단계를 완료했으며, 초기 사용자의 피드백은 긍정적입니다.
#    - 목표 시장인 20대~40대는 헬스케어 앱의 주요 사용층으로, 높은 관심을 보이고 있습니다. (출처: 통계청)
#    - 초기 사업화 성과로는 프로토타입 출시 후 500명의 베타테스터를 확보하였습니다.
#
# 2-2. 창업 아이템 실현 및 구체화 방안
#
# 1) 협약 기간 내 개선 방안
#    - AI 알고리즘의 정밀도를 높이기 위해 추가 데이터를 학습시키고, 사용자 인터페이스(UI)를 개선할 계획입니다.
#    - 웨어러블 기기와의 호환성을 강화하여 다양한 기기에서 일관된 사용자 경험을 제공할 것입니다.
#
# 2) 목표시장 요구사항 분석 및 경쟁력 확보 방안
#    - 고객 설문조사를 통해 주요 기능에 대한 만족도를 파악하고, UX/UI 디자인 개선점을 도출했습니다.
#    - 경쟁사 대비 정확한 데이터 분석 능력을 바탕으로 차별화를 구현합니다. 예를 들어, 기존 서비스 대비 분석 정확도가 15% 향상되었습니다. (출처: 자사 내부 데이터)
#
# 3) 기술 보호 계획
#    - 핵심 기술인 AI 알고리즘은 특허 출원을 진행 중이며, 데이터 보호를 위한 암호화 기술도 적용 예정입니다.
#    - 지속적인 R&D 투자로 기술 우위를 유지하고자 합니다.
# 3. 성장전략(Scale-up)
#
# 3-1. 비즈니스 모델 및 사업화 추진 성과
# 1) 수익 모델 작성
# - 초기 사용자는 헬스장 및 피트니스 센터와의 제휴를 통해 확보.
# - 프리미엄 구독 모델을 도입하여 사용자 별 맞춤형 피트니스 계획 제공.
# - 추가적인 매출원으로는 광고, 온라인 판매 및 기업 대상 B2B 솔루션 제공.
#
# 2) 목표시장 진입 현황 및 사업화 추진성과
# - 목표시장: 20대~40대 건강 관리에 관심이 많은 도시 거주자.
# - 매출: 월 평균 5천만 원 (출처: 내부 데이터)
# - 투자 유치: 초기 엔젤 투자 2억 원 완료 (출처: 내부 데이터)
# - 고용: 현재 직원 10명, 향후 6개월 내로 5명 추가 고용 계획.
#
# 3) 서비스 회원 확보 및 다운로드 수
# - 현재 회원 수: 약 5,000명 (출처: 내부 데이터)
# - 앱 다운로드 수: 약 10,000회 (출처: 구글 플레이 스토어)
#
# 3-2. 아이템 시장 확대 등 사업화 전략
# 1) 국내외 시장 확대 전략 수립
# - 경쟁사 분석 결과, 주요 대체 제품은 해외 유명 피트니스 앱들임.
# - 고객 세분화를 통해 특정 운동 카테고리별 맞춤형 콘텐츠 개발.
#
# 2) 목표시장 진출 및 확대 방안
# - 오프라인 헬스장과의 협력 강화로 지역 기반 확장.
# - SNS 인플루언서와의 파트너십을 통한 브랜드 인지도 상승.
#
# 3) 협약기간 내 달성하고자 하는 성과
# - 매출 목표: 연간 10억 원 달성.
# - 추가 투자 유치 목표: 시리즈 A 라운드에서 최소 5억 원 확보.
#
# 3-3. 사업추진 일정 및 자금운용 계획
#
# 1) 사업 전체 로드맵(일정)
#
# <사업추진 일정(전체 사업단계)>
# |구분|추진 내용|추진 기간|세부 내용|
# |---|---|---|---|
# |1|시제품 제작|2023년 2월 - 2023년 4월|시제품 설계|
# |2|시장 조사 및 초기 마케팅 활동|2023년 4월 - 2023년 6월|SNS 캠페인, 온라인 광고 진행|
#
# 2) 협약기간 내 목표 및 달성 방안
#
# <사업추진 일정(협약기간 내)>
# 예시) 표로 작성해주세요.
# |구분|추진 내용|추진 기간|세부 내용|
#
# 3) 정부지원사업비 집행계획
#
# <사업비 집행 계획>
# *"정부지원사업비는 총 사업비의 70%이하, 현금은 10%이상, 현물은 20% 이하로 작성하세요.(최대 1억원 이내)"*
#
# 예시)
# 구분	        항목	금액(천 원)|세부 내역|
# 정부지원사업비	인건비	ㅇㅇㅇ |ㅇㅇㅇ|
#                     개발비	ㅇㅇㅇ |  	  |
# 자기부담금	    현금	ㅇㅇㅇ | 	  |
#                     현물	    |      |
#
# 4) 기타 자금 필요성 및 조달계획
# 1) 추가 자금 조달 필요성
#    - 서비스 확장을 위한 서버 증설 비용 필요.
#    - 국제 시장 진입 준비를 위한 마케팅 예산 증대 필요.
#
# 2) 세부 조달 방안
#    - 벤처 캐피털 대상 시리즈 A 투자유치 추진 예정.
#    - 정부 지원 프로그램 신청을 통해 R&D 비용 보조 받을 계획.
# 4. 팀 구성(Team)
#
# 4-1. 대표자&팀원 현황 및 보유역량
#
# 1) 대표자 현황 및 역량
#     - 이지훈: 헬스 트레이너로 5년 경력, 스타트업 창업 경험 보유, 스포츠 과학 학사, 다양한 피트니스 관련 강의 수료.
#     - 윤다혜: AI 개발자로서 7년 경력, 컴퓨터 공학 석사, 인공지능 연구 논문 다수 게재.
#     - 정민우: 디지털 마케팅 전문가로 6년 경력, 마케팅 관련 국제 수상 실적 보유.
#
# <팀 구성 예정>
# |순번|직위|담당 업무|보유역량(경력 및 학력 등)|구성 상태|
# |---|---|---|---|---|
# |1|대표자|사업 총괄 및 전략 기획|헬스 트레이너 5년 경력, 스타트업 창업 경험|-|
# |2|AI 개발자|제품 개발 및 기술 구현|AI 개발 7년 경력|-|
# |3|마케팅 전문가|마케팅 및 홍보 전략 기획 디지털 마케팅 6년 경력|-|
#
# 2) 협약 기간 내 인력 고용 및 활용 계획
#     - 채용 예정이 없음에 따라 현재 팀원의 역량을 최대한 활용할 계획이며 시설과 장비를 통해 효율성을 극대화합니다.
#
# <추가 고용 및 활용 계획>
# 현재 추가 채용 계획 없음.
#
# 3) 외부 협력 현황 및 활용방안
#     예시)
#     |순번|파트너명 |보유역량 |협업방안 |협력 시기 |
#     |--- |---     |---     |---   |---   |
#     |1   |ABC 대학 연구소   |운동 효율성 분석 기술 보유   |헬스케어 프로그램 공동개발   |2024년 상반기 |
#     |2   |XYZ 마케팅 회사   |디지털 캠페인 전문성 보유   |공동 마케팅 캠페인 진행   |2024년 하반기 |
#
# 4-2. 중장기적 ESG 경영 도입계획
#
# 1) 재무적 성과 이외 사회적 가치 실현
#     - 지역 커뮤니티와 협력을 통한 건강 증진 활동 전개.
#     - 저소득층 청소년 대상 무료 운동 클래스 제공.
#
# 2) 실행 전략
#     - 지역 체육관과 제휴하여 무료 클래스를 월 2회 운영.
#     - 매출의 일정 비율을 지역 사회 발전 기금으로 적립.
#
# 3) 성과 측정
#     - 참여 인원 수와 만족도 조사 결과를 기반으로 평가.
#     - 지역 발전 기금 조성액 공개 투명성 확보.
#
# 4) 지속 가능성 방안
#     - 정부 지원 프로그램 연계 추진.
#     - 장기적인 후원 파트너십 구축.
#
# 5) 파트너십
#     - 지역 자치단체와의 협력을 통해 공공 스포츠 행사 개최.

# %% [markdown]
# - 팀 구성은 ESG 경영 실천계획을 제외한 나머지(대표자&팀원 현황 및 보유역량, 외부 협력기관 현황 및 활용 계획)은 예시로 작성.

# %% [markdown]
# ### 전체 출력(Combined)

# %% [markdown]
# ### 결합된 값을 json 파일로 저장.

# %%
# combined_data = {
#     'combined_draft': combined_draft
# }
# combined_data

# %%
# combined_folder = 'c:/Users/tjdrb/project01/25.02.03/금융정부지원 사업 추천 및 사업계획서 초안 작성 AI 서비스/예비창업자 패키지 초안'
# os.makedirs(combined_folder, exist_ok=True)

# n = 1
# while True:
#     # 파일 경로 설정
#     combined_file_path = os.path.join(combined_folder, f"예비창업자_초안{num}.json")
#     if not os.path.exists(combined_file_path):
#         with open(combined_file_path, 'w', encoding='utf-8') as f:
#             json.dump(combined_data, f, ensure_ascii=False, indent=4)
#         break
#     num += 1
    
# print(f"최종 초안이 {combined_file_path}에 저장되었습니다.")
