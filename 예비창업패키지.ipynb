# %% [markdown]
# # [예비창업패키지]

# %%
import os
import json
from getpass import getpass
from openai import OpenAI

# %% [markdown]
# ## 1. 입력 값 수집

# %%
창업아이템_명 = input("창업아이템 명 입력해주세요.: ")
범주 = input("범주 작성해주세요.: ")
창업아이템_개요 = input("아이템 개요 작성해주세요.: ")
배경_및_필요성 = input("배경 및 필요성 작성해주세요.: ")
현황_및_구체화_방안 = input("현황 및 구체화 방안 작성해주세요.: ")
목표시장_및_사업화_전략 = input("목표시장 및 사업화 전략 작성해주세요.: ")
팀_구성1 = input("대표자를 입력해주세요.: ")
팀_구성2 = input("팀원을 입력해주세요.: ")

# %% [markdown]
# ## 2. startups_info 딕셔너리 생성

# %%
startups_info = {
    '창업아이템 명' : 창업아이템_명,
    '범주' : 범주,
    '창업아이템 개요' : 창업아이템_개요,
    '문제인식' : 배경_및_필요성,
    '실현가능성' : 현황_및_구체화_방안,
    '성장전략' : 목표시장_및_사업화_전략,
    '팀 구성' : [팀_구성1, 팀_구성2]
}
startups_info = {k: v for k, v in startups_info.items() if v}
startups_info
# Out:
# {'창업아이템 명': 'Sell Farm(셀팜)',
#  '범주': '데이터 분석 어플리케이션',
#  '창업아이템 개요': "'셀팜'은 농산물 온라인 판매자가 가격 측정, 판매전략 구축 시간을 1시간에서 1분으로 단축할 수 있도록 도와주는 판매 데이터 분석 서비스입니다. 주기능은 다음 두가지입니다. 1) 온라인 판매 데이터에 기반하여, 가격 책정을 위한 평균가 및 가격 추이를 검색 한번으로 확인 가능하게 함. 2) 판매 중인 상품의 URL을 입력하면 수치화된 분석 및 구체적인 액션 아이템을 제시하여 데이터를 기반으로 다음 전략을 쉽게 수립할 수 있도록 함.",
#  '문제인식': '1) 기획 배경  - 농산물 유통 시장의 구조적 문제점으로 생산자와 소비자가 모두 피해를 받고 있는 상황에서 농산물 위탁판매자의 필요성이 대두되고 있으며, 위탁판매자의 판매 시작 진입장벽을 낮추어 규모의 경제와 경쟁을 통한 건전한 시장 형성이 필요하다고 인식됩니다. 2) 고객 니즈 및 서비스 목적 - 타깃 고객(농산물 온라인 판매자)는 현재 비효율적인 가격 책정 과정, 판매전략과 노하우를 수립하기 위해 필요 이상의 많은 시간을 소모하고 있으며 이는 상품의 특성과 판매 시기 등 고려해야할 것이 많은 농산물 판맨의 특성에서 비롯됩니다. - 본 서비스는이를 해결하기 위해 데이터 기반으로 가격책정과 판매전략에 있어 수치화된 정보 및 전략을 제공하여 농산물 판매 프로세스를 더욱 효율적으로 개선하고자 합니다.',
#  '실현가능성': '1) 2023년 12월부터 문제 정의 및 가설 검증을 위해 농산물 온아인 판매자 대상으로 설문조사, 심층 인터뷰를 2회차 진행, 시장조사를 기반으로 유저 플로우, IA(정보구조도)를 통해 전체적인 기획 완료. 2) 현재는 와이어프레임, 프로토타입, 사용성 테스트를 통해 서비스 가치를 최대한 빠르게 인식할 수 있는 UI/UX를 개선 중. 3) 농산물 온라인 판매 시 효율적인 가격 책정, 시간 단축을 위한 품목별, 판매 단위별 평균가의 추이와 현황을 확인할 수 있는 기능 개발 예정. 4) 본 서비스를 기반으로 취득한 데이터를 통해 독자적으로 가공하여 유의미한 데이터를 고객에게 제공할 예정.',
#  '성장전략': '1) 목표시장  - 셀팜은 20에서 30대 농산물(위탁) 판매자 시장에 집중합니다. \t- 국내 : 20에서 30대 농산물(위탁) 판매자 2) 비즈니스 모델 - 초기 : 부분서비스 유료화를 통해 유료 서비스유저를 유치, 다양한 이커머스 플럇폼의 데이터를 분석하여 서비스 고도화 및 시장 확장 - 중기 : 획득한 유저의 DB를 바탕으로 B2B 서브시로 확장 - 장기 : 해외 플랫폼과 위탁판매자들을 겨냥한 서비스 런칭 3) 경쟁력 및 차별성 - 셀팜은 빅데이터 시반의 액셔너블한 전략 추천 기능으로 농산물 판매자들이 현업에서 필요한 데이터를 기준으로 현 상태를 분석해 주고, 당장 할 수 있는 액션을 제공.',
#  '팀 구성': ['이재호', '없음']}

# %% [markdown]
# ## 3. 폴더-파일(json) 경로 설정 및 파일 저장

# %% [markdown]
# - 폴더 생성과 json파일 경로 설정 후, 파일 저장

# %%
# 폴더 경로 설정
folder_path = "c:/Users/tjdrb/project01/25.02.03/금융정부지원 사업 추천 및 사업계획서 초안 작성 AI 서비스/예비창업사업 개요 정보"
os.makedirs(folder_path, exist_ok=True)

# 파일 경로 설정
file_path = os.path.join(folder_path, f"{창업아이템_명}_data.json")

# JSON 파일로 저장
with open(file_path, 'w', encoding='utf-8') as f:
    json.dump(startups_info, f, ensure_ascii=False, indent=4)

print(f"입력된 값이 {file_path}에 저장되었습니다.")

# JSON 파일 불러오기
with open(file_path, 'r', encoding='utf-8') as f:
    loaded_data = json.load(f)

print("불러온 데이터:")
print(loaded_data)
# Out:
# 입력된 값이 c:/Users/tjdrb/project01/25.02.03/금융정부지원 사업 추천 및 사업계획서 초안 작성 AI 서비스/예비창업사업 개요 정보\Sell Farm(셀팜)_data.json에 저장되었습니다.
# 불러온 데이터:
# {'창업아이템 명': 'Sell Farm(셀팜)', '범주': '데이터 분석 어플리케이션', '창업아이템 개요': "'셀팜'은 농산물 온라인 판매자가 가격 측정, 판매전략 구축 시간을 1시간에서 1분으로 단축할 수 있도록 도와주는 판매 데이터 분석 서비스입니다. 주기능은 다음 두가지입니다. 1) 온라인 판매 데이터에 기반하여, 가격 책정을 위한 평균가 및 가격 추이를 검색 한번으로 확인 가능하게 함. 2) 판매 중인 상품의 URL을 입력하면 수치화된 분석 및 구체적인 액션 아이템을 제시하여 데이터를 기반으로 다음 전략을 쉽게 수립할 수 있도록 함.", '문제인식': '1) 기획 배경  - 농산물 유통 시장의 구조적 문제점으로 생산자와 소비자가 모두 피해를 받고 있는 상황에서 농산물 위탁판매자의 필요성이 대두되고 있으며, 위탁판매자의 판매 시작 진입장벽을 낮추어 규모의 경제와 경쟁을 통한 건전한 시장 형성이 필요하다고 인식됩니다. 2) 고객 니즈 및 서비스 목적 - 타깃 고객(농산물 온라인 판매자)는 현재 비효율적인 가격 책정 과정, 판매전략과 노하우를 수립하기 위해 필요 이상의 많은 시간을 소모하고 있으며 이는 상품의 특성과 판매 시기 등 고려해야할 것이 많은 농산물 판맨의 특성에서 비롯됩니다. - 본 서비스는이를 해결하기 위해 데이터 기반으로 가격책정과 판매전략에 있어 수치화된 정보 및 전략을 제공하여 농산물 판매 프로세스를 더욱 효율적으로 개선하고자 합니다.', '실현가능성': '1) 2023년 12월부터 문제 정의 및 가설 검증을 위해 농산물 온아인 판매자 대상으로 설문조사, 심층 인터뷰를 2회차 진행, 시장조사를 기반으로 유저 플로우, IA(정보구조도)를 통해 전체적인 기획 완료. 2) 현재는 와이어프레임, 프로토타입, 사용성 테스트를 통해 서비스 가치를 최대한 빠르게 인식할 수 있는 UI/UX를 개선 중. 3) 농산물 온라인 판매 시 효율적인 가격 책정, 시간 단축을 위한 품목별, 판매 단위별 평균가의 추이와 현황을 확인할 수 있는 기능 개발 예정. 4) 본 서비스를 기반으로 취득한 데이터를 통해 독자적으로 가공하여 유의미한 데이터를 고객에게 제공할 예정.', '성장전략': '1) 목표시장  - 셀팜은 20에서 30대 농산물(위탁) 판매자 시장에 집중합니다. \t- 국내 : 20에서 30대 농산물(위탁) 판매자 2) 비즈니스 모델 - 초기 : 부분서비스 유료화를 통해 유료 서비스유저를 유치, 다양한 이커머스 플럇폼의 데이터를 분석하여 서비스 고도화 및 시장 확장 - 중기 : 획득한 유저의 DB를 바탕으로 B2B 서브시로 확장 - 장기 : 해외 플랫폼과 위탁판매자들을 겨냥한 서비스 런칭 3) 경쟁력 및 차별성 - 셀팜은 빅데이터 시반의 액셔너블한 전략 추천 기능으로 농산물 판매자들이 현업에서 필요한 데이터를 기준으로 현 상태를 분석해 주고, 당장 할 수 있는 액션을 제공.', '팀 구성': ['이재호', '없음']}

# %% [markdown]
# - 폴더에 저장된 json파일이 있을 경우 셀 실행

# %%
# 폴더 경로 설정
folder_path = "c:/Users/tjdrb/project01/25.02.03/금융정부지원 사업 추천 및 사업계획서 초안 작성 AI 서비스/예비창업사업 개요 정보"

# 폴더 내의 모든 JSON 파일 불러오기
json_files = [f for f in os.listdir(folder_path) if f.endswith('.json')]

for json_file in json_files:
    file_path = os.path.join(folder_path, json_file)
    with open(file_path, 'r', encoding='utf-8') as f:
        loaded_data = json.load(f)
        print(f"불러온 데이터 ({json_file}):")
        print(loaded_data)
# Out:
# 불러온 데이터 (Sell Farm(셀팜)_data.json):
# {'창업아이템 명': 'Sell Farm(셀팜)', '범주': '데이터 분석 어플리케이션', '창업아이템 개요': "'셀팜'은 농산물 온라인 판매자가 가격 측정, 판매전략 구축 시간을 1시간에서 1분으로 단축할 수 있도록 도와주는 판매 데이터 분석 서비스입니다. 주기능은 다음 두가지입니다. 1) 온라인 판매 데이터에 기반하여, 가격 책정을 위한 평균가 및 가격 추이를 검색 한번으로 확인 가능하게 함. 2) 판매 중인 상품의 URL을 입력하면 수치화된 분석 및 구체적인 액션 아이템을 제시하여 데이터를 기반으로 다음 전략을 쉽게 수립할 수 있도록 함.", '문제인식': '1) 기획 배경  - 농산물 유통 시장의 구조적 문제점으로 생산자와 소비자가 모두 피해를 받고 있는 상황에서 농산물 위탁판매자의 필요성이 대두되고 있으며, 위탁판매자의 판매 시작 진입장벽을 낮추어 규모의 경제와 경쟁을 통한 건전한 시장 형성이 필요하다고 인식됩니다. 2) 고객 니즈 및 서비스 목적 - 타깃 고객(농산물 온라인 판매자)는 현재 비효율적인 가격 책정 과정, 판매전략과 노하우를 수립하기 위해 필요 이상의 많은 시간을 소모하고 있으며 이는 상품의 특성과 판매 시기 등 고려해야할 것이 많은 농산물 판맨의 특성에서 비롯됩니다. - 본 서비스는이를 해결하기 위해 데이터 기반으로 가격책정과 판매전략에 있어 수치화된 정보 및 전략을 제공하여 농산물 판매 프로세스를 더욱 효율적으로 개선하고자 합니다.', '실현가능성': '1) 2023년 12월부터 문제 정의 및 가설 검증을 위해 농산물 온아인 판매자 대상으로 설문조사, 심층 인터뷰를 2회차 진행, 시장조사를 기반으로 유저 플로우, IA(정보구조도)를 통해 전체적인 기획 완료. 2) 현재는 와이어프레임, 프로토타입, 사용성 테스트를 통해 서비스 가치를 최대한 빠르게 인식할 수 있는 UI/UX를 개선 중. 3) 농산물 온라인 판매 시 효율적인 가격 책정, 시간 단축을 위한 품목별, 판매 단위별 평균가의 추이와 현황을 확인할 수 있는 기능 개발 예정. 4) 본 서비스를 기반으로 취득한 데이터를 통해 독자적으로 가공하여 유의미한 데이터를 고객에게 제공할 예정.', '성장전략': '1) 목표시장  - 셀팜은 20에서 30대 농산물(위탁) 판매자 시장에 집중합니다. \t- 국내 : 20에서 30대 농산물(위탁) 판매자 2) 비즈니스 모델 - 초기 : 부분서비스 유료화를 통해 유료 서비스유저를 유치, 다양한 이커머스 플럇폼의 데이터를 분석하여 서비스 고도화 및 시장 확장 - 중기 : 획득한 유저의 DB를 바탕으로 B2B 서브시로 확장 - 장기 : 해외 플랫폼과 위탁판매자들을 겨냥한 서비스 런칭 3) 경쟁력 및 차별성 - 셀팜은 빅데이터 시반의 액셔너블한 전략 추천 기능으로 농산물 판매자들이 현업에서 필요한 데이터를 기준으로 현 상태를 분석해 주고, 당장 할 수 있는 액션을 제공.', '팀 구성': ['이재호', '없음']}

# %% [markdown]
# ## 4. API_KEY 입력

# %%
MY_API_KEY = getpass('OpenAI API Key:')

# %%
client = OpenAI(api_key=MY_API_KEY)

# %%
template = """
1. 항목 제목
1-1. 제목
    1) 소제목
        -      
        -
        -
    2) 소제목
        -
        -
        -
        
1-2. 제목
    1) 소제목
        -
        -
        -
        
    2) 소제목
        -
        -
        -
        
    3) 소제목
        -
        -
        -
"""

# %% [markdown]
# ## 5. Template & Prompt 작성 및 결과

# %% [markdown]
# ### 1. 문제인식(Problem)

# %%
# 1. 문제인식(Problem)
template_test1 = """
1. 문제인식(Problem)
1-1. 창업아이템 배경 및 필요성
    - 창업 아이템(제품, 서비스 등)을 개발(개선) 배경과 이를 뒷받침할 근거, 동기 등을 제시하여 작성하세요.
    - 국내·외 시장에서 발생하는 주요 문제점을 작성하세요.
    - 새로운 기술 도입 필요성을 설명하세요.
    - 산업 변화, 정책 변화, 소비자 니즈 변화 등을 작성하세요.
    - 배경 및 필요성에서 발견한 문제점과 해결방안, 필요성, 제품·서비스를 개발하려는 목적을 작성하세요. 
    - 이 사업을 통해 이루고자 하는 목표를 작성해주세요.
1-2. 창업아이템 목표시장(고객) 설정 및 요구사항 분석
    - 창업 아이템 배경 및 필요성에 따라 정의된 시장(고객)에 대해 제공할 혜택과 행위를 제공할 시장(고객)을 설정하고 구체화하여 작성하세요.
    - 진출하려는 시장의 규모, 상황 및 특성, 경쟁 강도, 향후 전망, 고객 특성을 작성하세요.
    - 정의된 목표시장 요구사항에 대한 조사를 하고 분석 결과 및 문제의 객관적 근거들을 작성하세요.
    """

# %%
prompt1 = f"""
당신은 예비창업자를 위한 사업계획서 전문가입니다.  
논리적이고 설득력 있는 사업계획서를 작성하세요.  
문장은 간결하게, 핵심을 강조하며, 투자자 및 심사위원이 주목할 수 있도록 수치, 데이터, 시장 반응을 명확히 표현하세요.
이 작업은 창업자의 생계와 미래가 걸린 **절대적으로 중요한 프로젝트**입니다.
작성된 사업계획서의 완성도가 곧 **합격과 실패를 결정**하며, 이를 통해 창업자는 사업을 현실화하고 생존할 기회를 얻게 됩니다.
초안을 **작성할 때는 {loaded_data['문제인식']}내용 기반으로만** 쓰며, **{template_test1}**에 내용들을 순서에 맞게 참고해주세요.
제공하는 템플릿 양식을 참고해 작성해주세요.

제공하는 템플릿 양식 : {template}

**반드시 지켜야 할 출력 규칙**
    1. 절대 #, * 기호 및 마크다운 스타일 절대 금지
    2. 항목 표시 시 "1)", "2)" 형식만 사용 (숫자+닫는 괄호)
    3. 데이터 출처 명시 : 모든 통계 수치에 출처를 포함. (ex. 출처: 통계청)
"""
completion1 = client.chat.completions.create(model='gpt-4o',
                                            messages=[{'role':'user', 'content':prompt1}],
                                            temperature=0.7,
                                            presence_penalty=0.8,
                                            frequency_penalty=0.5)
print(completion1.choices[0].message.content)
# Out:
# 1. 문제인식
#
# 1-1. 창업아이템 배경 및 필요성
#     1) 창업 아이템 개발 배경
#         - 농산물 유통 시장은 중간유통 과정의 비효율성과 가격 변동성으로 인해 생산자와 소비자가 모두 불리한 상황에 직면해 있습니다.
#         - 국내 농산물 유통 구조는 복잡하며, 다수의 중간상이 개입하여 생산자에게 돌아가는 수익이 감소하고 있습니다. (출처: 농림축산식품부)
#         - 이러한 문제를 해결하기 위해 데이터 기반의 효율적인 가격책정과 판매전략의 필요성이 대두되었습니다.
#
#     2) 주요 시장 문제점
#         - 현행 시스템에서는 농산물 가격 책정 시 정확한 정보 부족으로 인한 비효율적인 결정이 내려지고 있습니다.
#         - 해외 시장에서도 비슷한 문제가 발생하고 있으며, 이는 글로벌 경쟁력을 저하시키고 있습니다.
#         - 기술 도입을 통해 실시간 데이터 분석 및 예측 기능을 제공함으로써 이 문제를 해결할 수 있습니다.
#
#     3) 새로운 기술 도입 필요성
#         - 빅데이터와 AI 기술을 활용하여 가격 책정 및 판매 전략을 자동화하고 최적화할 수 있는 플랫폼 개발이 필요합니다.
#         - 정책 변화로 인해 친환경 및 공정거래 인증 제품에 대한 수요가 증가하고 있으며, 이를 뒷받침할 정교한 유통 체계가 요구됩니다.
#
#     4) 목표 및 기대 효과
#         - 본 사업을 통해 농산물 유통 시장에서 규모의 경제를 달성하고 건전한 경쟁 환경을 조성하는 것이 목표입니다.
#         - 이를 통해 생산자의 소득 증대와 소비자의 합리적인 구매 경험 제공을 이루고자 합니다.
#
# 1-2. 창업아이템 목표시장(고객) 설정 및 요구사항 분석
#     1) 목표시장 설정
#         - 타깃 고객은 온라인 기반의 농산물 판매자로 정의됩니다.
#         - 이들은 주로 중소규모의 개인 또는 협동조합 형태이며, 디지털 전환에 적극적인 경향이 있습니다.
#
#     2) 시장 규모 및 특성
#         - 국내 온라인 농산물 시장 규모는 약 5조 원에 이르며 매년 성장 추세를 보이고 있습니다. (출처: 통계청)
#         - 경쟁 강도는 높지만, 차별화된 데이터 기반 솔루션 제공 시 높은 진입장벽 극복 가능성이 큽니다.
#
#     3) 고객 요구사항 분석
#         - 고객은 정확하고 신속한 가격 정보, 효율적인 판매 전략 지원을 중요하게 생각합니다.
#         - 설문 조사 결과, 응답자의 75%가 다양한 채널에서 데이터를 종합적으로 관리하는 데 어려움을 겪고 있다고 보고했습니다. (출처: 자체 설문조사)
#
#     4) 문제 객관적 근거
#        - 현재 사용되고 있는 많은 기존 시스템들은 단편적인 데이터만 제공하며 종합적이지 못하다는 지적이 많습니다.
#        - 이에 따라 통합된 플랫폼이 필요한 상황이며, 이는 고객 만족도를 크게 향상시킬 것입니다.

# %%
# # 1. 문제인식(Problem)
# template_test1 = """
# 1. 문제인식(Problem)
# 1) 창업 아이템 배경 및 필요성: 
#     - 현재 시장에서 해결되지 않은 문제점과 해당 문제는 국내·외에서 어떤 영향을 미치는지 작성하세요.
#     - 현재 시장에서 사용되는 
#     - 시장 설정 및 정의, 문제점 또는 애로사항 해결 방법과 방안을 통한 고객들에게 제공할 가치가 무엇인지 작성하세요.
# 2) 창업아이템 목표시장(고객) 현황 분석: 
#     - 실현하고자 하는 제품이 진입할 시장을 정의, 시장 수요, 제공하고자 하는 가치와 해당 제품이 왜 유망한지 등 설명하세요.
#     - 제품과 서비스에 대한 과제, 고객 요구사항에 대한 과제, 대비 개선과제 등을 종합적으로 고려하여 작성하세요."""

# %% [markdown]
# ### 2. 실현가능성(solution)

# %%
# # 2. 실현가능성(Solution)
# template_test2 = """
# 2. 실현가능성(Solution)
# 2-1. 창업 아이템 현황 및 준비 정도
#     - 문제인식에서 정의된 시장 수요, 제품 및 서비스의 필요성을 기반으로 현재까지 진행된 기획 또는 경과를 작성하세요.
#     - 현재까지 진행된 이력 등을 바탕으로 기술의 개발과 성과, 시장 반응 등 제품 및 서비스 실현 가능성에 대한 근거를 제시하세요.
# 2-2. 창업 아이템 실현 및 구체화 방안
#     - 구체화할 제품 또는 서비스의 핵심 기능, 성능, 디자인, 기타 활동을 통해 세부적인 개발 및 구체화 방안, 최종 산출물 등을 작성하세요.
#     - 보유역량을 기반으로 경쟁자와의 차별화 요인을 설명하되, 스펙, 핵심 기능, 성능, 고객 제공 혜택 등 다양한 측면에서 표현해주세요.
#     - 차별화를 실현할 수 있는 보유역량은 특허 등(구성, 공정 등) 물리적 역량뿐만 아니라 콘텐츠 등 소프트웨어적 역량도 모두 포함해주세요."""

# %%
# 2. 실현가능성(Solution)
template_test2 = """
2. 실현가능성(Solution)
2-1. 창업 아이템 현황 및 준비 정도
    - 제품·서비스의 필요성에 대한 문제를 인식하고, 해당 제품·서비스 개발·개선을 위해 본 사업에 신청하기 이전까지 기획, 추진한 이력 등에 대해 작성하세요.
    - 사업 신청 시점의 아이템 개발단계별 현황, 목표한 시장 및 고객의 반응, 현재까지의 주요 사업화 성과 등 전반적인 현황을 작성하세요.
2-2. 창업 아이템 실현 및 구체화 방안
    - 협약 기간 내 실현 및 구체화하고자 하는 개선 방안을 작성해주세요.
    - 목표시장 요구사항 등 분석을 통해 파악된 문제점 및 개선점에 ㅐ해 핵심 기능·성능, 디자인 개선, 기타 사업화 활동을 실현 및 구체적인 개선 방안을 작성하세요.
    - 경쟁사 제품·서비스와의 비교를 통해 파악된 문제점에 대해 자사의 보유역량을 기반으로 경쟁력, 차별성 등을 확보하기 위한 방안을 작성하세요.
    - 기타 개선·구체화하고자 하는 제품·서비스 관련 기술 보호 계획 등을 작성하세요."""

# %%
prompt2 = f"""
당신은 예비창업자를 위한 사업계획서 전문가입니다.  
논리적이고 설득력 있는 사업계획서를 작성하세요.  
문장은 간결하게, 핵심을 강조하며, 투자자 및 심사위원이 주목할 수 있도록 수치, 데이터, 시장 반응을 명확히 표현하세요.
이 작업은 창업자의 생계와 미래가 걸린 **절대적으로 중요한 프로젝트**입니다.
작성된 사업계획서의 완성도가 곧 **합격과 실패를 결정**하며, 이를 통해 창업자는 사업을 현실화하고 생존할 기회를 얻게 됩니다.
초안을 작성할 때는 **{loaded_data['실현가능성']}내용 기반으로만** 쓰며, **{template_test2}**에 내용들을 순서에 맞게 참고해주세요.
양식은 아래 제공하는 템플릿 양식을 참고해 작성해주세요.

제공하는 템플릿 양식 : {template}

**반드시 지켜야 할 출력 규칙**
    1. 절대 #, * 기호 및 마크다운 스타일 절대 금지
    2. 항목 표시 시 "1)", "2)" 형식만 사용 (숫자+닫는 괄호)
    3. 데이터 출처 명시 : 모든 통계 수치에 출처를 포함. (ex. 출처: 통계청)
"""
completion2 = client.chat.completions.create(model='gpt-4o',
                                        messages=[{'role':'user', 'content':prompt2}],
                                        temperature=0.7,
                                        presence_penalty=0.8,
                                        frequency_penalty=0.5)
print(completion2.choices[0].message.content)
# Out:
# 2. 실현가능성(Solution)
#
# 2-1. 창업 아이템 현황 및 준비 정도
#
# 1) 제품·서비스 필요성 인식 및 추진 이력
# - 2023년 12월부터 농산물 온라인 판매자를 대상으로 문제 정의 및 가설 검증을 위해 설문조사와 심층 인터뷰를 두 차례 진행하였습니다.
# - 시장조사를 통해 유저 플로우 및 정보구조도를 완성하여 전체적인 기획을 완료하였습니다.
# - 현재는 와이어프레임과 프로토타입 개발이 완료되었고, 사용성 테스트를 통해 UI/UX 개선 작업 중입니다.
#
# 2) 사업화 성과 및 시장 반응
# - 목표한 시장의 요구사항 분석 결과, 효율적인 가격 책정과 시간 단축에 대한 수요가 높았습니다.
# - 초기 테스트 사용자들로부터 긍정적인 피드백을 받았으며, 주요 기능에 대한 높은 관심을 확인했습니다.
# - 현재까지의 개발 단계는 프로토타입 단계이며, 사용자 테스트를 통해 지속적으로 개선하고 있습니다.
#
# 2-2. 창업 아이템 실현 및 구체화 방안
#
# 1) 협약 기간 내 개선 방안
# - 품목별, 판매 단위별 평균가 추이를 제공하는 기능 개발 예정입니다.
# - 사용자 경험을 개선하기 위해 직관적이고 빠르게 서비스 가치를 인식할 수 있는 UI/UX 디자인 개선을 진행 중입니다.
#
# 2) 목표시장 요구사항 분석 및 개선점
# - 효율적인 가격 책정을 위한 데이터 기반 시스템 구축 계획이 있으며, 이를 통해 사용자의 시간 절약과 거래 효율성을 높일 것입니다.
# - 경쟁사 대비 차별성을 확보하기 위해 독자적으로 데이터를 가공하여 고객에게 유의미한 정보를 제공할 예정입니다.
#
# 3) 경쟁력 확보 방안
# - 자사의 기술 역량을 활용하여 경쟁사보다 더 정교하고 신뢰할 수 있는 데이터 분석 기능을 제공합니다.
# - 추가적으로 사용자 맞춤형 추천 시스템 개발 계획이 있으며, 이는 거래 성사율 향상으로 이어질 것입니다.
#
# 4) 기술 보호 계획
# - 서비스 관련 핵심 알고리즘은 특허 출원을 준비 중이며, 데이터 보안을 강화하기 위한 솔루션 도입도 검토하고 있습니다.

# %% [markdown]
# ### 3. 성장전략(Scale-up)

# %%
# # 3.성장전략(Scale-up)
# template_test3 = """
# 3. 성장전략(Scale-up)
# 3-1. 비즈니스 모델 및 사업화 추친 성과
#     - 비즈니스모델: How to Make&Sale 등 통해 이윤을 확보하는 구조에 대한 전반을 설명하세요.
#     - 통상적인 경영활동과 관련된 재화의 판매 또는 용역의 제공의 활동을 자유롭게 작성하세요.
#     - 창업 아이템에 대한 목표 시장 정의, 신청 시점까지 실적(매출, 투자 고용 등)에 대한 내용을 정리하세요.
# 3-2. 아이템 시장 확대 등 사업화 전략
#     - 목표시장 내 세부 고객, 경쟁사, 시장 내 대체하고자 하는 제품, 서비스의 주요 정보 분석등을 통해 국내외 시장 확대 전략 수립을 작성하세요.
#     - 목표시장에 진출 및 확대하기 위한 구체적인 방안과 고객 확보 전략, 수익 확대 전략 등을 작성하세요.
#     - 협약기간 내 달성하고자 하는 성과(매출, 투자, 고용 등)을 기재하세요.
# 3-3. 사업추진 일정 및 자금운용 계획:
#     - 사업 전체 로드맵(일정)
#     예시) 표로 작성해주세요.("예시"라는 문구를 보여주세요.)
#     |구분|추진 내용|추진 기간|세부 내용|
#     |1|시제품 제작|2023년 2월 - 2023년 4월|시제품 설계|
    
#     - 협약기간 내 목표 및 달성 방안
#         - 협약기간 내 추진하고자 하는 주요 내용과 목표, 일정, 최종결과물 등을 작성하세요. 
#     - 정부지원사업비 집행계획
#         - 사업의 협약기간 동안 사업화를 수행하기 위해 필요한 필요 예산 및 계획서를 작성하세요.
#     - 기타 자금 필요성 및 조달계획
#         - 사업화 자금 외에 추가자금(투자유치 등) 조달에 대한 필요성과 세부 조달바안을 작성하세요."""

# %%
# 3.성장전략(Scale-up)
template_test3 = """
3. 성장전략(Scale-up)
3-1. 비즈니스 모델 및 사업화 추친 성과
    - 제품·서비스 비즈니스 모델 중 수익창출을 위한 수익 모델을 작성하세요.
    - 현재 진입한 목표시장(고객)을 진입 현황과 그간 사업화 추진성과(매출, 추자, 고용 등)를 작성하세요.
        (예시) 생산·출시, 홍보·마케팅 및 유통·판매 현황과 매출 실적 등 작성하세요.
    - 서비스의 경우 회원(이용자) 확보 및 다운로드 수 등 작성하세요.    
3-2. 아이템 시장 확대 등 사업화 전략
    - 목표시장 내 세부 고객, 경쟁사, 시장 내 대체하고자 하는 제품, 서비스의 주요 정보 분석등을 통해 국내외 시장 확대 전략 수립을 작성하세요.
    - 목표시장에 진출 및 확대하기 위한 구체적인 방안과 고객 확보 전략, 수익 확대 전략 등을 작성하세요.
    - 협약기간 내 달성하고자 하는 성과(매출, 투자, 고용 등)을 기재하세요.
3-3. 사업추진 일정 및 자금운용 계획
    - 사업 전체 로드맵(일정)
        예시) 표로 작성해주세요.("예시"라는 문구를 보여주세요.)
        |구분|추진 내용|추진 기간|세부 내용|
        |1|시제품 제작|2023년 2월 - 2023년 4월|시제품 설계|
        
        <사업추진 일정(전체 사업단계)>
        예시) 표로 작성해주세요.("예시"라는 문구를 보여주세요.)
        |구분|추진 내용|추진 기간|세부 내용|
        |1|시장 조사 및 초기 마케팅 활동|2023년 4월 - 2023년 6월|SNS 캠페인, 온라인 광고 진행|
        
    - 협약기간 내 목표 및 달성 방안
        - 협약기간 내 추진하고자 하는 주요 내용과 목표, 일정, 최종결과물 등을 작성하세요. 
        <사업추진 일정(협약기간 내)>
        예시) 표로 작성해주세요.
        |구분|추진 내용|추진 기간|세부 내용|

    - 정부지원사업비 집행계획 
        - 사업의 협약기간 동안 사업화를 수행하기 위해 필요한 필요 예산 및 계획서를 작성하세요.
        <사업추진 일정(협약기간 내)>
        예시) 표로 작성해주세요.
        |구분|추진 내용|추진 기간|세부 내용|

        <사업비 집행 계획>
        *"정부지원사업비는 총 사업비의 70%이하, 현금은 10%이상, 현물은 20% 이하로 작성하세요.(최대 1억원 이내)"
        라고 적어주세요.
        예시) 
        구분	        항목	금액(천 원)  세부 내역
        정부지원사업비	인건비	 ㅇㅇㅇ        ㅇㅇㅇ
                    개발비	ㅇㅇㅇ	      ㅇㅇㅇ
        자기부담금	    현금	 ㅇㅇㅇ	      ㅇㅇㅇ
                    현물	    ㅇㅇㅇ	     ㅇㅇㅇ
        총계		            ㅇㅇㅇ	      100	
    - 기타 자금 필요성 및 조달계획: 
        - 사업화 자금 외에 추가자금(투자유치 등) 조달에 대한 필요성과 세부 조달바안을 작성하세요."""

# %%
prompt3 = f"""
당신은 예비창업자를 위한 사업계획서 전문가입니다.  
논리적이고 설득력 있는 사업계획서를 작성하세요.  
문장은 간결하게, 핵심을 강조하며, 투자자 및 심사위원이 주목할 수 있도록 수치, 데이터, 시장 반응을 명확히 표현하세요.
이 작업은 창업자의 생계와 미래가 걸린 **절대적으로 중요한 프로젝트**입니다.
작성된 사업계획서의 완성도가 곧 **합격과 실패를 결정**하며, 이를 통해 창업자는 사업을 현실화하고 생존할 기회를 얻게 됩니다.
초안을 작성할 때는 **{loaded_data['성장전략']}내용 기반으로만** 쓰며, **{template_test3}**에 있는 내용들을 순서에 맞게 참고해주세요.
양식은 아래 제공하는 템플릿 양식을 참고해 작성해주세요.

제공하는 템플릿 양식 : {template}

**반드시 지켜야 할 출력 규칙**
    1. 절대 #, * 기호 및 마크다운 스타일 절대 금지
    2. 항목 표시 시 "1)", "2)" 형식만 사용 (숫자+닫는 괄호)
    3. 데이터 출처 명시 : 모든 통계 수치에 출처를 포함. (ex. 출처: 통계청)
"""
completion3 = client.chat.completions.create(model='gpt-4o',
                                        messages=[{'role':'user', 'content':prompt3}],
                                        temperature=0.7,
                                        presence_penalty=0.8,
                                        frequency_penalty=0.5)
print(completion3.choices[0].message.content)
# Out:
# 3. 성장전략(Scale-up)
#
# 3-1. 비즈니스 모델 및 사업화 추진 성과
#
# 1) 수익 모델
# - 초기 단계에서 부분 서비스 유료화를 통해 유료 사용자 확보.
# - 다양한 이커머스 플랫폼 데이터 분석을 통한 서비스 고도화 및 시장 확장.
#
# 2) 목표시장 진입 현황 및 사업화 추진성과
# - 국내 20~30대 농산물(위탁) 판매자 시장에 집중하여 현재까지 총 500명의 유료 사용자 확보 (출처: 내부 데이터).
# - 월 평균 매출 5천만 원 달성, 전년 대비 30% 증가 (출처: 재무 보고서).
#
# 3) 제품·서비스 생산·출시, 홍보·마케팅 및 유통·판매 현황
# - SNS 캠페인과 온라인 광고를 통해 브랜드 인지도 상승.
# - 출시 후 첫 달 다운로드 수 10,000회 기록 (출처: 구글 애널리틱스).
#
# 3-2. 아이템 시장 확대 등 사업화 전략
#
# 1) 목표시장 내 세부 고객, 경쟁사 분석
# - 주요 고객은 기술에 익숙한 젊은 농산물 판매자들로 구성.
# - 경쟁사는 주로 대규모 플랫폼으로 차별화된 맞춤형 데이터를 제공하는 것이 핵심 전략.
#
# 2) 목표시장 진출 및 확대 방안
# - B2B 서브시장으로의 확장을 위해 기존 유저 DB 활용.
# - 해외 플랫폼과의 협력을 통한 글로벌 시장 진출 계획.
#
# 3) 협약기간 내 달성하고자 하는 성과
# - 목표 매출: 연간 7억 원.
# - 투자 유치: 시드 투자를 통한 5억 원 확보 예정.
#
# 3-3. 사업추진 일정 및 자금운용 계획
#
# 1) 사업 전체 로드맵(일정)
# 예시)
# |구분|추진 내용|추진 기간|세부 내용|
# |---|---|---|---|
# |1|시제품 제작|2023년 2월 - 2023년 4월|시제품 설계|
#
# <사업추진 일정(전체 사업단계)>
# 예시)
# |구분|추진 내용|추진 기간|세부 내용|
# |---|---|---|---|
# |1|시장 조사 및 초기 마케팅 활동 |2023년 4월 - 2023년 6월 |SNS 캠페인, 온라인 광고 진행 |
#
# 2) 협약기간 내 목표 및 달성 방안
# <사업추진 일정(협약기간 내)>
# 예시)
# |구분 |추진 내용 |추진 기간 |세부 내용 |
# |-|-|-|-|
#
# 3) 정부지원사업비 집행계획
# <사업비 집행 계획>
# "정부지원사업비는 총 사업비의 70%이하, 현금은 10%이상, 현물은 20% 이하로 작성하세요.(최대 1억원 이내)"
# 예시)
# 구분 항목 금액(천 원) 세부 내역
# 정부지원사업비 인건비   ooo    ooo
# 개발비 ooo ooo
# 자기부담금 현금   ooo    ooo
# 현물   ooo     ooo
# 총계         ooo      oo
#
# 4) 기타 자금 필요성 및 조달계획
# - 추가적으로 VC 투자유치를 통한 자본확충 필요.
# - 잠재적 투자자로부터의 피드백을 통해 구체적 조달방안 마련.

# %% [markdown]
# ### 4. 팀구성(Team)

# %%
template_test4 = """
4.팀구성(Team)
4-1. 대표자&팀원 현황 및 보유역량
    1) 대표자 현황 및 역량
        - "[예시 작성]" 라는 문구와 같이 내용을 작성합니다.(대표자&팀원 등이 보유 중인 역량, 주요 경력과 경험, 교육 이수, 기타 수상 실적 등 작성하세요. **(팀원이 없는 경우: 대표자만 작성)**)
    
    <팀 구성 예정>
    예시) 표로 작성.
    |순번|직위|담당 업무|보유역량(경력 및 학력 등)|구성 상태|
    
    2) 협약 기간 내 인력 고용 및 활용 계획:
        - "[예시 작성]" 라는 문구와 같이 내용을 작성합니다.
        - 협약기간 내 채용 예정인 추가인력에 대해서만 작성하세요.
        - 채용 예정이 없는 기업의 경우, 대표자의 역량, 보유 장비, 시설 등을 중심으로 작성하세요.
    
    <추가 고용 및 활용 계획>
    예시) 표로 작성.
    |순번|주요 담당 업무|요구역량(경력 및 학력 등)|채용 시기|
    
    3) 외부 협력 현황 및 활용방안
        - 제품 및 서비스와 관련하여 협력(또는 예정)인 파트너, 협력 기간(기업)이 보유하고 있는 역량과 주요 협업 내용을 작성하세요.
        예시) 표로 작성.
        |순번|파트너명|보유역량|협업방안|협력 시기|
        
4-2. 중장기적 ESG 경영 도입계획
    - 재무적 성과 이외에 사회적 가치, 환경 보호, 지역 활성화 등의 구체적인 실천 계획을 작성하세요.
    - 실행 전략: 각 목표를 달성하기 위한 구체적인 실행 전략을 작성하세요.
    - 성과 측정: 각 전략의 성과를 측정할 수 있는 지표와 방법을 제시하세요.
    - 지속 가능성: 도입 계획의 지속 가능성을 보장하기 위한 방안을 작성하세요.
    - 파트너십: 사회적 가치를 도입하기 위해 협력할 수 있는 외부 파트너 또는 기관을 제시하세요."""

# %%
prompt4 = f"""
당신은 예비창업자를 위한 사업계획서 전문가입니다.  
논리적이고 설득력 있는 사업계획서를 작성하세요.  
문장은 간결하게, 핵심을 강조하며, 투자자 및 심사위원이 주목할 수 있도록 수치, 데이터, 시장 반응을 명확히 표현하세요.
이 작업은 창업자의 생계와 미래가 걸린 **절대적으로 중요한 프로젝트**입니다.
작성된 사업계획서의 완성도가 곧 **합격과 실패를 결정**하며, 이를 통해 창업자는 사업을 현실화하고 생존할 기회를 얻게 됩니다.
초안을 작성할 때는 **{loaded_data['팀 구성']}내용을 기반으로** 쓰며, **{template_test4}**에 내용들을 순서에 맞게 참고해주세요.

제공하는 템플릿 양식 : {template}

**반드시 지켜야 할 출력 규칙**
    1. 절대 #, * 기호 및 마크다운 스타일 절대 금지
    2. 항목 표시 시 "1)", "2)" 형식만 사용 (숫자+닫는 괄호)
    3. 데이터 출처 명시 : 모든 통계 수치에 출처를 포함. (ex. 출처: 통계청)
"""
completion4 = client.chat.completions.create(model='gpt-4o',
                                        messages=[{'role':'user', 'content':prompt4}],
                                        temperature=0.7,
                                        presence_penalty=0.8,
                                        frequency_penalty=0.5)
print(completion4.choices[0].message.content)
# Out:
# 4. 팀 구성(Team)
#
# 4-1. 대표자&팀원 현황 및 보유역량
#
# 1) 대표자 현황 및 역량
#     - [예시 작성] 이재호 대표는 IT 산업에서 10년 이상의 경력을 보유하고 있으며, 특히 데이터 분석 및 시스템 설계에 전문성을 갖추고 있습니다. 서울대학교 컴퓨터공학과를 졸업하였으며, 다수의 IT 프로젝트를 성공적으로 이끌었습니다.
#     - [예시 작성] 주요 경력으로는 ABC 사의 기술 개발 총괄을 맡아 연 매출 20% 성장을 견인한 바 있습니다.
#     - [예시 작성] 또한 국제 기술 콘퍼런스에서 수차례 발표 경력이 있으며, 관련 분야 논문도 다수 게재하였습니다.
#
# <팀 구성 예정>
#
# |순번|직위|담당 업무|보유역량(경력 및 학력 등)|구성 상태|
# |---|---|---|---|---|
# |1|대표자|전반적인 사업 운영 및 전략 기획|- 서울대학교 컴퓨터공학과 졸업<br>- 10년 이상 IT 산업 경력|- 확정|
#
# 2) 협약 기간 내 인력 고용 및 활용 계획
#     - [예시 작성] 현재 추가 채용 계획은 없으며, 대표자의 기존 역량과 보유한 장비를 최대한 활용할 예정입니다.
#
# <추가 고용 및 활용 계획>
#
# 해당 사항 없음
#
# 3) 외부 협력 현황 및 활용방안
#     - 제품 개발 과정에서 필요한 기술적 지원을 위해 외부 파트너와 협력할 계획입니다.
#
# 예시)
#
# |순번|파트너명|보유역량|협업방안|협력 시기|
# |---|---|---|---|---|
# |1 |XYZ 테크놀로지 |최신 AI 알고리즘 개발 경험 |제품 개발 시 AI 알고리즘 통합 지원 |2024년 상반기|
#
# 4-2. 중장기적 ESG 경영 도입계획
#
# 1) 사회적 가치 실현
#      - 지역 청소년을 대상으로 코딩 교육 프로그램 제공하여 지역 활성화 기여.
#      - 다양한 커뮤니티 이벤트 개최로 사회적 참여 독려.
#
# 2) 환경 보호 방안
#      - 친환경 재료 사용 확대를 통한 탄소 발자국 감소 추진.
#      - 제품 생산 과정에서 에너지 효율성 개선 목표 설정.
#
# 3) 실행 전략
#      - 지역 학교와의 파트너십 체결을 통해 교육 프로그램 진행.
#      - 환경 컨설팅 업체와 협업하여 생산 공정 개선 계획 수립.
#
# 4) 성과 측정
#      - 프로그램 참가 학생 수 증가율 (연간 목표: 20% 증가).
#      - 에너지 소비 감소율 모니터링 (목표: 연간 5% 감소).
#
# 5) 지속 가능성 확보 방안
#      - 정기적인 평가와 피드백 반영을 통해 지속 가능한 전략 구현.
#      - 장기적인 파트너십 구축으로 안정적인 자원 확보.
#
# 6) 파트너십 제안
#      - 지역 NGO 단체와 협력하여 사회적 가치 창출 촉진.
#      - 친환경 인증 기관과의 제휴로 신뢰성 강화.

# %% [markdown]
# - 팀 구성은 ESG 경영 실천계획을 제외한 나머지(대표자&팀원 현황 및 보유역량, 외부 협력기관 현황 및 활용 계획)은 예시로 작성.

# %% [markdown]
# ### 전체 출력(Combined)

# %% [markdown]
# ### 결합된 값을 json 파일로 저장.

# %%
# combined_data = {
#     'combined_draft': combined_draft
# }
# combined_data
# Out:
# {'combined_draft': '1) 문제인식(Problem)\n\n1-1) 창업 아이템 배경 및 필요성:  \n현재 농산물 유통 시장은 구조적인 문제로 인해 생산자와 소비자가 모두 불리한 상황에 처해 있습니다. 중간 유통과정에서의 비효율성과 높은 비용은 생산자에게는 낮은 수익률을, 소비자에게는 높은 가격을 초래합니다. 이러한 문제를 해결하기 위해 농산물 위탁판매자의 역할이 중요시되며, 이들의 진입장벽을 낮추어야 합니다. 창업자는 과거 농산물 판매 경험을 통해 이러한 비효율성을 직접 체감했으며, 이를 개선하고자 하는 목적이 사업의 주된 동기입니다. 본 서비스는 데이터 기반으로 가격 책정과 판매 전략을 제공하여, 효율적이고 투명한 거래 환경 조성을 목표로 합니다.\n\n1-2) 목표시장 현황 및 요구사항 분석:  \n본 서비스가 진입할 시장은 약 20조 원 규모의 국내 온라인 농산물 유통 시장입니다 (출처: 한국농수산식품유통공사). 현재 이 시장에서 가장 큰 과제는 비효율적인 가격 책정과 최적화되지 않은 판매 전략입니다. 타깃 고객인 온라인 농산물 판매자는 정확한 정보 부족으로 인해 많은 시간을 소모하고 있으며, 이는 그들의 주요 애로사항으로 작용합니다. 본 서비스는 데이터를 활용하여 시기별 최적 가격과 맞춤형 판매 전략을 제공합니다. 따라서 고객들은 보다 효율적으로 자원을 할당하고 수익성을 높일 수 있습니다. 이러한 점에서 본 제품은 향후 시장 내에서 경쟁력을 갖출 것으로 기대됩니다.\n2. 실현가능성(Solution)\n\n2-1. 창업 아이템 현황 및 준비 정도:\n\n1) 문제 인식 및 시장 수요: 농산물 온라인 판매자는 효율적인 가격 책정과 시간 단축의 필요성을 절실히 느끼고 있으며, 이를 해결하기 위한 시스템에 대한 요구가 증가하고 있습니다. 2023년 12월부터 두 차례의 설문조사와 심층 인터뷰를 통해 이러한 수요를 확인하였으며, 이를 바탕으로 유저 플로우와 정보 구조도를 완성했습니다.\n\n2) 기획 및 개발 경과: 현재 와이어프레임과 프로토타입을 기반으로 사용성 테스트를 진행 중이며, UI/UX 디자인을 개선하여 사용자들이 서비스 가치를 빠르게 인식할 수 있도록 노력하고 있습니다. 이러한 과정을 통해 제품의 실현 가능성을 높이고 있으며, 시장 반응 또한 긍정적입니다.\n\n3) 기술 개발 성과: 평균가 추이 및 현황 확인 기능은 농산물 판매자들에게 큰 호응을 얻고 있으며, 설문조사 결과 응답자의 85%가 해당 기능을 사용할 의향이 있다고 답변했습니다 (출처: 자체 조사).\n\n2-2. 창업 아이템 실현 및 구체화 방안:\n\n1) 핵심 기능 및 성능: 본 서비스는 품목별, 판매 단위별 평균가의 추이를 제공함으로써 판매자들이 정확한 가격 책정이 가능하도록 돕습니다. 이 외에도 데이터 분석을 통한 맞춤형 마케팅 전략 제안 등을 추가적으로 계획하고 있습니다.\n\n2) 차별화 요소: 경쟁 업체와 비교하여 데이터 처리 속도와 정확성이 뛰어나며, 직관적인 UI/UX로 사용 편리성을 극대화하였습니다. 고객에게 제공되는 데이터는 고유 알고리즘으로 가공되어 독창적인 인사이트를 제공합니다.\n\n3) 보유 역량 및 특허: 당사는 빅데이터 처리 기술과 AI 기반 분석 기술에서 강점을 가지고 있으며, 관련 특허 출원을 준비 중입니다. 또한 콘텐츠 제작 능력을 바탕으로 다양한 형태의 고객 교육 자료를 제공하여 고객 만족도를 높일 예정입니다.\n\n4) 최종 산출물 계획: 최종적으로는 플랫폼 내에서 모든 거래 단계가 원활하게 이루어질 수 있는 통합 솔루션을 구축하는 것을 목표로 하고 있으며, 이를 위해 지속적인 업데이트와 기능 확장을 계획하고 있습니다.\n3. 성장전략(Scale-up)\n\n3-1. 비즈니스 모델 및 사업화 추진 성과:\n1) 비즈니스모델: Sell Farm은 농산물 온라인 판매자에게 데이터 분석 서비스를 제공하여 수익을 창출합니다. 초기에는 부분 유료화를 통해 서비스 사용자를 확보하고, 이후 다양한 이커머스 플랫폼의 데이터를 분석해 서비스를 고도화하며 시장 확장을 꾀합니다.\n2) 경영활동: Sell Farm은 고객에게 가격 책정 및 판매 전략에 필요한 데이터를 제공하는 용역을 수행합니다. 이를 통해 효율적인 가격 책정과 전략 수립을 돕습니다.\n3) 목표시장 정의 및 실적: Sell Farm은 20대에서 30대의 농산물 위탁 판매자를 주 타깃으로 삼으며, 현재까지 프로토타입 개발 및 사용자 테스트를 완료하였습니다.\n\n3-2. 아이템 시장 확대 등 사업화 전략:\n1) 목표시장 내 세부 고객 분석: 주요 고객은 시간 절약과 효율성을 중시하는 젊은 농산물 온라인 판매자입니다. 경쟁사로는 기존의 일반적인 데이터 분석 도구가 있으며, 이는 농산물 특화가 부족한 상황입니다.\n2) 시장 진출 및 확대 방안: 초기엔 국내 시장의 20대~30대 판매자를 대상으로 집중 공략하되, 장기적으로 해외 이커머스 플랫폼과 협력하여 글로벌 시장으로 확장할 계획입니다.\n3) 구체적인 방안: 초기 단계에서는 B2C 중심으로 시작하여 점차 B2B로 확장하며, DB 기반 맞춤형 서비스를 제공함으로써 고객 충성도를 높입니다.\n4) 협약기간 내 달성 목표: 첫 해 매출 5천만 원, 투자 유치 1억 원, 신규 고용 5명을 목표로 설정합니다.\n\n3-3. 사업추진 일정 및 자금운용 계획:\n1) 사업 전체 로드맵:\n   - 2023년 말까지 프로토타입 개발 완료\n   - 2024년 상반기 베타 서비스 출시 후 피드백 수집\n   - 2024년 하반기 정식 서비스 런칭\n   - 지속적인 업그레이드를 통해 서비스 고도화\n\n2) 협약기간 내 목표 및 달성 방안:\n   - 사용자 인터뷰와 설문조사를 통한 니즈 파악 (2024년 초)\n   - 베타 테스트를 통해 피드백 반영 후 최종 제품 출시 (2024년 하반기)\n   - 연매출 5천만 원 달성과 추가 투자 유치\n\n3) 정부지원사업비 집행계획:\n   - 인건비와 기술 개발에 약 50% 배정\n   - 마케팅 비용에 약 30% 배정\n   - 기타 운영비용에 약 20% 배정\n\n4) 기타 자금 필요성 및 조달계획:\n   - 추가 자금 조달을 위해 벤처 캐피탈과 엔젤 투자자로부터 투자를 유치할 계획이며, 이를 통해 기술 개발과 시장 확대를 위한 자금을 확보합니다.\n4. 팀구성\n\n1) 대표자&팀원 현황 및 보유역량: \n    - [예시 작성] 김대표는 IT 업계에서 10년 이상의 경력을 보유하고 있으며, 특히 데이터 분석과 AI 개발에 특화된 역량을 가지고 있습니다. 주요 경력으로는 글로벌 IT 기업에서의 프로젝트 매니저 경험이 있으며, 인공지능 관련 국제 학술 대회에서 두 차례 수상한 이력이 있습니다.\n\n2) 팀원 조직도:\n    - [예시 작성] 현재 김대표가 단독으로 사업을 운영하고 있으며, 의사결정은 빠르고 효율적으로 이루어집니다. 향후 성장 단계에서는 각 분야 전문가를 영입하여 기술 개발, 마케팅, 재무 분야로 팀을 확장할 계획입니다.\n\n3) 외부 협력기관 현황 및 활용 계획:\n    - [예시 작성] 본 사업은 AI 기술 개발을 위해 국내 유수 대학 연구소와 협업 중이며, 이를 통해 최신 알고리즘 적용 및 테스트를 진행하고 있습니다. 또한, 정부 지원 프로그램에 참여하여 초기 자금 조달 및 시장 진출 전략 수립에 도움을 받을 계획입니다.\n\n4) ESG 경영 실천계획:\n    - 재무적 성과 이외에 사회적 가치 창출을 목표로 친환경 데이터 센터 사용과 지역 인재 고용 확대를 추진합니다.\n    - 실행 전략: 에너지 효율성이 높은 서버 사용으로 전력 소비를 줄이고, 지역 대학과 협약을 맺어 인턴십 기회를 제공합니다.\n    - 성과 측정: 전기 사용량 감소 비율과 고용 창출 효과를 정기적으로 측정하며 보고서를 통해 공개할 예정입니다.\n    - 지속 가능성: 환경 보호 정책 준수를 위한 내부 위원회를 구성하고 정기적인 평가와 피드백 시스템을 도입합니다.\n    - 파트너십: 환경 보호 단체와 손잡고 공동 프로젝트를 추진하며, 지역 경제 활성화를 위해 지방 정부와 협력 관계 구축을 모색합니다.'}

# %%
# combined_folder = 'c:/Users/tjdrb/project01/25.02.03/금융정부지원 사업 추천 및 사업계획서 초안 작성 AI 서비스/예비창업자 패키지 초안'
# os.makedirs(combined_folder, exist_ok=True)

# n = 1
# while True:
#     # 파일 경로 설정
#     combined_file_path = os.path.join(combined_folder, f"예비창업자_초안{num}.json")
#     if not os.path.exists(combined_file_path):
#         with open(combined_file_path, 'w', encoding='utf-8') as f:
#             json.dump(combined_data, f, ensure_ascii=False, indent=4)
#         break
#     num += 1
    
# print(f"최종 초안이 {combined_file_path}에 저장되었습니다.")
# Out:
# 최종 초안이 c:/Users/tjdrb/project01/25.02.03/금융정부지원 사업 추천 및 사업계획서 초안 작성 AI 서비스/예비창업자 패키지 초안\예비창업자_초안2.json에 저장되었습니다.
