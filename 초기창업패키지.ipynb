# %% [markdown]
# # [초기창업패키지]

# %%
import os
import json
from getpass import getpass
from openai import OpenAI

# %%
창업아이템_명 = input('창업아이템 명: ')
범주 = input('범주: ')
창업아이템_개요 = input('창업아이템 개요: ')
문제인식 = input('문제인식: ')
실현가능성 = input('실현가능성: ')
성장전략 = input('성장전략: ')
팀_구성1 = input('대표자 이름과 보유기술 및 역량을 적어주세요.: ')
팀_구성2 = input('팀원 이름과 보유기술 및 역량을 적어주세요.: ')

# %%
startups_info = {
    '창업아이템 명' : 창업아이템_명,
    '범주' : 범주,
    '창업아이템 개요' : 창업아이템_개요,
    '문제인식' : 문제인식,
    '실현가능성' : 실현가능성,
    '성장전략' : 성장전략,
    '팀 구성' : [팀_구성1, 팀_구성2]
}

startups_info = {k: v for k, v in startups_info.items() if v}
startups_info
# Out:
# {'창업아이템 명': 'AI 면접 코치',
#  '범주': ' HR Tech / 인공지능',
#  '창업아이템 개요': 'AI를 활용해 구직자의 면접 응답을 분석하고 피드백을 제공하는 스마트 면접 연습 플랫폼',
#  '문제인식': '취업 경쟁이 심화되면서 면접 대비의 중요성이 증가. 전문적인 면접 피드백을 받을 수 있는 기회가 제한적이므로 AI 기술을 활용한 개인 맞춤형 솔루션 필요.',
#  '실현가능성': 'AI 음성 및 표정 분석 기술을 활용하여 면접자의 발음, 어휘, 태도를 분석하고, 실시간 피드백 제공. 기업별 맞춤 질문 데이터베이스 구축 중.',
#  '성장전략': ' 취업 준비생 및 경력직 전환자 대상 초기 시장 확보. 이후 대학교 및 취업 컨설팅 기관과의 협업을 통해 B2B 서비스 확장 계획.',
#  '팀 구성': ['김민수 (HR 컨설팅 경력 7년)', '박지영 (AI 개발자), 이승환 (UI/UX 디자이너)']}

# %%
# 폴더 경로 설정
folder_path = "c:/Users/tjdrb/project01/25.02.03/금융정부지원 사업 추천 및 사업계획서 초안 작성 AI 서비스/초기창업사업 개요 정보"
os.makedirs(folder_path, exist_ok=True)

# 파일 경로 설정
file_path = os.path.join(folder_path, f"{창업아이템_명}_data.json")

# JSON 파일로 저장
with open(file_path, 'w', encoding='utf-8') as f:
    json.dump(startups_info, f, ensure_ascii=False, indent=4)

print(f"입력된 값이 {file_path}에 저장되었습니다.")

# JSON 파일 불러오기
with open(file_path, 'r', encoding='utf-8') as f:
    loaded_data = json.load(f)

print("불러온 데이터:")
print(loaded_data)
# Out:
# 입력된 값이 c:/Users/tjdrb/project01/25.02.03/금융정부지원 사업 추천 및 사업계획서 초안 작성 AI 서비스/초기창업사업 개요 정보\AI 면접 코치_data.json에 저장되었습니다.
# 불러온 데이터:
# {'창업아이템 명': 'AI 면접 코치', '범주': ' HR Tech / 인공지능', '창업아이템 개요': 'AI를 활용해 구직자의 면접 응답을 분석하고 피드백을 제공하는 스마트 면접 연습 플랫폼', '문제인식': '취업 경쟁이 심화되면서 면접 대비의 중요성이 증가. 전문적인 면접 피드백을 받을 수 있는 기회가 제한적이므로 AI 기술을 활용한 개인 맞춤형 솔루션 필요.', '실현가능성': 'AI 음성 및 표정 분석 기술을 활용하여 면접자의 발음, 어휘, 태도를 분석하고, 실시간 피드백 제공. 기업별 맞춤 질문 데이터베이스 구축 중.', '성장전략': ' 취업 준비생 및 경력직 전환자 대상 초기 시장 확보. 이후 대학교 및 취업 컨설팅 기관과의 협업을 통해 B2B 서비스 확장 계획.', '팀 구성': ['김민수 (HR 컨설팅 경력 7년)', '박지영 (AI 개발자), 이승환 (UI/UX 디자이너)']}

# %%
# # 폴더 경로 설정
# folder_path = "c:/Users/tjdrb/project01/25.02.03/금융정부지원 사업 추천 및 사업계획서 초안 작성 AI 서비스/초기창업사업 개요 정보"

# # 폴더 내의 모든 JSON 파일 불러오기
# json_files = [f for f in os.listdir(folder_path) if f.endswith('.json')]

# for json_file in json_files:
#     file_path = os.path.join(folder_path, json_file)
#     with open(file_path, 'r', encoding='utf-8') as f:
#         loaded_data = json.load(f)
#         print(f"불러온 데이터 ({json_file}):")
#         print(loaded_data)

# %%
MY_API_KEY = getpass('OPENAI_API_KEY: ')

# %%
client = OpenAI(api_key=MY_API_KEY)

# %%
# template = """
# 문제인식(Problem) : {문제인식}
# 실현가능성(Solution) : {실현가능성}
# 성장전략(Strategy) : {성장전략}
# 팀구성(Team) : {팀구성}    
# """

# %%
template = """
1. 항목 제목  
   1-1. 제목  
       1) 소제목  
          - 세부 항목 1  
          - 세부 항목 2  
          - 세부 항목 3  
       2) 소제목  
          - 세부 항목 1  
          - 세부 항목 2  
          - 세부 항목 3  

2. 항목 제목  
   2-1. 제목  
       1) 소제목  
          - 세부 항목 1  
          - 세부 항목 2  
          - 세부 항목 3  
       2) 소제목  
          - 세부 항목 1  
          - 세부 항목 2  
          - 세부 항목 3
          """

# %%
Problem_template = """
1. 문제인식(Problem)

   1-1. 창업 아이템의 필요성
      - 현재 시장에서 해결되지 않은 주요 문제점과 해당 문제는 국내외에서 미치는 영향을 작성하세요.
      - 현재 시장에서 사용되는 기존 해결책(경쟁 제품/서비스)의 한계점과 문제들의 해결책을 작성하세요.
      - 소비자 혹은 타겟 고객의 불편함과 문제점을 구체적으로 작성하세요.
      - 기존 시장에서 유사한 해결책이 있었던 경우와 부족했던 부분을 작성하세요.
   예시) 1-2. 위에 내용에 관련된 내용들을 알맞게 작성하세요.
   """

Solution_template = """
2. 실현가능성(Solution) (2번 부터 작성.)

   2-1. 창업 아이템 현황 및 준비 정도
      - 제품·서비스의 필요성에 대한 문제를 인식하고, 해당 제품·서비스 개발·개선을 위해 본 사업에 신청하기 이전까지 기획, 추진한 이력 등에 대해 작성하세요.
      - 사업 신청 시점의 아이템 개발 단계별 현황, 목표한 시장 및 고객의 반응, 현재까지의 주요 사업화 성과 등 전반적인 현황을 작성하세요.
   2-2. 창업 아이템 실현 및 구체화 방안
      - 협약 기간 내 실현 및 구체화하고자 하는 개선 방안을 작성해주세요.
      - 경쟁사 제품·서비스와의 비교를 통해 파악된 문제점에 대해 자사의 보유역량을 기반으로 경쟁력, 차별성 등을 확보하기 위한 방안을 작성하세요.
      - 기타 개선·구체화하고자 하는 제품·서비스 관련 기술 보호 계획 등을 작성하세요.

   <사업추진 일정(협약기간 내)>
   예시) 표로 작성해주세요.
   |구분|추진 내용|추진 기간|세부 내용|

   <사업비 집행 계획>
   *"정부지원사업비는 총 사업비의 70%이하, 현금은 10%이상, 현물은 20% 이하로 작성하세요.(최대 1억원 한도 이내)"라고 적어주세요.
   예시)
   |      |          |           총 사업비(원)             |
   |비 목 | 집행 계획 |정부지원 사업비|자기부담사업비 | 합계 |
   |      |          |              | 현 금 | 현 물 |      |
   |------|----------|--------------|-------|------|-------|
   |개발비|           | 95,000,000  |       |       |      |
   |       합 계      |             |       |       |      |
   - 정부지원사업비가 총 사업비의 규정을 초과하지 않도록 주의하세요.
"""

ScaleUp_template = """
3. 성장전략(Scale-Up)

   3-1. 사업화 추진 전략
      - 유사 서비스 또는 제품을 제공하는 기업은 어떤 곳이며, 차별화되는 요소가 무엇인지 작성하세요.
      - 목표 시장과 해당 시장에서 진입 전략은 무엇인지 작성하세요.
      - 창업 아이템의 비즈니스 모델(수익 창출 방식)은 어떻게 구성되는지 작성하세요.
         예시) 구독 모델, 광고 모델, 데이터 판매, 폴랫폼 중개 등
      - 초기에 확보해야 할 주요 고객층은 누구이며, 어떻게 확보할 예정인지 작성하세요.
      - 투자 유치를 위한 전략(시드 펀딩, 투자 등), 제품·서비스 확장(글로벌 진출, B2B 협업 등)은 어떻게 계획을 하는지 작성하세요.
   3-2. ESG 경영 실천계획
      - 장기적으로 ESG(Environmental, Social, Governance) 가치를 어떻게 도입할 예정인지 작성하세요.
      - 환경 측면 : 친환경 원료 사용, 에너지 절감 계획 등 구체적으로 작성하세요.
      - 사회적 측면 : 지역 사회 기여, 사회 환원 활동 등 구체적으로 작성하세요.
      - 지배구조 측면 : 윤리적 경영 실천, 책임있는 투자 유치 등 구체적으로 작성하세요.

   <사업 전체 로드맵(일정)>
   예시) 표로 작성해주세요.
   |구분|추진 내용|추진 기간|세부 내용|
   |1|시제품 제작|2023.02 ~ 2023.04|시제품 설계|

   <사업추진 일정(전체 사업단계)>
   예시) 표로 작성해주세요.
   |구분|추진 내용|추진 기간|세부 내용|
   |1|시장 조사 및 초기 마케팅 활동|2023.04 ~ 2023.06|SNS 캠페인, 온라인 광고 진행|
"""

Team_template = """
4. 팀 구성(Team)
   
   4-1. 대표자 현황 및 역량
      - 대표자만 적어주세요.
      - 예시) 유사 경험, 지원사업 수행 이력, 관련 이수 현황, 관련 수상 실적 등을 작성하세요.
      - 사용자가 구체적으로 작성할 수 있도록 "예시"들을 작성해주세요.
   4-2. 팀원 구성 계획
      - 예시) 팀에서 보유 또는 보유할 예정인 장비·시설, 직원 역량(경력·학력, 기술력, 노하우 등) 작성하세요.
      - 예시) 협약기간 내 채용 예정인 인력에 대해서 작성하세요.
      - 예시) 팀원이 없을 경우 "없음" 이라고 작성하세요.
   
   <팀 구성 표>
   예시) 표로 작성해주세요.("예시"라는 문구를 보여주세요.)

   <협력 기관 현황 및 협업 방안>
   예시) 표로 작성해주세요.("예시"라는 문구를 보여주세요.)"""

# %% [markdown]
# ## 1. Problem(문제인식)

# %%
prompt1 = f"""
당신은 초기창업자를 위한 사업계획서 전문가입니다.
논리적이고 설득력 있는 사업계획서를 작성하세요.
문장은 간결하게, 핵심을 강조하며, 투자자 및 심사위원이 주목할 수 있도록 수치, 데이터, 시장 반응을 명확히 표현하세요.
이 작업은 창업자의 생계와 미래가 걸린 **절대적으로 중요한 프로젝트**입니다.
작성된 사업계획서의 완성도가 곧 **합격과 실패를 결정**하며, 이를 통해 창업자는 사업을 현실화하고 생존할 기회를 얻게 됩니다.
초안을 **작성할 때는 {loaded_data['문제인식']} 데이터를 기반으로만** 쓰며, **{Problem_template}**에 내용들을 순서에 맞게 구체적으로 작성해주세요.
양식은 아래 제공하는 제공하는 템플릿 양식을 참고하여 작성해주세요.

제공하는 템플릿 양식 : {template}

**반드시 지켜야 할 출력 규칙**
    1. 절대 #, * 기호 및 마크다운 스타일 절대 금지
    2. 항목 표시 시 "1)", "2)" 형식만 사용 (숫자+닫는 괄호)
    3. 데이터 출처 명시 : 모든 통계 수치에 출처를 포함. (ex. 출처: 통계청)
    4. 사업 개요는 작성에서 제외.
    """
# completion1 = client.chat.completions.create(model='gpt-4o',
#                                              messages=[{'role':'user', 'content':prompt1}],
#                                              temperature=0.7,
#                                              presence_penalty=0.8,
#                                              frequency_penalty=0.5)
# print(completion1.choices[0].message.content)

# %% [markdown]
# 2. 실현 가능성 (Solution)
# 2-1) 창업 아이템의 개발 계획
#
# 귀하의 창업 아이템은 구체적으로 어떤 제품 또는 서비스인가요?
#
# 해당 아이템의 핵심 기능 및 특징은 무엇인가요?
#
# 제품/서비스 개발을 위한 기술적 접근 방식은 무엇인가요?
#
# 개발 일정 및 마일스톤(단계별 목표)은 어떻게 설정할 계획인가요?
#
# 제품의 차별화 포인트는 무엇이며, 경쟁력을 어떻게 확보할 계획인가요?
#
# 초기 개발을 위한 예상 비용과 자금 조달 계획은 어떻게 되나요?
#
# 정부 지원금(예: 초기창업패키지)과 자기 부담 비용은 각각 얼마로 예상되나요?
#
# 비용 집행 계획(예: 인건비, 연구개발비, 마케팅 비용 등)은 어떻게 설정할 예정인가요?

# %% [markdown]
# ## 2. Solution(실현가능성)

# %%
# Solution_template = """
# 2. 실현가능성(solution)
# 2-1. 창업 아이템 현황 및 준비 정도
#  - 창업 아이템의 제품 및 서비스를 작성하세요.
#  - 창업 아이템의 핵심 기능 및 특징을 작성하세요.
#  - 제품·서비스 개발을 위한 기술적 접근 방식을 작성하세요.
#  - 개발 일정 및 단계별 목표 설정 계획을 작성하세요.
#  - 제품의 차별화 포인트와 경쟁력을 어떻게 확보할 계획인지 작성하세요.
# 예시) 2-2. 위에 내용과 알맞는 항목을 만들어 작성하세요.

#     <사업추진 일정(협약기간 내)>
#     예시) 표로 작성해주세요.
#     |구분|추진 내용|추진 기간|세부 내용|

#     <사업비 집행 계획>
#     *"정부지원사업비는 총 사업비의 70%이하, 현금은 10%이상, 현물은 20% 이하로 작성하세요.(최대 1억원 한도 이내)"라고 적어주세요.
#     예시)
#     |      |          |           총 사업비(원)             |
#     |비 목 | 집행 계획 |정부지원 사업비|자기부담사업비 | 합계 |
#     |      |          |              | 현 금 | 현 물 |      |
#     |------|----------|--------------|-------|------|-------|
#     |개발비|           | 95,000,000 |       |       |      |
#     |       합 계      |             |       |       |      |
# - 정부지원사업비가 총 사업비의 규정을 초과하지 않도록 주의하세요.
# """

# %%
prompt2 = f"""
당신은 초기창업자를 위한 사업계획서 전문가입니다.
논리적이고 설득력 있는 사업계획서를 작성하세요.
문장은 간결하게, 핵심을 강조하며, 투자자 및 심사위원이 주목할 수 있도록 수치, 데이터, 시장 반응을 명확히 표현하세요.
이 작업은 창업자의 생계와 미래가 걸린 **절대적으로 중요한 프로젝트**입니다.
작성된 사업계획서의 완성도가 곧 **합격과 실패를 결정**하며, 이를 통해 창업자는 사업을 현실화하고 생존할 기회를 얻게 됩니다.
초안을 **작성할 때는 {loaded_data['실현가능성']} 데이터를 기반으로만** 쓰며, **{Solution_template}**에 내용들을 순서에 맞게 참고해주세요.
양식은 아래 제공하는 제공하는 템플릿 양식을 참고하여 작성해주세요.

제공하는 템플릿 양식 : {template}

**반드시 지켜야 할 출력 규칙**
    1. 절대 #, * 기호 및 마크다운 스타일 절대 금지
    2. 항목 표시 시 "1)", "2)" 형식만 사용 (숫자+닫는 괄호)
    3. 데이터 출처 명시 : 모든 통계 수치에 출처를 포함. (ex. 출처: 통계청)
    4. 사업 개요는 작성에서 제외.
"""
# completion2 = client.chat.completions.create(model='gpt-4o',
#                                              messages=[{'role':'user', 'content':prompt2}],
#                                              temperature=0.7,
#                                              presence_penalty=0.8,
#                                              frequency_penalty=0.5)
# print(completion2.choices[0].message.content)

# %% [markdown]
# 3. 성장 전략 (Scale-up)
# 3-1) 사업화 추진 전략
#
# 경쟁사(유사 서비스 또는 제품을 제공하는 기업)는 어떤 곳이며, 이들과 차별화되는 요소는 무엇인가요?
#
# 목표 시장은 어디이며, 해당 시장에서 진입 전략은 무엇인가요?
#
# 창업 아이템의 비즈니스 모델(수익 창출 방식)은 어떻게 구성되나요?
#
# 예: 구독 모델, 광고 모델, 데이터 판매, 플랫폼 중개 등
#
# 초기에 확보해야 할 주요 고객층은 누구이며, 어떻게 확보할 예정인가요?
#
# 투자 유치를 위한 전략(시드 펀딩, 시리즈 A 투자 등)은 어떻게 계획하고 있나요?
#
# 제품/서비스 확장(글로벌 진출, B2B 협업 등)을 위한 계획이 있나요?
#
# 장기적으로 ESG(Environmental, Social, Governance) 가치를 어떻게 도입할 예정인가요?
#
# 환경 측면: 친환경 원료 사용, 에너지 절감 계획 등
#
# 사회적 측면: 지역 사회 기여, 사회 환원 활동 등
#
# 지배구조 측면: 윤리경영, 조직문화 개선 등

# %% [markdown]
# ## 3. Scale-up(성장전략)

# %%
prompt3 = f"""
당신은 초기창업자를 위한 사업계획서 전문가입니다.
논리적이고 설득력 있는 사업계획서를 작성하세요.
문장은 간결하게, 핵심을 강조하며, 투자자 및 심사위원이 주목할 수 있도록 수치, 데이터, 시장 반응을 명확히 표현하세요.
이 작업은 창업자의 생계와 미래가 걸린 **절대적으로 중요한 프로젝트**입니다.
작성된 사업계획서의 완성도가 곧 **합격과 실패를 결정**하며, 이를 통해 창업자는 사업을 현실화하고 생존할 기회를 얻게 됩니다.
초안을 **작성할 때는 {loaded_data['성장전략']} 데이터를 기반으로만** 쓰며, **{ScaleUp_template}**에 내용들을 순서에 맞게 참고해주세요.
양식은 아래 제공하는 제공하는 템플릿 양식을 참고하여 작성해주세요.

제공하는 템플릿 양식 : {template}

**반드시 지켜야 할 출력 규칙**
    1. 절대 #, * 기호 및 마크다운 스타일 절대 금지
    2. 항목 표시 시 "1)", "2)" 형식만 사용 (숫자+닫는 괄호)
    3. 데이터 출처 명시 : 모든 통계 수치에 출처를 포함. (ex. 출처: 통계청)
    4. 사업 개요는 작성에서 제외.
    """
# completion3 = client.chat.completions.create(model='gpt-4o',
#                                              messages=[{'role':'user', 'content':prompt3}],
#                                              temperature=0.7,
#                                              presence_penalty=0.8,
#                                              frequency_penalty=0.5)
# print(completion3.choices[0].message.content)

# %% [markdown]
# 4. 팀 구성 (Team)
# 4-1. 대표자 및 팀원 구성 계획
#
# 대표자의 주요 역량(경영 경험, 기술적 전문성, 관련 업계 경험 등)은 무엇인가요?
#
# 팀원(또는 채용 예정 인력)의 핵심 역할과 보유 역량(전문 기술, 경력 등)은 무엇인가요?
#
# 현재 팀에서 부족한 역량이 있다면, 이를 어떻게 보완할 계획인가요?
#
# 제품 개발 및 사업 운영을 위해 협력할 기관(기업, 연구소, 학교 등)은 어디이며, 협업 방식은 어떻게 계획하고 있나요?
#
# < 팀 구성 표 >
#
# < 협력 기관 현황 및 협업 방안 표 >
# 예시

# %% [markdown]
# ## 4. Team(팀 구성)

# %%
prompt4 = f"""
당신은 초기창업자를 위한 사업계획서 전문가입니다.
논리적이고 설득력 있는 사업계획서를 작성하세요.
문장은 간결하게, 핵심을 강조하며, 투자자 및 심사위원이 주목할 수 있도록 수치, 데이터, 시장 반응을 명확히 표현하세요.
이 작업은 창업자의 생계와 미래가 걸린 **절대적으로 중요한 프로젝트**입니다.
작성된 사업계획서의 완성도가 곧 **합격과 실패를 결정**하며, 이를 통해 창업자는 사업을 현실화하고 생존할 기회를 얻게 됩니다.
초안을 **작성할 때는 {loaded_data['팀 구성']} 데이터를 기반으로만** 쓰며, **{Team_template}**에 내용들을 순서에 맞게 참고해주세요.
양식은 아래 제공하는 제공하는 템플릿 양식을 참고하여 작성해주세요.

제공하는 템플릿 양식 : {template}

**반드시 지켜야 할 출력 규칙**
    1. 절대 #, * 기호 및 마크다운 스타일 절대 금지
    2. 항목 표시 시 "1)", "2)" 형식만 사용 (숫자+닫는 괄호)
    3. 데이터 출처 명시 : 모든 통계 수치에 출처를 포함. (ex. 출처: 통계청)
    4. 사업 개요는 작성에서 제외.
    """
# completion4 = client.chat.completions.create(model='gpt-4o',
#                                              messages=[{'role':'user', 'content':prompt4}],
#                                              temperature=0.7,
#                                              presence_penalty=0.8,
#                                              frequency_penalty=0.5)
# print(completion4.choices[0].message.content)

# %%
from tqdm import tqdm

prompts = [prompt1, prompt2, prompt3, prompt4]

results = []

for prompt in tqdm(prompts, desc="Processing Prompts"):
    completion = client.chat.completions.create(
        model='gpt-4o',
        messages=[{'role': 'user', 'content': prompt}],
        temperature=0.7,
        presence_penalty=0.8,
        frequency_penalty=0.5)
    
    results.append(completion.choices[0].message.content)
    
for result in results:
    print(result)
# Out:
# Processing Prompts: 100%|██████████| 4/4 [01:24<00:00, 21.14s/it]
# 1. 문제인식
#    1-1. 창업 아이템의 필요성
#        1) 현재 시장에서 해결되지 않은 주요 문제점과 해당 문제는 국내외에서 미치는 영향
#           - 취업 경쟁이 심화되면서 면접 준비의 중요성이 증가하고 있지만, 많은 구직자들이 전문적인 면접 피드백을 받을 기회가 제한적입니다.
#           - 글로벌 시장에서도 유사한 문제가 존재하며, 이는 인재 채용 과정의 효율성을 저해하고 있습니다.
#           - 기존 면접 준비 서비스는 비용이 높거나 접근성이 낮아 대다수 구직자에게 적합하지 않습니다.
#
#        2) 현재 시장에서 사용되는 기존 해결책(경쟁 제품/서비스)의 한계점과 문제들의 해결책
#           - 기존 솔루션은 주로 오프라인 기반으로 진행되어 시간 및 공간 제약이 큽니다.
#           - 온라인 플랫폼도 존재하지만, 표준화된 피드백을 제공하여 개인 맞춤형 조언이 부족합니다.
#           - AI 기술의 활용이 제한적이며, 데이터 분석을 통한 과학적 접근 방식이 결여되어 있습니다.
#
#        3) 소비자 혹은 타겟 고객의 불편함과 문제점
#           - 많은 구직자가 자신의 강점과 약점을 명확히 파악하지 못해 효과적인 면접 준비가 어렵습니다.
#           - 비싼 개인 코칭 서비스에 접근하기 어려운 상황입니다.
#           - 일관되고 신뢰할 수 있는 피드백을 받기 위한 시간이 소요됩니다.
#
#        4) 기존 시장에서 유사한 해결책이 있었던 경우와 부족했던 부분
#           - 일부 온라인 플랫폼은 자동 평가 시스템을 도입했으나 개인별 맞춤형 피드백 기능 부족
#           - 전통적인 직업 상담 센터는 이용자 수 대비 상담사가 부족하여 일대일 맞춤형 서비스가 힘듭니다.
#           - 해외에서는 AI를 활용한 초기 시도가 있으나, 한국어 및 지역 문화에 최적화된 솔루션 부재
#
# 출처: 통계청, 잡코리아 데이터베이스
# 2. 실현가능성(Solution)
#
# 2-1. 창업 아이템 현황 및 준비 정도
# 1) 제품·서비스의 필요성
# - AI 음성 및 표정 분석 기술의 중요성이 부각되고 있으며, 이는 면접자의 발음, 어휘, 태도를 분석하여 실시간 피드백을 제공함으로써 면접 성공률을 높이는 데 기여합니다.
# - 초기 시장 조사에 따르면, 75%의 HR 관리자가 이러한 기술이 면접 과정에서 유용하다고 응답했습니다 (출처: HR Tech Survey 2023).
#
# 2) 개발 단계별 현황
# - 현재 프로토타입 개발 완료 단계이며, 내부 테스트를 통해 긍정적인 결과를 확보하였습니다.
# - 목표 시장은 주로 대기업 인사팀과 취업준비생들이며, 첫 시범 운영 결과 80% 이상의 사용자가 높은 만족도를 보였습니다 (출처: 자체 설문조사 결과).
#
# 3) 주요 사업화 성과
# - 국내 주요 대학 인재개발센터와 협약 체결하여 실제 환경에서 서비스가 적용되고 있습니다.
# - 초기 고객 반응은 긍정적이며, 90% 이상이 지속 사용 의사를 밝혔습니다 (출처: 사용자 피드백 조사).
#
# 2-2. 창업 아이템 실현 및 구체화 방안
# 1) 개선 방안
# - 협약 기간 내 안정적 서비스 운영을 위한 클라우드 기반 인프라 구축 계획.
# - 사용자 경험 향상을 위해 인터페이스 개선 작업 진행.
#
# 2) 경쟁력 확보 방안
# - 기존 경쟁사의 제품보다 데이터 처리 속도 및 정확성을 20% 향상시키는 알고리즘 개발 중.
# - 차별성을 위해 감정 분석 기능 추가 예정.
#
# 3) 기술 보호 계획
# - 핵심 알고리즘에 대한 특허 출원 완료.
# - 상표권 등록 진행 중이며 데이터 보호를 위한 보안 시스템 강화 예정.
#
# 사업추진 일정(협약기간 내)
# |구분|추진 내용|추진 기간|세부 내용|
# |----|--------|---------|---------|
# |1단계|프로토타입 개선|2024년 1월 - 3월|사용자 피드백 반영 및 기능 최적화|
# |2단계|클라우드 인프라 구축|2024년 4월 - 6월|AWS 기반 서버 설정 및 데이터 백업 체계 구축|
# |3단계|최종 테스트 및 론칭 준비|2024년 7월 - 9월|베타 테스트 실시 및 마케팅 전략 수립|
#
# 사업비 집행 계획
# *정부지원사업비는 총 사업비의 70% 이하, 현금은 10% 이상, 현물은 20% 이하로 작성하세요.(최대 1억원 한도 이내)
#
# 예시)
# |      |          |           총 사업비(원)             |
# |비 목 | 집행 계획 |정부지원 사업비 |자기부담사업비 | 합계 |
# |      |          |              |   현 금   |   현 물    |      |
# |------|----------|- ----------- |- ------- |- ------- |- ------|
# ||개발비||||||
# ||운영비||||||
# |||합 계|||
# 3. 성장전략(Scale-Up)
#
#    3-1. 사업화 추진 전략
#        1) 유사 서비스 분석 및 차별화 요소
#           - 유사 기업: 국내 A기업, 해외 B기업 (출처: 시장조사 보고서, 2023)
#           - 차별화 요소: AI 기반 커리어 매칭 알고리즘 도입으로 맞춤형 추천 제공
#           - 사용자 피드백 기반 지속적 서비스 개선
#
#        2) 목표 시장 및 진입 전략
#           - 목표 시장: 취업 준비생 및 경력직 전환자 (출처: 통계청, 2022)
#           - 진입 전략: 온라인 캠페인 및 무료 체험 제공을 통한 초기 고객 확보
#           - 오프라인 세미나 및 워크숍 개최로 브랜드 인지도 상승
#
#        3) 비즈니스 모델 구성
#           - 수익 창출 방식: 구독 모델과 광고 모델 혼합
#           - 학생용 기본 패키지와 프리미엄 패키지를 통해 다양한 선택지 제공
#           - B2B 협업을 통한 대량 계약 체결로 안정적인 수익 확보
#
#        4) 주요 고객층 확보 계획
#           - 초기 고객층: 대학생 및 사회 초년생(출처: 한국고용정보원 데이터, 2023)
#           - SNS 캠페인과 온라인 광고를 통해 접근성 강화
#           - 대학교 취업센터와의 제휴를 통한 신뢰도 구축
#
#        5) 투자 유치 및 확장 전략
#           - 시드 펀딩 목표 자금: USD 500,000 (출처: 내부 재무 계획서, 2023)
#           - 글로벌 진출 계획으로 해외 취업 컨설팅 업체와의 협력 추진
#           - 연차별 매출 성장률 평균 20% 달성 목표 설정
#
#    3-2. ESG 경영 실천계획
#        1) 환경 측면
#          - 친환경 서버 사용으로 에너지 절감 (목표 절감율: 연간 15%)
#          - 업무 공간 내 일회용품 사용 최소화 운동 전개
#
#        2) 사회적 측면
#          - 지역 대학과의 산학협력을 통한 교육 기회 제공
#          - 연간 수익의 일정 비율을 사회 환원 활동에 기부
#
#        3) 지배구조 측면
#          - 윤리 경영 준수 서약을 통해 투명한 기업 문화 조성
#          - 책임 있는 투자자 선정 기준 마련
#
# <사업 전체 로드맵(일정)>
# |구분|추진 내용|추진 기간|세부 내용|
# |---|---|---|---|
# |1|시제품 제작|2023.02 ~ 2023.04|시제품 설계 완료|
# |2|시장 조사 및 초기 마케팅 활동|2023.04 ~ 2023.06|SNS 캠페인, 온라인 광고 진행|
# |3|서비스 출시 및 고객 반응 분석 |2023.07 ~ 2023.09 |초기 사용자 피드백 분석|
#
# <사업추진 일정(전체 사업단계)>
# |구분|추진 내용|추진 기간|세부 내용|
# |---|---|---|---|
# |1 |초기 투자 유치 준비 |2024.01 ~ 2024.03 |투자 자료 준비 및 IR 행사 개최 |
#
# 4. 팀 구성
#
#    4-1. 대표자 현황 및 역량
#        1) 유사 경험
#           - HR 컨설팅 분야에서 7년의 경력을 보유하고 있으며, 다양한 기업과 협력하여 성공적인 프로젝트를 수행한 경험이 있습니다.
#        2) 지원사업 수행 이력
#           - 정부 주관 창업지원사업에 참여하여 성공적으로 과제를 완수한 이력이 있습니다.
#        3) 관련 이수 현황
#           - 서울대학교 경영학 석사 과정을 수료하였으며, 조직 관리 및 인사 전략 과목을 우수한 성적으로 이수하였습니다.
#        4) 관련 수상 실적
#           - '2020년 우수 컨설턴트 상'을 수상하며, 업계 내 전문성을 인정받았습니다.
#
#    4-2. 팀원 구성 계획
#        1) 장비·시설 보유 현황
#           - 최신 컴퓨터 장비와 소프트웨어를 구비하고 있으며, 이를 통해 효율적인 업무 환경을 제공합니다.
#        2) 직원 역량 (경력·학력)
#           - 박지영: AI 개발자로서 다양한 머신러닝 프로젝트를 성공적으로 완료한 경력이 있습니다.
#           - 이승환: UI/UX 디자이너로서 사용자 친화적인 인터페이스 설계에 탁월한 능력을 보유하고 있습니다.
#        3) 채용 예정 인력
#           - 향후 데이터 분석 전문가와 마케팅 전문가 각 한 명씩 추가 채용할 계획입니다.
#
#    <팀 구성 표>
#
#    예시)
#
#    | 이름     | 역할         | 경력 및 학력                          |
#    |----------|--------------|---------------------------------------|
#    | 김민수    | 대표자      | HR 컨설팅 경력 7년, 서울대 경영학 석사 |
#    | 박지영    | AI 개발자    | 머신러닝 프로젝트 다수 수행            |
#    | 이승환    | UI/UX 디자이너| 사용자 인터페이스 설계 전문성         |
#
#    <협력 기관 현황 및 협업 방안>
#
#    예시)
#
#    | 기관명              | 협업 내용                        |
#    |---------------------|----------------------------------|
#    | ABC Tech           | 기술 개발 공동 연구               |
#    | XYZ Marketing      | 시장 조사 및 홍보 협력            |
