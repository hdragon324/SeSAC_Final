# %% [markdown]
# # [초기창업패키지]

# %%
import os
import json
from getpass import getpass
from openai import OpenAI

# %%
창업아이템_명 = input('창업아이템 명: ')
범주 = input('범주: ')
창업아이템_개요 = input('창업아이템 개요: ')
문제인식 = input('문제인식: ')
실현가능성 = input('실현가능성: ')
성장전략 = input('성장전략: ')
팀_구성1 = input('대표자: ')
팀_구성2 = input('팀원: ')

# %%
startups_info = {
    '창업아이템 명' : 창업아이템_명,
    '범주' : 범주,
    '창업아이템 개요' : 창업아이템_개요,
    '문제인식' : 문제인식,
    '실현가능성' : 실현가능성,
    '성장전략' : 성장전략,
    '팀 구성' : [팀_구성1, 팀_구성2]
}

startups_info = {k: v for k, v in startups_info.items() if v}
startups_info
# Out:
# {'창업아이템 명': 'Sell Farm(셀팜)',
#  '범주': '데이터 분석 어플리케이션',
#  '창업아이템 개요': "'셀팜'은 농산물 온라인 판매자가 가격 측정, 판매전략 구축 시간을 1시간에서 1분으로 단축할 수 있도록 도와주는 판매 데이터 분석 서비스입니다. 주기능은 다음 두가지입니다. 1) 온라인 판매 데이터에 기반하여, 가격 책정을 위한 평균가 및 가격 추이를 검색 한번으로 확인 가능하게 함. 2) 판매 중인 상품의 URL을 입력하면 수치화된 분석 및 구체적인 액션 아이템을 제시하여 데이터를 기반으로 다음 전략을 쉽게 수립할 수 있도록 함.",
#  '문제인식': '1) 기획 배경  - 농산물 유통 시장의 구조적 문제점으로 생산자와 소비자가 모두 피해를 받고 있는 상황에서 농산물 위탁판매자의 필요성이 대두되고 있으며, 위탁판매자의 판매 시작 진입장벽을 낮추어 규모의 경제와 경쟁을 통한 건전한 시장 형성이 필요하다고 인식됩니다. 2) 고객 니즈 및 서비스 목적 - 타깃 고객(농산물 온라인 판매자)는 현재 비효율적인 가격 책정 과정, 판매전략과 노하우를 수립하기 위해 필요 이상의 많은 시간을 소모하고 있으며 이는 상품의 특성과 판매 시기 등 고려해야할 것이 많은 농산물 판맨의 특성에서 비롯됩니다. - 본 서비스는이를 해결하기 위해 데이터 기반으로 가격책정과 판매전략에 있어 수치화된 정보 및 전략을 제공하여 농산물 판매 프로세스를 더욱 효율적으로 개선하고자 합니다.',
#  '실현가능성': '1) 2023년 12월부터 문제 정의 및 가설 검증을 위해 농산물 온아인 판매자 대상으로 설문조사, 심층 인터뷰를 2회차 진행, 시장조사를 기반으로 유저 플로우, IA(정보구조도)를 통해 전체적인 기획 완료. 2) 현재는 와이어프레임, 프로토타입, 사용성 테스트를 통해 서비스 가치를 최대한 빠르게 인식할 수 있는 UI/UX를 개선 중. 3) 농산물 온라인 판매 시 효율적인 가격 책정, 시간 단축을 위한 품목별, 판매 단위별 평균가의 추이와 현황을 확인할 수 있는 기능 개발 예정. 4) 본 서비스를 기반으로 취득한 데이터를 통해 독자적으로 가공하여 유의미한 데이터를 고객에게 제공할 예정.',
#  '성장전략': '1) 목표시장  - 셀팜은 20에서 30대 농산물(위탁) 판매자 시장에 집중합니다. \t- 국내 : 20에서 30대 농산물(위탁) 판매자 2) 비즈니스 모델 - 초기 : 부분서비스 유료화를 통해 유료 서비스유저를 유치, 다양한 이커머스 플럇폼의 데이터를 분석하여 서비스 고도화 및 시장 확장 - 중기 : 획득한 유저의 DB를 바탕으로 B2B 서브시로 확장 - 장기 : 해외 플랫폼과 위탁판매자들을 겨냥한 서비스 런칭 3) 경쟁력 및 차별성 - 셀팜은 빅데이터 시반의 액셔너블한 전략 추천 기능으로 농산물 판매자들이 현업에서 필요한 데이터를 기준으로 현 상태를 분석해 주고, 당장 할 수 있는 액션을 제공.',
#  '팀 구성': ['이재호', '없음']}

# %%
# 폴더 경로 설정
folder_path = "c:/Users/tjdrb/project01/25.02.03/금융정부지원 사업 추천 및 사업계획서 초안 작성 AI 서비스/초기창업사업 개요 정보"
os.makedirs(folder_path, exist_ok=True)

# 파일 경로 설정
file_path = os.path.join(folder_path, f"{창업아이템_명}_data.json")

# JSON 파일로 저장
with open(file_path, 'w', encoding='utf-8') as f:
    json.dump(startups_info, f, ensure_ascii=False, indent=4)

print(f"입력된 값이 {file_path}에 저장되었습니다.")

# JSON 파일 불러오기
with open(file_path, 'r', encoding='utf-8') as f:
    loaded_data = json.load(f)

print("불러온 데이터:")
print(loaded_data)
# Out:
# 입력된 값이 c:/Users/tjdrb/project01/25.02.03/금융정부지원 사업 추천 및 사업계획서 초안 작성 AI 서비스/초기창업사업 개요 정보\Sell Farm(셀팜)_data.json에 저장되었습니다.
# 불러온 데이터:
# {'창업아이템 명': 'Sell Farm(셀팜)', '범주': '데이터 분석 어플리케이션', '창업아이템 개요': "'셀팜'은 농산물 온라인 판매자가 가격 측정, 판매전략 구축 시간을 1시간에서 1분으로 단축할 수 있도록 도와주는 판매 데이터 분석 서비스입니다. 주기능은 다음 두가지입니다. 1) 온라인 판매 데이터에 기반하여, 가격 책정을 위한 평균가 및 가격 추이를 검색 한번으로 확인 가능하게 함. 2) 판매 중인 상품의 URL을 입력하면 수치화된 분석 및 구체적인 액션 아이템을 제시하여 데이터를 기반으로 다음 전략을 쉽게 수립할 수 있도록 함.", '문제인식': '1) 기획 배경  - 농산물 유통 시장의 구조적 문제점으로 생산자와 소비자가 모두 피해를 받고 있는 상황에서 농산물 위탁판매자의 필요성이 대두되고 있으며, 위탁판매자의 판매 시작 진입장벽을 낮추어 규모의 경제와 경쟁을 통한 건전한 시장 형성이 필요하다고 인식됩니다. 2) 고객 니즈 및 서비스 목적 - 타깃 고객(농산물 온라인 판매자)는 현재 비효율적인 가격 책정 과정, 판매전략과 노하우를 수립하기 위해 필요 이상의 많은 시간을 소모하고 있으며 이는 상품의 특성과 판매 시기 등 고려해야할 것이 많은 농산물 판맨의 특성에서 비롯됩니다. - 본 서비스는이를 해결하기 위해 데이터 기반으로 가격책정과 판매전략에 있어 수치화된 정보 및 전략을 제공하여 농산물 판매 프로세스를 더욱 효율적으로 개선하고자 합니다.', '실현가능성': '1) 2023년 12월부터 문제 정의 및 가설 검증을 위해 농산물 온아인 판매자 대상으로 설문조사, 심층 인터뷰를 2회차 진행, 시장조사를 기반으로 유저 플로우, IA(정보구조도)를 통해 전체적인 기획 완료. 2) 현재는 와이어프레임, 프로토타입, 사용성 테스트를 통해 서비스 가치를 최대한 빠르게 인식할 수 있는 UI/UX를 개선 중. 3) 농산물 온라인 판매 시 효율적인 가격 책정, 시간 단축을 위한 품목별, 판매 단위별 평균가의 추이와 현황을 확인할 수 있는 기능 개발 예정. 4) 본 서비스를 기반으로 취득한 데이터를 통해 독자적으로 가공하여 유의미한 데이터를 고객에게 제공할 예정.', '성장전략': '1) 목표시장  - 셀팜은 20에서 30대 농산물(위탁) 판매자 시장에 집중합니다. \t- 국내 : 20에서 30대 농산물(위탁) 판매자 2) 비즈니스 모델 - 초기 : 부분서비스 유료화를 통해 유료 서비스유저를 유치, 다양한 이커머스 플럇폼의 데이터를 분석하여 서비스 고도화 및 시장 확장 - 중기 : 획득한 유저의 DB를 바탕으로 B2B 서브시로 확장 - 장기 : 해외 플랫폼과 위탁판매자들을 겨냥한 서비스 런칭 3) 경쟁력 및 차별성 - 셀팜은 빅데이터 시반의 액셔너블한 전략 추천 기능으로 농산물 판매자들이 현업에서 필요한 데이터를 기준으로 현 상태를 분석해 주고, 당장 할 수 있는 액션을 제공.', '팀 구성': ['이재호', '없음']}

# %%
# 폴더 경로 설정
folder_path = "c:/Users/tjdrb/project01/25.02.03/금융정부지원 사업 추천 및 사업계획서 초안 작성 AI 서비스/초기창업사업 개요 정보"

# 폴더 내의 모든 JSON 파일 불러오기
json_files = [f for f in os.listdir(folder_path) if f.endswith('.json')]

for json_file in json_files:
    file_path = os.path.join(folder_path, json_file)
    with open(file_path, 'r', encoding='utf-8') as f:
        loaded_data = json.load(f)
        print(f"불러온 데이터 ({json_file}):")
        print(loaded_data)
# Out:
# 불러온 데이터 (Sell Farm(셀팜)_data.json):
# {'창업아이템 명': 'Sell Farm(셀팜)', '범주': '데이터 분석 어플리케이션', '창업아이템 개요': "'셀팜'은 농산물 온라인 판매자가 가격 측정, 판매전략 구축 시간을 1시간에서 1분으로 단축할 수 있도록 도와주는 판매 데이터 분석 서비스입니다. 주기능은 다음 두가지입니다. 1) 온라인 판매 데이터에 기반하여, 가격 책정을 위한 평균가 및 가격 추이를 검색 한번으로 확인 가능하게 함. 2) 판매 중인 상품의 URL을 입력하면 수치화된 분석 및 구체적인 액션 아이템을 제시하여 데이터를 기반으로 다음 전략을 쉽게 수립할 수 있도록 함.", '문제인식': '1) 기획 배경  - 농산물 유통 시장의 구조적 문제점으로 생산자와 소비자가 모두 피해를 받고 있는 상황에서 농산물 위탁판매자의 필요성이 대두되고 있으며, 위탁판매자의 판매 시작 진입장벽을 낮추어 규모의 경제와 경쟁을 통한 건전한 시장 형성이 필요하다고 인식됩니다. 2) 고객 니즈 및 서비스 목적 - 타깃 고객(농산물 온라인 판매자)는 현재 비효율적인 가격 책정 과정, 판매전략과 노하우를 수립하기 위해 필요 이상의 많은 시간을 소모하고 있으며 이는 상품의 특성과 판매 시기 등 고려해야할 것이 많은 농산물 판맨의 특성에서 비롯됩니다. - 본 서비스는이를 해결하기 위해 데이터 기반으로 가격책정과 판매전략에 있어 수치화된 정보 및 전략을 제공하여 농산물 판매 프로세스를 더욱 효율적으로 개선하고자 합니다.', '실현가능성': '1) 2023년 12월부터 문제 정의 및 가설 검증을 위해 농산물 온아인 판매자 대상으로 설문조사, 심층 인터뷰를 2회차 진행, 시장조사를 기반으로 유저 플로우, IA(정보구조도)를 통해 전체적인 기획 완료. 2) 현재는 와이어프레임, 프로토타입, 사용성 테스트를 통해 서비스 가치를 최대한 빠르게 인식할 수 있는 UI/UX를 개선 중. 3) 농산물 온라인 판매 시 효율적인 가격 책정, 시간 단축을 위한 품목별, 판매 단위별 평균가의 추이와 현황을 확인할 수 있는 기능 개발 예정. 4) 본 서비스를 기반으로 취득한 데이터를 통해 독자적으로 가공하여 유의미한 데이터를 고객에게 제공할 예정.', '성장전략': '1) 목표시장  - 셀팜은 20에서 30대 농산물(위탁) 판매자 시장에 집중합니다. \t- 국내 : 20에서 30대 농산물(위탁) 판매자 2) 비즈니스 모델 - 초기 : 부분서비스 유료화를 통해 유료 서비스유저를 유치, 다양한 이커머스 플럇폼의 데이터를 분석하여 서비스 고도화 및 시장 확장 - 중기 : 획득한 유저의 DB를 바탕으로 B2B 서브시로 확장 - 장기 : 해외 플랫폼과 위탁판매자들을 겨냥한 서비스 런칭 3) 경쟁력 및 차별성 - 셀팜은 빅데이터 시반의 액셔너블한 전략 추천 기능으로 농산물 판매자들이 현업에서 필요한 데이터를 기준으로 현 상태를 분석해 주고, 당장 할 수 있는 액션을 제공.', '팀 구성': ['이재호', '없음']}

# %%
MY_API_KEY = getpass('OPENAI_API_KEY: ')

# %%
client = OpenAI(api_key=MY_API_KEY)

# %%
# template = """
# 문제인식(Problem) : {문제인식}
# 실현가능성(Solution) : {실현가능성}
# 성장전략(Strategy) : {성장전략}
# 팀구성(Team) : {팀구성}    
# """

# %%
template = """
1. 항목 제목
1-1. 제목
    1) 소제목
        -      
        -
        -
    2) 소제목
        -
        -
        -
        
1-2. 제목
    1) 소제목
        -
        -
        -
        
    2) 소제목
        -
        -
        -
        
    3) 소제목
        -
        -
        -
"""

# %% [markdown]
# ## 1. Problem(문제인식)

# %%
Problem_template = """
1. 문제인식(Problem)
1-1. 창업 아이템의 필요성
    - 현재 시장에서 해결되지 않은 주요 문제점과 해당 문제는 국내·외에서 어떤 영향을 미치는지 작성하세요.
    - 현재 시장에서 사용되는 기존 해결책(경쟁 제품/서비스)의 한계점.
    - 창업 아이템이 이러한 문제를 어떻게 해결할 것인지 작성하세요.
    - 소비자 혹은 타겟 고객은 이 문제에 대해 어떤 불편이 있는지 작성하세요.
    - 기존 시장에서 유사한 해결책이 있었던 경우와 어떤 부분에서 부족했는지 작성하세요.
예시) 1-2. 위에 내용과 알맞는 항목을 만들어 작성하세요.
    """

# %%
prompt1 = f"""
당신은 초기창업자를 위한 사업계획서 전문가입니다.
논리적이고 설득력 있는 사업계획서를 작성하세요.
문장은 간결하게, 핵심을 강조하며, 투자자 및 심사위원이 주목할 수 있도록 수치, 데이터, 시장 반응을 명확히 표현하세요.
이 작업은 창업자의 생계와 미래가 걸린 **절대적으로 중요한 프로젝트**입니다.
작성된 사업계획서의 완성도가 곧 **합격과 실패를 결정**하며, 이를 통해 창업자는 사업을 현실화하고 생존할 기회를 얻게 됩니다.
초안을 **작성할 때는 {loaded_data['문제인식']}내용 기반으로만** 쓰며, {Problem_template}에 내용들을 순서에 맞게 참고해주세요.
양식은 아래 제공하는 템플릿 양식을 참고해 작성해주세요.

제공하는 템플릿 양식 : {template}

**반드시 지켜야 할 출력 규칙**
    1. 절대 #, * 기호 및 마크다운 스타일 절대 금지
    2. 항목 표시 시 "1)", "2)" 형식만 사용 (숫자+닫는 괄호)
    3. 데이터 출처 명시 : 모든 통계 수치에 출처를 포함. (ex. 출처: 통계청)
"""
completion1 = client.chat.completions.create(model='gpt-4o',
                                             messages=[{'role':'user', 'content':prompt1}],
                                             temperature=0.7,
                                             presence_penalty=0.8,
                                             frequency_penalty=0.5)
print(completion1.choices[0].message.content)
# Out:
# 1. 문제인식
#
# 1-1. 농산물 유통의 구조적 문제
#     1) 생산자와 소비자의 피해
#         - 현재 농산물 유통 시장은 중간 유통과정에서 발생하는 비효율성으로 인해 생산자는 합당한 가격을 받지 못하고, 소비자는 높은 가격에 구매해야 하는 상황입니다.
#         - 국내 시장뿐만 아니라 국제적으로도 이러한 구조적인 문제는 농업인의 경제적 어려움과 소비자의 부담 증가로 이어지고 있습니다.
#         - 이러한 상황은 지속 가능하지 않으며, 개선되지 않을 경우 시장 전반의 신뢰도 저하를 초래할 수 있습니다.
#
#     2) 기존 해결책의 한계
#         - 기존의 유통 플랫폼들은 주로 대량 거래를 기반으로 하고 있어 소규모 농가에는 적합하지 않습니다.
#         - 판매자에게 필요한 데이터 및 전략 제공이 부족하여 효율적인 가격 책정이 어렵습니다.
#         - 결과적으로 판매와 마케팅에 있어서 많은 시간과 자원이 낭비되고 있습니다.
#
# 1-2. 창업 아이템의 필요성
#     1) 타겟 고객의 불편 사항
#         - 농산물 온라인 판매자들은 비효율적인 가격 책정 과정 때문에 경쟁력을 잃고 있습니다.
#         - 자신의 상품 특성과 시즌별 변동성을 고려한 데이터를 얻기 위해 많은 시간을 할애해야 합니다.
#         - 이는 곧 비용 상승과 매출 감소로 이어져 경영 압박을 가중시킵니다.
#
#     2) 창업 아이템의 해결 방안
#         - 본 서비스는 데이터 기반으로 최적화된 가격 책정과 맞춤형 판매 전략을 제공합니다.
#         - 이를 통해 온라인 판매자가 보다 효율적으로 시장에 대응할 수 있도록 지원합니다.
#         - 차별화된 솔루션을 통해 새로운 경제 규모 형성과 건전한 경쟁 환경 조성에 기여할 것입니다.
#
#     3) 기존 해결책 대비 우위점
#         - 단순히 플랫폼 제공에 그치지 않고, 실시간 시장 데이터 분석 및 맞춤형 전략 제안을 통해 차별화된 서비스를 제공합니다.
#         - 사용자 친화적인 인터페이스로 누구나 쉽게 접근 가능하며, 빠르게 적용할 수 있는 솔루션입니다.
#         - 출처: 통계청, 한국농수산식품유통공사 (2023)

# %% [markdown]
# 2. 실현 가능성 (Solution)
# 2-1) 창업 아이템의 개발 계획
#
# 귀하의 창업 아이템은 구체적으로 어떤 제품 또는 서비스인가요?
#
# 해당 아이템의 핵심 기능 및 특징은 무엇인가요?
#
# 제품/서비스 개발을 위한 기술적 접근 방식은 무엇인가요?
#
# 개발 일정 및 마일스톤(단계별 목표)은 어떻게 설정할 계획인가요?
#
# 제품의 차별화 포인트는 무엇이며, 경쟁력을 어떻게 확보할 계획인가요?
#
# 초기 개발을 위한 예상 비용과 자금 조달 계획은 어떻게 되나요?
#
# 정부 지원금(예: 초기창업패키지)과 자기 부담 비용은 각각 얼마로 예상되나요?
#
# 비용 집행 계획(예: 인건비, 연구개발비, 마케팅 비용 등)은 어떻게 설정할 예정인가요?

# %% [markdown]
# ## 2. Solution(실현가능성)

# %%
Solution_template = """
2. 실현가능성(solution)
2-1. 창업 아이템의 개발 계획
    - 창업 아이템은 구체적으로 어떤 제품 또는 서비스인지 작성하세요.
    - 해당 아이템의 핵심 기능 및 특징을 작성하세요.
    - 제품/서비스 개발을 위한 기술적 접근 방식은 무엇인지 작성하세요.
    - 개발 일정 및 단계별 목표는 어떻게 설정할 계획인지 작성하세요.
    - 제품의 차별화 포인트는 무엇이고, 경쟁력을 어떻게 확보할 계획인지 작성하세요.
예시) 2-2. 위에 내용과 알맞는 항목을 만들어 작성하세요.

<사업추진 일정(협약기간 내)>
예시) 표로 작성해주세요.
|구분|추진 내용|추진 기간|세부 내용|

<사업비 집행 계획>
*"정부지원사업비는 총 사업비의 70%이하, 현금은 10%이상, 현물은 20% 이하로 작성하세요.(최대 1억원 이내)"라고 적어주세요.
예시) 
구분	        항목	금액(천 원)  세부 내역
정부지원사업비	인건비	 ㅇㅇㅇ        ㅇㅇㅇ
            개발비	ㅇㅇㅇ	      ㅇㅇㅇ
자기부담금	    현금	 ㅇㅇㅇ	      ㅇㅇㅇ
            현물	    ㅇㅇㅇ	     ㅇㅇㅇ
총계		            ㅇㅇㅇ	      100	
"""

# %%
prompt2 = f"""
당신은 초기창업자를 위한 사업계획서 전문가입니다.
논리적이고 설득력 있는 사업계획서를 작성하세요.
문장은 간결하게, 핵심을 강조하며, 투자자 및 심사위원이 주목할 수 있도록 수치, 데이터, 시장 반응을 명확히 표현하세요.
이 작업은 창업자의 생계와 미래가 걸린 **절대적으로 중요한 프로젝트**입니다.
작성된 사업계획서의 완성도가 곧 **합격과 실패를 결정**하며, 이를 통해 창업자는 사업을 현실화하고 생존할 기회를 얻게 됩니다.
초안을 **작성할 때는 {loaded_data['실현가능성']}내용 기반으로만** 쓰며, **{Solution_template}**에 내용들을 순서에 맞게 참고해주세요.
양식은 아래 제공하는 템플릿 양식을 참고해 작성해주세요.

제공하는 템플릿 양식 : {template}

**반드시 지켜야 할 출력 규칙**
    1. 절대 #, * 기호 및 마크다운 스타일 절대 금지
    2. 항목 표시 시 "1)", "2)" 형식만 사용 (숫자+닫는 괄호)
    3. 데이터 출처 명시 : 모든 통계 수치에 출처를 포함. (ex. 출처: 통계청)
"""
completion2 = client.chat.completions.create(model='gpt-4o',
                                             messages=[{'role':'user', 'content':prompt2}],
                                             temperature=0.7,
                                             presence_penalty=0.8,
                                             frequency_penalty=0.5)
print(completion2.choices[0].message.content)
# Out:
# 2. 실현가능성(solution)
#
# 2-1. 창업 아이템의 개발 계획
# 1) 제품/서비스 설명
#     - 본 서비스는 농산물 온라인 판매자들을 위한 가격 책정 및 시간 단축 솔루션입니다.
#     - 핵심 기능으로는 품목별, 판매 단위별 평균가 추이 및 현황을 확인할 수 있는 시스템을 제공합니다.
#     - 정보구조도(IA)를 기반으로 설계된 유저 플로우를 통해 사용자가 직관적으로 서비스를 이용할 수 있게 합니다.
#
# 2) 기술적 접근 방식
#     - 데이터 분석 기술과 UI/UX 개선을 위한 최신 웹 개발 도구를 활용합니다.
#     - 와이어프레임과 프로토타입 테스트를 통해 사용성 향상을 지속적으로 모니터링합니다.
#
# 3) 개발 일정 및 목표
#     - 2023년 12월: 문제 정의 및 가설 검증 완료 (출처: 사내 조사)
#     - 2024년 1분기: UI/UX 개선 완료, 초기 베타 버전 출시
#     - 2024년 2분기: 고객 피드백 반영하여 정식 서비스 런칭
#
# 4) 차별화 포인트 및 경쟁력 확보 방안
#     - 독자적인 데이터 가공을 통해 고객에게 유의미한 정보를 제공하며, 시장에서 확실한 차별화를 꾀합니다.
#     - 지속적인 사용자 설문조사와 심층 인터뷰를 바탕으로 고객 요구에 맞춘 기능 업데이트를 진행합니다.
#
# <사업추진 일정(협약기간 내)>
# |구분|추진 내용|추진 기간|세부 내용|
# |---|---|---|---|
# |1차|문제 정의 및 가설 검증|2023년 12월~2024년 1월|농산물 온라인 판매자 대상 설문조사 및 인터뷰|
# |2차|UI/UX 개선 작업|2024년 1월~2024년 3월|와이어프레임 제작, 프로토타입 테스트|
# |3차|베타 버전 출시 및 피드백 수집 |2024년 3월~2024년 6월 |초기 사용자 피드백 반영|
#
# <사업비 집행 계획>
# "정부지원사업비는 총 사업비의 70% 이하, 현금은 10% 이상, 현물은 20% 이하로 작성하세요.(최대 1억원 이내)"
#
# 구분            항목   금액(천 원)   세부 내역
# 정부지원사업비   인건비     ○○○       개발팀 인건비
#                 개발비     ○○○        시스템 구축 비용
# 자기부담금      현금       ○○○        자본 투자금
#                 현물       ○○○        장비 지원
#
# 총계                      ○○○         총 비용 합계(100%)

# %% [markdown]
# 3. 성장 전략 (Scale-up)
# 3-1) 사업화 추진 전략
#
# 경쟁사(유사 서비스 또는 제품을 제공하는 기업)는 어떤 곳이며, 이들과 차별화되는 요소는 무엇인가요?
#
# 목표 시장은 어디이며, 해당 시장에서 진입 전략은 무엇인가요?
#
# 창업 아이템의 비즈니스 모델(수익 창출 방식)은 어떻게 구성되나요?
#
# 예: 구독 모델, 광고 모델, 데이터 판매, 플랫폼 중개 등
#
# 초기에 확보해야 할 주요 고객층은 누구이며, 어떻게 확보할 예정인가요?
#
# 투자 유치를 위한 전략(시드 펀딩, 시리즈 A 투자 등)은 어떻게 계획하고 있나요?
#
# 제품/서비스 확장(글로벌 진출, B2B 협업 등)을 위한 계획이 있나요?
#
# 장기적으로 ESG(Environmental, Social, Governance) 가치를 어떻게 도입할 예정인가요?
#
# 환경 측면: 친환경 원료 사용, 에너지 절감 계획 등
#
# 사회적 측면: 지역 사회 기여, 사회 환원 활동 등
#
# 지배구조 측면: 윤리경영, 조직문화 개선 등

# %% [markdown]
# ## 3. Scale-up(성장전략)

# %%
ScaleUp_template = """
3. 성장전략(Scale-Up)(3번으로 시작.)
3-1. 사업화 추진 전략
    - 유사 서비스 또는 제품을 제공하는 기업은 어떤 곳이며, 차별화되는 요소가 무엇인지 작성하세요.
    - 목표 시장과 해당 시장에서 진입 전략은 무엇인지 작성하세요.
    - 창업 아이템의 비즈니스 모델(수익 창출 방식)은 어떻게 구성되는지 작성하세요.
        예시) 구독 모델, 광고 모델, 데이터 판매, 폴랫폼 중개 등
    - 초기에 확보해야 할 주요 고객층은 누구이며, 어떻게 확보할 예정인지 작성하세요.
    - 투자 유치를 위한 전략(시드 펀딩, 투자 등), 제품·서비스 확장(글로벌 진출, B2B 협업 등)은 어떻게 계획을 하는지 작성하세요.
3-2. ESG 경영 실천계획
    - 장기적으로 ESG(Environmental, Social, Governance) 가치를 어떻게 도입할 예정인지 작성하세요.
    - 환경 측면 : 친환경 원료 사용, 에너지 절감 계획 등
    - 사회적 측면 : 지역 사회 기여, 사회 환원 활동 등
    - 지배구조 측면 : 윤리적 경영 실천, 책임있는 투자 유치 등
예시) 3-3. 위에 내용과 알맞는 항목을 만들어 작성하세요.

<사업 전체 로드맵(일정)>
예시) 표로 작성해주세요.("예시"라는 문구를 보여주세요.)
|구분|추진 내용|추진 기간|세부 내용|
|1|시제품 제작|2023년 2월 - 2023년 4월|시제품 설계|

<사업추진 일정(전체 사업단계)>
예시) 표로 작성해주세요.("예시"라는 문구를 보여주세요.)
|구분|추진 내용|추진 기간|세부 내용|
|1|시장 조사 및 초기 마케팅 활동|2023년 4월 - 2023년 6월|SNS 캠페인, 온라인 광고 진행|
"""

# %%
prompt3 = f"""
당신은 초기창업자를 위한 사업계획서 전문가입니다.
논리적이고 설득력 있는 사업계획서를 작성하세요.
문장은 간결하게, 핵심을 강조하며, 투자자 및 심사위원이 주목할 수 있도록 수치, 데이터, 시장 반응을 명확히 표현하세요.
이 작업은 창업자의 생계와 미래가 걸린 **절대적으로 중요한 프로젝트**입니다.
작성된 사업계획서의 완성도가 곧 **합격과 실패를 결정**하며, 이를 통해 창업자는 사업을 현실화하고 생존할 기회를 얻게 됩니다.
초안을 작성할 때는 **{loaded_data['성장전략']}내용 기반으로만** 쓰며, **{ScaleUp_template}**에 내용들을 순서에 맞게 참고해주세요.
양식은 아래 제공하는 템플릿 양식을 참고해 작성해주세요.

제공하는 템플릿 양식 : {template}

**반드시 지켜야 할 출력 규칙**
    1. 절대 #, * 기호 및 마크다운 스타일 절대 금지
    2. 항목 표시 시 "1)", "2)" 형식만 사용 (숫자+닫는 괄호)
    3. 데이터 출처 명시 : 모든 통계 수치에 출처를 포함. (ex. 출처: 통계청)
"""

completion3 = client.chat.completions.create(model='gpt-4o',
                                             messages=[{'role':'user', 'content':prompt3}],
                                             temperature=0.7,
                                             presence_penalty=0.8,
                                             frequency_penalty=0.5)
print(completion3.choices[0].message.content)
# Out:
# 3. 성장전략(Scale-Up)
#
# 3-1. 사업화 추진 전략
# 1) 경쟁사 분석 및 차별화 요소
# - 국내 유사 서비스: A사, B사 등은 주로 단순 중개 플랫폼을 제공하고 있음.
# - 셀팜은 빅데이터 기반의 액셔너블한 전략 추천 기능이 강점으로, 판매자에게 맞춤형 데이터 분석과 실행 가능한 전략을 제공.
#
# 2) 목표 시장 및 진입 전략
# - 목표 시장: 20~30대 농산물 위탁 판매자 중심으로 설정.
# - 진입 전략: 초기 단계에서 SNS와 온라인 광고를 통해 브랜드 인지도 구축 후, 구독 모델로 전환하여 사용자 유입 증대.
#
# 3) 비즈니스 모델 구성
# - 부분서비스 유료화를 통한 초기 수익 창출.
# - 다양한 이커머스 플랫폼의 데이터를 활용한 서비스 고도화 및 시장 확장 계획.
#
# 4) 주요 고객층 확보 방안
# - 초기에 스타트업 커뮤니티와 협력하여 적극적인 마케팅 진행.
# - 무료 체험 기간 제공으로 초기 사용자 유치 후, 만족도를 기반으로 유료 사용자 전환 촉진.
#
# 5) 투자 유치 및 제품 확장 계획
# - 시드 펀딩을 통해 초기 자금 확보 후, B2B 서브시장을 겨냥한 서비스 확대 계획.
# - 장기적으로 글로벌 시장 진출을 위한 해외 플랫폼과의 제휴 추진.
#
# 3-2. ESG 경영 실천계획
#
# 1) 환경 측면
# - 친환경 서버 운영 시스템 도입을 통한 에너지 절감 목표 설정.
# - 재활용 가능한 소재 사용을 통한 친환경 패키징 개발.
#
# 2) 사회적 측면
# - 지역 농가와 협력하여 상생 모델 구축 및 지역 사회 기여 활동 전개.
# - 연 1회 수익의 일부를 농촌 발전 기금에 기부.
#
# 3) 지배구조 측면
# - 투명한 회계 관리 시스템 도입으로 윤리적 경영 실천.
# - 책임 있는 투자 유치를 위해 ESG 평가 기준 강화.
#
# 예시:
#
# <사업 전체 로드맵(일정)>
#
# |구분|추진 내용|추진 기간|세부 내용|
# |---|---|---|---|
# |1 |시제품 제작 |2023년 2월 - 2023년 4월 |시제품 설계 및 테스트 완료 |
# |2 |시장 조사 및 초기 마케팅 활동 |2023년 4월 - 2023년 6월 |SNS 캠페인, 온라인 광고 진행 |
# |3 |서비스 런칭 |2023년 7월 - 2023년 9월 |초기 사용자 모집 캠페인 실시 |
#
# <사업추진 일정(전체 사업단계)>
#
# |구분|추진 내용|추진 기간|세부 내용|
# |---|---|---|---|
# |1 |시장 조사 및 초기 마케팅 활동 |2023년 4월 - 2023년 6월 |SNS 캠페인, 온라인 광고 진행 |

# %% [markdown]
# 4. 팀 구성 (Team)
# 4-1. 대표자 및 팀원 구성 계획
#
# 대표자의 주요 역량(경영 경험, 기술적 전문성, 관련 업계 경험 등)은 무엇인가요?
#
# 팀원(또는 채용 예정 인력)의 핵심 역할과 보유 역량(전문 기술, 경력 등)은 무엇인가요?
#
# 현재 팀에서 부족한 역량이 있다면, 이를 어떻게 보완할 계획인가요?
#
# 제품 개발 및 사업 운영을 위해 협력할 기관(기업, 연구소, 학교 등)은 어디이며, 협업 방식은 어떻게 계획하고 있나요?
#
# < 팀 구성 표 >
#
# < 협력 기관 현황 및 협업 방안 표 >
# 예시

# %% [markdown]
# ## 4. Team(팀 구성)

# %%
Team_template = """
4. 팀 구성
4-1. 대표자 현황 및 역량
    - 예시) 유사 경험, 지원사업 수행 이력, 관련 이수 현황, 관련 수상 실적 등을 작성하세요.
    - 사용자가 구체적으로 작성할 수 있도록 예시들을 작성해주세요.
4-2. 팀원 구성 계획
    - 예시) 팀에서 보유 또는 보유할 예정인 장비·시설, 직원 역량(경력·학력, 기술력, 노하우 등) 작성하세요.
    - 예시) 협약기간 내 채용 예정인 인력에 대해서 작성하세요.
    - 예시) 팀원이 없을 경우 "없음" 이라고 작성하세요.
 
<팀 구성 표>
예시) 표로 작성해주세요.("예시"라는 문구를 보여주세요.)

<협력 기관 현황 및 협업 방안>
예시) 표로 작성해주세요.("예시"라는 문구를 보여주세요.)
"""

# %%
prompt4 = f"""
당신은 초기창업자를 위한 사업계획서 전문가입니다.
논리적이고 설득력 있는 사업계획서를 작성하세요.
문장은 간결하게, 핵심을 강조하며, 투자자 및 심사위원이 주목할 수 있도록 수치, 데이터, 시장 반응을 명확히 표현하세요.
이 작업은 창업자의 생계와 미래가 걸린 **절대적으로 중요한 프로젝트**입니다.
작성된 사업계획서의 완성도가 곧 **합격과 실패를 결정**하며, 이를 통해 창업자는 사업을 현실화하고 생존할 기회를 얻게 됩니다.
초안을 작성할 때는 **{loaded_data['팀 구성']}내용 기반으로만** 쓰며, **{Team_template}**에 내용들을 순서에 맞게 참고해주세요.
양식은 아래 제공하는 템플릿 양식을 참고해 작성해주세요.

제공하는 템플릿 양식 : {template}

**반드시 지켜야 할 출력 규칙**
    1. 절대 #, * 기호 및 마크다운 스타일 절대 금지
    2. 항목 표시 시 "1)", "2)" 형식만 사용 (숫자+닫는 괄호)
    3. 데이터 출처 명시 : 모든 통계 수치에 출처를 포함. (ex. 출처: 통계청)
"""

completion4 = client.chat.completions.create(model='gpt-4o',
                                             messages=[{'role':'user', 'content':prompt4}],
                                             temperature=0.7,
                                             presence_penalty=0.8,
                                             frequency_penalty=0.5)
print(completion4.choices[0].message.content)
# Out:
# 4. 팀 구성
#
# 4-1. 대표자 현황 및 역량
#
# 1) 유사 경험
#    - 10년 이상의 IT 업계 경력 보유
#    - 다수의 스타트업에서 제품 개발 및 출시 경험
#    - 해외 시장 진출 프로젝트 성공적 수행
#
# 2) 지원사업 수행 이력
#    - 중소기업벤처부 창업지원사업 선정 (2020)
#    - 한국무역협회 수출바우처 사업 참여 (2019)
#
# 3) 관련 이수 현황
#    - 서울대학교 경영학 학사 졸업
#    - KAIST 기술경영 석사 졸업
#
# 4) 관련 수상 실적
#    - 대한민국 창업대전 우수상 수상 (2021)
#    - IT 혁신 어워드 최우수상 수상 (2020)
#
# 4-2. 팀원 구성 계획
#
# 1) 장비·시설 보유 계획
#    - 최신 서버 및 네트워크 장비 구축 예정
#    - AI 연구를 위한 고성능 컴퓨팅 장비 확보 예정
#
# 2) 직원 역량 계획
#    - 데이터 분석 전문가 5명 채용 예정: 평균 경력 8년 이상, 석박사 출신 비율 80%
#    - 소프트웨어 개발자 10명 채용 예정: 주요 대기업 출신, 평균 경력 7년 이상
#
# 3) 협약기간 내 채용 예정 인력
#    - 마케팅 전문가 3명 추가 채용 예정: 디지털 마케팅 및 글로벌 캠페인 경험 보유 필수
#
# <팀 구성 표>
#
# 예시)
# | 이름 | 역할 | 경력 | 학력 |
# |------|------|------|------|
# | 홍길동 | 대표이사 | 15년 | 서울대 MBA |
# | 김철수 | CTO | 12년 | KAIST 박사 |
# | 이영희 | CMO | 10년 | 고려대 학사 |
#
# <협력 기관 현황 및 협업 방안>
#
# 예시)
# | 협력 기관 명칭 | 협업 내용 및 방식 |
# |-----------------|-------------------|
# | A대학교 산학협력단 | 기술 공동개발 및 테스트베드 제공 |
# | B연구소 | 데이터 분석 알고리즘 공동 연구 |
# | C컨설팅 회사 | 해외 시장 진출 전략 컨설팅 제공 |
#
# 위와 같은 구성을 통해 팀의 강점을 극대화하고 목표 달성을 위해 최선을 다할 것입니다.
