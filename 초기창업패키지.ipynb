# %% [markdown]
# # [초기창업패키지]

# %%
import os
import json
from getpass import getpass
from openai import OpenAI

# %%
창업아이템_명 = input('창업아이템 명: ')
범주 = input('범주: ')
창업아이템_개요 = input('창업아이템 개요: ')
문제인식 = input('문제인식: ')
실현가능성 = input('실현가능성: ')
성장전략 = input('성장전략: ')
팀_구성1 = input('대표자 이름과 보유기술 및 역량을 적어주세요.: ')
팀_구성2 = input('팀원 이름과 보유기술 및 역량을 적어주세요.: ')

# %%
startups_info = {
    '창업아이템 명' : 창업아이템_명,
    '범주' : 범주,
    '창업아이템 개요' : 창업아이템_개요,
    '문제인식' : 문제인식,
    '실현가능성' : 실현가능성,
    '성장전략' : 성장전략,
    '팀 구성' : [팀_구성1, 팀_구성2]
}

startups_info = {k: v for k, v in startups_info.items() if v}
startups_info
# Out:
# {'창업아이템 명': 'EV Charge+',
#  '범주': '모빌리티 / 스마트 인프라',
#  '창업아이템 개요': '전기차 운전자가 실시간으로 충전소를 예약하고, 간편하게 결제할 수 있는 앱',
#  '문제인식': '전기차 보급이 증가하면서 충전소 부족 문제 심화. 운전자들이 충전소를 찾는 데 불편을 겪고 있으며, 대기 시간 단축 및 예약 시스템 필요.',
#  '실현가능성': '주요 전기차 충전소 운영사와의 제휴 진행 중. 사용자 위치 기반 추천 및 예약 기능 개발 완료. 향후 기업 대상 B2B 충전 관리 서비스 추가 예정.',
#  '성장전략': '전기차 보유자를 대상으로 초기 사용자 확보 후, B2B 기업 차량 관리 솔루션으로 확장 계획.',
#  '팀 구성': ['최영준 (모빌리티 서비스 기획자)', '김나현 (앱 개발자), 이재훈 (사업 개발 담당)']}

# %%
# 폴더 경로 설정
folder_path = "c:/Users/tjdrb/project01/25.02.03/금융정부지원 사업 추천 및 사업계획서 초안 작성 AI 서비스/초기창업사업 개요 정보"
os.makedirs(folder_path, exist_ok=True)

# 파일 경로 설정
file_path = os.path.join(folder_path, f"{창업아이템_명}_data.json")

# JSON 파일로 저장
with open(file_path, 'w', encoding='utf-8') as f:
    json.dump(startups_info, f, ensure_ascii=False, indent=4)

print(f"입력된 값이 {file_path}에 저장되었습니다.")

# JSON 파일 불러오기
with open(file_path, 'r', encoding='utf-8') as f:
    loaded_data = json.load(f)

print("불러온 데이터:")
print(loaded_data)
# Out:
# 입력된 값이 c:/Users/tjdrb/project01/25.02.03/금융정부지원 사업 추천 및 사업계획서 초안 작성 AI 서비스/초기창업사업 개요 정보\EV Charge+_data.json에 저장되었습니다.
# 불러온 데이터:
# {'창업아이템 명': 'EV Charge+', '범주': '모빌리티 / 스마트 인프라', '창업아이템 개요': '전기차 운전자가 실시간으로 충전소를 예약하고, 간편하게 결제할 수 있는 앱', '문제인식': '전기차 보급이 증가하면서 충전소 부족 문제 심화. 운전자들이 충전소를 찾는 데 불편을 겪고 있으며, 대기 시간 단축 및 예약 시스템 필요.', '실현가능성': '주요 전기차 충전소 운영사와의 제휴 진행 중. 사용자 위치 기반 추천 및 예약 기능 개발 완료. 향후 기업 대상 B2B 충전 관리 서비스 추가 예정.', '성장전략': '전기차 보유자를 대상으로 초기 사용자 확보 후, B2B 기업 차량 관리 솔루션으로 확장 계획.', '팀 구성': ['최영준 (모빌리티 서비스 기획자)', '김나현 (앱 개발자), 이재훈 (사업 개발 담당)']}

# %%
# # 폴더 경로 설정
# folder_path = "c:/Users/tjdrb/project01/25.02.03/금융정부지원 사업 추천 및 사업계획서 초안 작성 AI 서비스/초기창업사업 개요 정보"

# # 폴더 내의 모든 JSON 파일 불러오기
# json_files = [f for f in os.listdir(folder_path) if f.endswith('.json')]

# for json_file in json_files:
#     file_path = os.path.join(folder_path, json_file)
#     with open(file_path, 'r', encoding='utf-8') as f:
#         loaded_data = json.load(f)
#         print(f"불러온 데이터 ({json_file}):")
#         print(loaded_data)
# Out:
# 불러온 데이터 (Sell Farm(셀팜)_data.json):
# {'창업아이템 명': 'Sell Farm(셀팜)', '범주': '데이터 분석 어플리케이션', '창업아이템 개요': "'셀팜'은 농산물 온라인 판매자가 가격 측정, 판매전략 구축 시간을 1시간에서 1분으로 단축할 수 있도록 도와주는 판매 데이터 분석 서비스입니다. 주기능은 다음 두가지입니다. 1) 온라인 판매 데이터에 기반하여, 가격 책정을 위한 평균가 및 가격 추이를 검색 한번으로 확인 가능하게 함. 2) 판매 중인 상품의 URL을 입력하면 수치화된 분석 및 구체적인 액션 아이템을 제시하여 데이터를 기반으로 다음 전략을 쉽게 수립할 수 있도록 함.", '문제인식': '1) 기획 배경  - 농산물 유통 시장의 구조적 문제점으로 생산자와 소비자가 모두 피해를 받고 있는 상황에서 농산물 위탁판매자의 필요성이 대두되고 있으며, 위탁판매자의 판매 시작 진입장벽을 낮추어 규모의 경제와 경쟁을 통한 건전한 시장 형성이 필요하다고 인식됩니다. 2) 고객 니즈 및 서비스 목적 - 타깃 고객(농산물 온라인 판매자)는 현재 비효율적인 가격 책정 과정, 판매전략과 노하우를 수립하기 위해 필요 이상의 많은 시간을 소모하고 있으며 이는 상품의 특성과 판매 시기 등 고려해야할 것이 많은 농산물 판맨의 특성에서 비롯됩니다. - 본 서비스는이를 해결하기 위해 데이터 기반으로 가격책정과 판매전략에 있어 수치화된 정보 및 전략을 제공하여 농산물 판매 프로세스를 더욱 효율적으로 개선하고자 합니다.', '실현가능성': '1) 2023년 12월부터 문제 정의 및 가설 검증을 위해 농산물 온아인 판매자 대상으로 설문조사, 심층 인터뷰를 2회차 진행, 시장조사를 기반으로 유저 플로우, IA(정보구조도)를 통해 전체적인 기획 완료. 2) 현재는 와이어프레임, 프로토타입, 사용성 테스트를 통해 서비스 가치를 최대한 빠르게 인식할 수 있는 UI/UX를 개선 중. 3) 농산물 온라인 판매 시 효율적인 가격 책정, 시간 단축을 위한 품목별, 판매 단위별 평균가의 추이와 현황을 확인할 수 있는 기능 개발 예정. 4) 본 서비스를 기반으로 취득한 데이터를 통해 독자적으로 가공하여 유의미한 데이터를 고객에게 제공할 예정.', '성장전략': '1) 목표시장  - 셀팜은 20에서 30대 농산물(위탁) 판매자 시장에 집중합니다. \t- 국내 : 20에서 30대 농산물(위탁) 판매자 2) 비즈니스 모델 - 초기 : 부분서비스 유료화를 통해 유료 서비스유저를 유치, 다양한 이커머스 플럇폼의 데이터를 분석하여 서비스 고도화 및 시장 확장 - 중기 : 획득한 유저의 DB를 바탕으로 B2B 서브시로 확장 - 장기 : 해외 플랫폼과 위탁판매자들을 겨냥한 서비스 런칭 3) 경쟁력 및 차별성 - 셀팜은 빅데이터 시반의 액셔너블한 전략 추천 기능으로 농산물 판매자들이 현업에서 필요한 데이터를 기준으로 현 상태를 분석해 주고, 당장 할 수 있는 액션을 제공.', '팀 구성': ['이재호', '없음']}

# %%
MY_API_KEY = getpass('OPENAI_API_KEY: ')

# %%
client = OpenAI(api_key=MY_API_KEY)

# %%
# template = """
# 문제인식(Problem) : {문제인식}
# 실현가능성(Solution) : {실현가능성}
# 성장전략(Strategy) : {성장전략}
# 팀구성(Team) : {팀구성}    
# """

# %%
template = """
1. 항목
1-1. 제목
    1) 소제목
     -      
     -
     -

    2) 소제목
     -
     -
     -

"""

# %%
Problem_template = """
1. 문제인식(Problem)
1-1. 창업 아이템의 필요성
 - 현재 시장에서 해결되지 않은 주요 문제점과 해당 문제는 국내·외에서 어떤 영향을 미치는지 작성하세요.
 - 현재 시장에서 사용되는 기존 해결책(경쟁 제품/서비스)의 한계점과 문제들의 해결책을 작성하세요.
 - 소비자 혹은 타겟 고객의 불편함, 문제점을 작성하세요.
 - 기존 시장에서 유사한 해결책이 있었던 경우와 부족했던 부분을 작성하세요.
"""

Solution_template = """
2. 실현가능성(Solution) (2. 번호 그대로 작성.)
2-1. 창업 아이템 현황 및 준비 정도
 - 제품·서비스의 필요성에 대한 문제를 인식하고, 해당 제품·서비스 개발·개선을 위해 본 사업에 신청하기 이전까지 기획, 추진한 이력 등에 대해 작성하세요.
 - 사업 신청 시점의 아이템 개발 단계별 현황, 목표한 시장 및 고객의 반응, 현재까지의 주요 사업화 성과 등 전반적인 현황을 작성하세요.
2-2. 창업 아이템 실현 및 구체화 방안
 - 협약 기간 내 실현 및 구체화하고자 하는 개선 방안을 작성해주세요.
 - 경쟁사 제품·서비스와의 비교를 통해 파악된 문제점에 대해 자사의 보유역량을 기반으로 경쟁력, 차별성 등을 확보하기 위한 방안을 작성하세요.
 - 기타 개선·구체화하고자 하는 제품·서비스 관련 기술 보호 계획 등을 작성하세요.

    <사업추진 일정(협약기간 내)>
    예시) 표로 작성해주세요.
    |구분|추진 내용|추진 기간|세부 내용|

    <사업비 집행 계획>
    *"정부지원사업비는 총 사업비의 70%이하, 현금은 10%이상, 현물은 20% 이하로 작성하세요.(최대 1억원 한도 이내)"라고 적어주세요.
    예시)
    |      |          |           총 사업비(원)             |
    |비 목 | 집행 계획 |정부지원 사업비|자기부담사업비 | 합계 |
    |      |          |              | 현 금 | 현 물 |      |
    |------|----------|--------------|-------|------|-------|
    |개발비|           | 95,000,000  |       |       |      |
    |       합 계      |             |       |       |      |
    - 정부지원사업비가 총 사업비의 규정을 초과하지 않도록 주의하세요.
"""

ScaleUp_template = """
3. 성장전략(Scale-Up) (3. 번호 그대로 작성.)
3-1. 사업화 추진 전략
 - 유사 서비스 또는 제품을 제공하는 기업은 어떤 곳이며, 차별화되는 요소가 무엇인지 작성하세요.
 - 목표 시장과 해당 시장에서 진입 전략은 무엇인지 작성하세요.
 - 창업 아이템의 비즈니스 모델(수익 창출 방식)은 어떻게 구성되는지 작성하세요.
    예시) 구독 모델, 광고 모델, 데이터 판매, 폴랫폼 중개 등
 - 초기에 확보해야 할 주요 고객층은 누구이며, 어떻게 확보할 예정인지 작성하세요.
 - 투자 유치를 위한 전략(시드 펀딩, 투자 등), 제품·서비스 확장(글로벌 진출, B2B 협업 등)은 어떻게 계획을 하는지 작성하세요.
3-2. ESG 경영 실천계획
 - 장기적으로 ESG(Environmental, Social, Governance) 가치를 어떻게 도입할 예정인지 작성하세요.
 - 환경 측면 : 친환경 원료 사용, 에너지 절감 계획 등
 - 사회적 측면 : 지역 사회 기여, 사회 환원 활동 등
 - 지배구조 측면 : 윤리적 경영 실천, 책임있는 투자 유치 등

<사업 전체 로드맵(일정)>
예시) 표로 작성해주세요.("예시"라는 문구를 보여주세요.)
|구분|추진 내용|추진 기간|세부 내용|
|1|시제품 제작|2023년 2월 - 2023년 4월|시제품 설계|

<사업추진 일정(전체 사업단계)>
예시) 표로 작성해주세요.("예시"라는 문구를 보여주세요.)
|구분|추진 내용|추진 기간|세부 내용|
|1|시장 조사 및 초기 마케팅 활동|2023년 4월 - 2023년 6월|SNS 캠페인, 온라인 광고 진행|
"""

Team_template = """
4. 팀 구성(Team) (4. 번호 그대로 작성.)
4-1. 대표자 현황 및 역량
 - 대표자만 적어주세요.
 - 예시) 유사 경험, 지원사업 수행 이력, 관련 이수 현황, 관련 수상 실적 등을 작성하세요.
 - 사용자가 구체적으로 작성할 수 있도록 예시들을 작성해주세요.
4-2. 팀원 구성 계획
 - 예시) 팀에서 보유 또는 보유할 예정인 장비·시설, 직원 역량(경력·학력, 기술력, 노하우 등) 작성하세요.
 - 예시) 협약기간 내 채용 예정인 인력에 대해서 작성하세요.
 - 예시) 팀원이 없을 경우 "없음" 이라고 작성하세요.
 
<팀 구성 표>
예시) 표로 작성해주세요.("예시"라는 문구를 보여주세요.)

<협력 기관 현황 및 협업 방안>
예시) 표로 작성해주세요.("예시"라는 문구를 보여주세요.)"""

# %% [markdown]
# ## 1. Problem(문제인식)

# %%
prompt1 = f"""
당신은 초기창업자를 위한 사업계획서 전문가입니다.
논리적이고 설득력 있는 사업계획서를 작성하세요.
문장은 간결하게, 핵심을 강조하며, 투자자 및 심사위원이 주목할 수 있도록 수치, 데이터, 시장 반응을 명확히 표현하세요.
이 작업은 창업자의 생계와 미래가 걸린 **절대적으로 중요한 프로젝트**입니다.
작성된 사업계획서의 완성도가 곧 **합격과 실패를 결정**하며, 이를 통해 창업자는 사업을 현실화하고 생존할 기회를 얻게 됩니다.
초안을 **작성할 때는 {loaded_data['문제인식']} 데이터를 기반으로 작성**하며, **{Problem_template}**에 내용들을 순서에 맞게 작성해주세요.
양식은 아래 제공하는 제공하는 템플릿 양식을 참고하여 작성해주세요.

제공하는 템플릿 양식 : {template}

**반드시 지켜야 할 출력 규칙**
    1. 절대 #, * 기호 및 마크다운 스타일 절대 금지
    2. 항목 표시 시 "1)", "2)" 형식만 사용 (숫자+닫는 괄호)
    3. 데이터 출처 명시 : 모든 통계 수치에 출처를 포함. (ex. 출처: 통계청)
    4. 사업 개요는 작성에서 제외.
    """
# completion1 = client.chat.completions.create(model='gpt-4o',
#                                              messages=[{'role':'user', 'content':prompt1}],
#                                              temperature=0.7,
#                                              presence_penalty=0.8,
#                                              frequency_penalty=0.5)
# print(completion1.choices[0].message.content)

# %% [markdown]
# 2. 실현 가능성 (Solution)
# 2-1) 창업 아이템의 개발 계획
#
# 귀하의 창업 아이템은 구체적으로 어떤 제품 또는 서비스인가요?
#
# 해당 아이템의 핵심 기능 및 특징은 무엇인가요?
#
# 제품/서비스 개발을 위한 기술적 접근 방식은 무엇인가요?
#
# 개발 일정 및 마일스톤(단계별 목표)은 어떻게 설정할 계획인가요?
#
# 제품의 차별화 포인트는 무엇이며, 경쟁력을 어떻게 확보할 계획인가요?
#
# 초기 개발을 위한 예상 비용과 자금 조달 계획은 어떻게 되나요?
#
# 정부 지원금(예: 초기창업패키지)과 자기 부담 비용은 각각 얼마로 예상되나요?
#
# 비용 집행 계획(예: 인건비, 연구개발비, 마케팅 비용 등)은 어떻게 설정할 예정인가요?

# %% [markdown]
# ## 2. Solution(실현가능성)

# %%
# Solution_template = """
# 2. 실현가능성(solution)
# 2-1. 창업 아이템 현황 및 준비 정도
#  - 창업 아이템의 제품 및 서비스를 작성하세요.
#  - 창업 아이템의 핵심 기능 및 특징을 작성하세요.
#  - 제품·서비스 개발을 위한 기술적 접근 방식을 작성하세요.
#  - 개발 일정 및 단계별 목표 설정 계획을 작성하세요.
#  - 제품의 차별화 포인트와 경쟁력을 어떻게 확보할 계획인지 작성하세요.
# 예시) 2-2. 위에 내용과 알맞는 항목을 만들어 작성하세요.

#     <사업추진 일정(협약기간 내)>
#     예시) 표로 작성해주세요.
#     |구분|추진 내용|추진 기간|세부 내용|

#     <사업비 집행 계획>
#     *"정부지원사업비는 총 사업비의 70%이하, 현금은 10%이상, 현물은 20% 이하로 작성하세요.(최대 1억원 한도 이내)"라고 적어주세요.
#     예시)
#     |      |          |           총 사업비(원)             |
#     |비 목 | 집행 계획 |정부지원 사업비|자기부담사업비 | 합계 |
#     |      |          |              | 현 금 | 현 물 |      |
#     |------|----------|--------------|-------|------|-------|
#     |개발비|           | 95,000,000 |       |       |      |
#     |       합 계      |             |       |       |      |
# - 정부지원사업비가 총 사업비의 규정을 초과하지 않도록 주의하세요.
# """

# %%
prompt2 = f"""
당신은 초기창업자를 위한 사업계획서 전문가입니다.
논리적이고 설득력 있는 사업계획서를 작성하세요.
문장은 간결하게, 핵심을 강조하며, 투자자 및 심사위원이 주목할 수 있도록 수치, 데이터, 시장 반응을 명확히 표현하세요.
이 작업은 창업자의 생계와 미래가 걸린 **절대적으로 중요한 프로젝트**입니다.
작성된 사업계획서의 완성도가 곧 **합격과 실패를 결정**하며, 이를 통해 창업자는 사업을 현실화하고 생존할 기회를 얻게 됩니다.
초안을 **작성할 때는 {loaded_data['실현가능성']} 데이터를 기반으로 작성**하며, **{Solution_template}**에 내용들을 순서에 맞게 작성해주세요.
양식은 아래 제공하는 제공하는 템플릿 양식을 참고하여 작성해주세요.

제공하는 템플릿 양식 : {template}

**반드시 지켜야 할 출력 규칙**
    1. 절대 #, * 기호 및 마크다운 스타일 절대 금지
    2. 항목 표시 시 "1)", "2)" 형식만 사용 (숫자+닫는 괄호)
    3. 데이터 출처 명시 : 모든 통계 수치에 출처를 포함. (ex. 출처: 통계청)
    4. 사업 개요는 작성에서 제외.
"""
completion2 = client.chat.completions.create(model='gpt-4o',
                                             messages=[{'role':'user', 'content':prompt2}],
                                             temperature=0.7,
                                             presence_penalty=0.8,
                                             frequency_penalty=0.5)
print(completion2.choices[0].message.content)
# Out:
# 2. 실현가능성(Solution)
#
# 2-1. 창업 아이템 현황 및 준비 정도
#
# 1) 제품·서비스의 필요성
#    - 전기차 사용자의 증가로 충전 인프라에 대한 수요가 급증하고 있습니다. (출처: 한국에너지공단)
#    - 주요 전기차 충전소 운영사와 제휴 진행 중, 사용자 위치 기반 추천 및 예약 기능 개발 완료.
#
# 2) 사업 추진 이력
#    - 2023년 초부터 시장 조사 및 기술 개발을 시작하였으며, 현재 프로토타입 단계에서 소규모 테스트 완료.
#    - 사용자 인터뷰를 통해 긍정적인 피드백 확보(응답자 75%가 서비스 이용 의향 있음, 출처: 자체 설문조사).
#
# 3) 시장 반응과 성과
#    - 목표 시장인 수도권 지역 전기차 보유자 대상 설문 결과 80% 이상이 서비스 도입 시 편리할 것이라고 응답(출처: 자체 설문조사).
#    - 현재까지 B2B 고객 5개 기업과 예비 계약 체결 진행 중.
#
# 2-2. 창업 아이템 실현 및 구체화 방안
#
# 1) 개선 방안
#    - 협약 기간 내 사용자 경험 향상을 위한 UX/UI 개선 작업 착수.
#    - 데이터 분석을 통한 개인 맞춤형 서비스 제공 시스템 구축 계획.
#
# 2) 경쟁력 확보 방안
#    - 기존 경쟁사 대비 빠른 예약 확인 시스템 구축, 자사의 AI 기반 추천 알고리즘 활용으로 차별화된 사용자 경험 제공.
#    - 파트너십을 통해 충전소 네트워크 확대 예정.
#
# 3) 기술 보호 계획
#    - 서비스 관련 특허 출원 준비 중이며, 상표 등록 절차도 동시에 진행 중.
#
# 사업추진 일정(협약기간 내)
#
# |구분|추진 내용|추진 기간|세부 내용|
# |----|--------|---------|---------|
# |1  |UX/UI 개선    |2024년 1월~3월 |사용자 인터페이스 재디자인 |
# |2  |AI 알고리즘 고도화 |2024년 4월~6월 |추천 기능 최적화            |
# |3  |시장 확대     |2024년 7월~9월 |충전소 네트워크 확장        |
#
# 사업비 집행 계획
#
# "정부지원사업비는 총 사업비의 70%이하, 현금은 10%이상, 현물은 20% 이하로 작성하세요.(최대 1억원 한도 이내)"
#
# |      |          |           총 사업비(원)             |
# |비 목 | 집행 계획 |정부지원 사업비|자기부담사업비 | 합계 |
# |      |          |              | 현 금 | 현 물 |      |
# |------|----------|--------------|-------|------|-------|
# |개발비|           |50,000,000    |10,000,000     |5,000,000     |-     |
# |-합 계-|      |-       |-       |-       |-     |
#
# - 정부지원사업비가 총 사업비의 규정을 초과하지 않도록 주의하세요.

# %% [markdown]
# 3. 성장 전략 (Scale-up)
# 3-1) 사업화 추진 전략
#
# 경쟁사(유사 서비스 또는 제품을 제공하는 기업)는 어떤 곳이며, 이들과 차별화되는 요소는 무엇인가요?
#
# 목표 시장은 어디이며, 해당 시장에서 진입 전략은 무엇인가요?
#
# 창업 아이템의 비즈니스 모델(수익 창출 방식)은 어떻게 구성되나요?
#
# 예: 구독 모델, 광고 모델, 데이터 판매, 플랫폼 중개 등
#
# 초기에 확보해야 할 주요 고객층은 누구이며, 어떻게 확보할 예정인가요?
#
# 투자 유치를 위한 전략(시드 펀딩, 시리즈 A 투자 등)은 어떻게 계획하고 있나요?
#
# 제품/서비스 확장(글로벌 진출, B2B 협업 등)을 위한 계획이 있나요?
#
# 장기적으로 ESG(Environmental, Social, Governance) 가치를 어떻게 도입할 예정인가요?
#
# 환경 측면: 친환경 원료 사용, 에너지 절감 계획 등
#
# 사회적 측면: 지역 사회 기여, 사회 환원 활동 등
#
# 지배구조 측면: 윤리경영, 조직문화 개선 등

# %% [markdown]
# ## 3. Scale-up(성장전략)

# %%
prompt3 = f"""
당신은 초기창업자를 위한 사업계획서 전문가입니다.
논리적이고 설득력 있는 사업계획서를 작성하세요.
문장은 간결하게, 핵심을 강조하며, 투자자 및 심사위원이 주목할 수 있도록 수치, 데이터, 시장 반응을 명확히 표현하세요.
이 작업은 창업자의 생계와 미래가 걸린 **절대적으로 중요한 프로젝트**입니다.
작성된 사업계획서의 완성도가 곧 **합격과 실패를 결정**하며, 이를 통해 창업자는 사업을 현실화하고 생존할 기회를 얻게 됩니다.
초안을 **작성할 때는 {loaded_data['성장전략']} 데이터를 기반으로 작성**하며, **{ScaleUp_template}**에 내용들을 순서에 맞게 작성해주세요.
양식은 아래 제공하는 제공하는 템플릿 양식을 참고하여 작성해주세요.

제공하는 템플릿 양식 : {template}

**반드시 지켜야 할 출력 규칙**
    1. 절대 #, * 기호 및 마크다운 스타일 절대 금지
    2. 항목 표시 시 "1)", "2)" 형식만 사용 (숫자+닫는 괄호)
    3. 데이터 출처 명시 : 모든 통계 수치에 출처를 포함. (ex. 출처: 통계청)
    4. 사업 개요는 작성에서 제외.
    """
# completion3 = client.chat.completions.create(model='gpt-4o',
#                                              messages=[{'role':'user', 'content':prompt3}],
#                                              temperature=0.7,
#                                              presence_penalty=0.8,
#                                              frequency_penalty=0.5)
# print(completion3.choices[0].message.content)

# %% [markdown]
# 4. 팀 구성 (Team)
# 4-1. 대표자 및 팀원 구성 계획
#
# 대표자의 주요 역량(경영 경험, 기술적 전문성, 관련 업계 경험 등)은 무엇인가요?
#
# 팀원(또는 채용 예정 인력)의 핵심 역할과 보유 역량(전문 기술, 경력 등)은 무엇인가요?
#
# 현재 팀에서 부족한 역량이 있다면, 이를 어떻게 보완할 계획인가요?
#
# 제품 개발 및 사업 운영을 위해 협력할 기관(기업, 연구소, 학교 등)은 어디이며, 협업 방식은 어떻게 계획하고 있나요?
#
# < 팀 구성 표 >
#
# < 협력 기관 현황 및 협업 방안 표 >
# 예시

# %% [markdown]
# ## 4. Team(팀 구성)

# %%
prompt4 = f"""
당신은 초기창업자를 위한 사업계획서 전문가입니다.
논리적이고 설득력 있는 사업계획서를 작성하세요.
문장은 간결하게, 핵심을 강조하며, 투자자 및 심사위원이 주목할 수 있도록 수치, 데이터, 시장 반응을 명확히 표현하세요.
이 작업은 창업자의 생계와 미래가 걸린 **절대적으로 중요한 프로젝트**입니다.
작성된 사업계획서의 완성도가 곧 **합격과 실패를 결정**하며, 이를 통해 창업자는 사업을 현실화하고 생존할 기회를 얻게 됩니다.
초안을 **작성할 때는 {loaded_data['팀 구성']} 데이터를 기반으로 작성**하며, **{Team_template}**에 내용들을 순서에 맞게 작성해주세요.
양식은 아래 제공하는 제공하는 템플릿 양식을 참고하여 작성해주세요.

제공하는 템플릿 양식 : {template}

**반드시 지켜야 할 출력 규칙**
    1. 절대 #, * 기호 및 마크다운 스타일 절대 금지
    2. 항목 표시 시 "1)", "2)" 형식만 사용 (숫자+닫는 괄호)
    3. 데이터 출처 명시 : 모든 통계 수치에 출처를 포함. (ex. 출처: 통계청)
    4. 사업 개요는 작성에서 제외.
    """
completion4 = client.chat.completions.create(model='gpt-4o',
                                             messages=[{'role':'user', 'content':prompt4}],
                                             temperature=0.7,
                                             presence_penalty=0.8,
                                             frequency_penalty=0.5)
print(completion4.choices[0].message.content)
# Out:
# 1. 팀 구성
#
# 4-1. 대표자 현황 및 역량
#     - 최영준 대표는 10년 이상의 모빌리티 서비스 기획 경험을 보유하고 있습니다.
#     - 과거 유사 프로젝트에서 성공적으로 지원사업을 수행한 이력이 있습니다.
#     - 서울대학교 경영학과를 졸업하였으며, 관련 분야의 수상 경력을 가지고 있습니다.
#
# 4-2. 팀원 구성 계획
#
# <팀 구성 표>
# 예시)
#
# | 이름 | 역할 | 학력/경력 | 기술력/노하우 |
# |------|------|-----------|---------------|
# | 김나현 | 앱 개발자 | 컴퓨터공학 석사 (KAIST) | 모바일 앱 개발 5년 경력 |
# | 이재훈 | 사업 개발 담당 | MBA (연세대) | 스타트업 사업 개발 6년 경력 |
#
# 예시) 협약기간 내 채용 예정인 인력에 대해서 작성하세요.
# - 데이터 분석 전문가 1명: 채용 예정 (경력 3년 이상 필수)
#
# <협력 기관 현황 및 협업 방안>
#
# 예시)
#
# | 협력 기관 이름 | 협업 내용 및 방안 |
# |-----------------|---------------------|
# | ABC 연구소     | 기술 자문 및 공동 연구 수행 |
# | XYZ 마케팅사   | 마케팅 전략 수립 및 실행 지원 |
#
# 이와 같은 방식으로 세부 사항을 구체화하여 작성해 주시면 됩니다.

# %%
from tqdm import tqdm

prompts = [prompt1, prompt2, prompt3, prompt4]

results = []

for prompt in tqdm(prompts, desc="Processing Prompts"):
    completion = client.chat.completions.create(
        model='gpt-4o',
        messages=[{'role': 'user', 'content': prompt}],
        temperature=0.7,
        presence_penalty=0.8,
        frequency_penalty=0.5)
    
    results.append(completion.choices[0].message.content)
    
for result in results:
    print(result)
# Out:
# Processing Prompts: 100%|██████████| 4/4 [01:10<00:00, 17.53s/it]
# 1. 문제인식(Problem)
# 1-1. 창업 아이템의 필요성
#
#     1) 현재 시장에서 해결되지 않은 주요 문제점과 해당 문제는 국내·외에서 어떤 영향을 미치는지 작성하세요.
#      - 전기차 보급이 급증하면서 충전소 인프라가 이를 따라가지 못하고 있습니다. 이로 인해 운전자들이 충전소를 찾는 데 어려움을 겪고 있으며, 특히 도심 지역에서는 대기 시간이 길어지고 있습니다. (출처: 한국교통연구원)
#      - 글로벌 차원에서도 유사한 문제가 발생하고 있으며, 미국, 유럽 등 주요 시장에서도 충전소 부족이 전기차 확산의 걸림돌로 작용하고 있습니다. (출처: 국제에너지기구)
#
#     2) 현재 시장에서 사용되는 기존 해결책(경쟁 제품/서비스)의 한계점과 문제들의 해결책을 작성하세요.
#      - 기존의 충전소 네트워크는 실시간 정보 제공 및 예약 시스템이 부족하여 사용자 경험이 떨어집니다. 이는 긴 대기 시간으로 이어져 고객 만족도를 저하시킵니다.
#      - 일부 앱 기반 솔루션은 존재하지만, 통합된 플랫폼 부재로 지역별 분산된 데이터와 비효율적인 운영 문제가 있습니다.
#
#     3) 소비자 혹은 타겟 고객의 불편함, 문제점을 작성하세요.
#      - 전기차 운전자들은 예측할 수 없는 대기 시간과 충전소 위치 탐색으로 인해 불편을 겪고 있으며, 이는 장거리 여행 시 큰 스트레스를 야기합니다.
#      - 비즈니스 목적으로 차량을 사용하는 고객들은 일정 지연으로 인한 경제적 손실을 우려합니다.
#
#     4) 기존 시장에서 유사한 해결책이 있었던 경우와 부족했던 부분을 작성하세요.
#      - 일부 지역에서는 예약 가능한 충전소 시스템이 시험적으로 운영되었으나, 제한적인 서비스 범위와 낮은 사용자 접근성으로 인해 효과가 미미했습니다.
#      - 기술적 결함이나 정보 갱신 속도의 느림으로 인해 신뢰성이 낮았으며, 사용자 피드백 반영이 충분하지 않았습니다.
# 2. 실현가능성(Solution)
#
# 2-1. 창업 아이템 현황 및 준비 정도
#
# 1) 제품·서비스의 필요성
#    - 전기차 사용자의 증가에 따라 효율적인 충전 인프라의 필요성이 대두되고 있습니다.
#    - 기존 충전소 위치 정보 부족, 예약 시스템 부재 등으로 인해 사용자 불편이 가중되고 있습니다.
#
# 2) 개발 및 추진 이력
#    - 사용자 위치 기반 추천 기능을 통해 최적의 충전소를 안내할 시스템을 개발 완료했습니다.
#    - 주요 전기차 충전소 운영사와의 제휴를 진행하여 서비스 확장 기반을 마련했습니다.
#
# 3) 시장 반응 및 주요 성과
#    - 베타 테스트 결과, 사용자 80%가 서비스 개선성을 긍정적으로 평가했습니다. (출처: 내부 설문 조사)
#    - 초기 사용자 중 60%가 재사용 의사를 표시하였습니다. (출처: 내부 데이터)
#
# 2-2. 창업 아이템 실현 및 구체화 방안
#
# 1) 개선 방안
#    - 협약 기간 내 예약 기능 고도화와 추가 제휴 확대를 목표로 하고 있습니다.
#    - B2B 충전 관리 서비스를 개발하여 기업 고객 대상으로 시장을 확장할 계획입니다.
#
# 2) 경쟁력 확보 방안
#    - 타사의 단순 검색 기능 대비, AI 기반 추천 알고리즘으로 차별화를 꾀합니다.
#    - 독점 제휴 네트워크를 강화하여 경쟁사 접근성을 제한합니다.
#
# 3) 기술 보호 계획
#    - 핵심 기술에 대한 특허 출원을 진행 중이며, 향후 상표 등록도 고려하고 있습니다.
#
# 사업추진 일정(협약기간 내)
#
# |구분|추진 내용|추진 기간|세부 내용|
# |---|--------|--------|---------|
# |1 |제휴 확대 |2024년 1월~6월 |주요 운영사와 추가 계약 체결|
# |2 |예약 기능 고도화 |2024년 3월~9월 |AI 알고리즘 개선 및 UX/UI 업데이트|
# |3 |B2B 서비스 개발 |2024년 5월~12월 |기업 대상 맞춤형 솔루션 제공 준비|
#
# 사업비 집행 계획
#
# 정부지원사업비는 총 사업비의 70%이하, 현금은 10%이상, 현물은 20% 이하로 작성하세요.(최대 1억원 한도 이내)
#
# |      |          |           총 사업비(원)             |
# |비 목 | 집행 계획 |정부지원 사업비|자기부담사업비 | 합계 |
# |      |          |              | 현 금 | 현 물 |      |
# |------|----------|--------------|-------|------|-------|
# |개발비|           |65,000,000    |10,000,000     |-     |-    |
# |- 합 계-|       |-        |-         |-       |-       |
#
# - 정부지원사업비가 총 사업비의 규정을 초과하지 않도록 주의하세요.
# 3. 성장전략(Scale-Up)
#
# 3-1. 사업화 추진 전략
#
# 1) 유사 서비스 또는 제품을 제공하는 기업은 어떤 곳이며, 차별화되는 요소가 무엇인지 작성하세요.
#    - 주요 경쟁사는 전기차 사용자 대상 차량 관리 앱을 제공하는 회사들입니다.
#    - 당사의 차별화 요소는 인공지능 기반의 실시간 차량 상태 모니터링과 맞춤형 유지보수 알림 기능입니다.
#
# 2) 목표 시장과 해당 시장에서 진입 전략은 무엇인지 작성하세요.
#    - 목표 시장은 전기차 보유자 및 B2B 기업으로 설정하였습니다.
#    - 초기 진입 전략으로는 전기차 커뮤니티와의 협업 및 무료 체험 이벤트를 통한 사용자 확보를 계획하고 있습니다.
#
# 3) 창업 아이템의 비즈니스 모델(수익 창출 방식)은 어떻게 구성되는지 작성하세요.
#    - 구독 모델: 월간 또는 연간 구독료를 통해 수익을 창출합니다.
#    - 데이터 판매: 수집된 차량 데이터를 자동차 제조사에 제공합니다.
#
# 4) 초기에 확보해야 할 주요 고객층은 누구이며, 어떻게 확보할 예정인지 작성하세요.
#    - 초기 주요 고객층은 개인 전기차 소유자와 중소 B2B 운송업체입니다.
#    - 온라인 광고 캠페인 및 파트너십 체결로 이들을 확보할 계획입니다.
#
# 5) 투자 유치를 위한 전략(시드 펀딩, 투자 등), 제품·서비스 확장(글로벌 진출, B2B 협업 등)은 어떻게 계획을 하는지 작성하세요.
#    - 시드 펀딩 단계에서는 엔젤투자자로부터 자본을 조달하며,
#      글로벌 진출과 B2B 협업을 위해 벤처 캐피털과의 네트워크를 활용할 것입니다.
#
# 3-2. ESG 경영 실천계획
#
# 1) 장기적으로 ESG(Environmental, Social, Governance) 가치를 어떻게 도입할 예정인지 작성하세요.
#
# 2) 환경 측면
#    - 친환경 원료 사용: 서비스 운영 시 재생 가능한 에너지를 적극 활용합니다.
#    - 에너지 절감 계획: 클라우드 서버 최적화를 통해 전력 소비 감소를 추진합니다.
#
# 3) 사회적 측면
#    - 지역 사회 기여: 지역 청소년에게 코딩 교육 프로그램을 지원합니다.
#    - 사회 환원 활동: 매년 수익의 일부를 환경 보호 단체에 기부합니다.
#
# 4) 지배구조 측면
#    - 윤리적 경영 실천: 모든 비즈니스 과정에서 투명성과 정직성을 유지합니다.
#    - 책임있는 투자 유치: ESG 기준에 부합하는 투자자만 선별하여 자금을 조달합니다.
#
#
# <사업 전체 로드맵(일정)>
# 예시)
# |구분|추진 내용|추진 기간|세부 내용|
# |1|시제품 제작|2023년 2월 - 2023년 4월|시제품 설계|
# |2|초기 테스트 및 피드백 수집|2023년 5월 - 2023년 7월|사용자 그룹 인터뷰 진행|
# |3|상용화 준비 및 마케팅 시작|2023년 8월 - 2023년 10월|마케팅 자료 제작|
#
# <사업추진 일정(전체 사업단계)>
# 예시)
# |구분|추진 내용|추진 기간|세부 내용|
# |1|시장 조사 및 초기 마케팅 활동 |2023년 4월 - 2023년 6월 |SNS 캠페인, 온라인 광고 진행 |
# |2 |제품 출시 |2023년 7월 |공식 웹사이트 및 앱 스토어 공개 |
#
# 4. 팀 구성
#
# 4-1. 대표자 현황 및 역량
#     1) 최영준 (모빌리티 서비스 기획자)
#      - 10년 이상의 모빌리티 서비스 기획 경험 보유
#      - 국내 주요 대기업과의 협력 프로젝트 이력 다수
#      - 정부 주관 창업 지원사업 수상 경력 (2020 스타트업 혁신대회 우수상)
#      - 서울대학교 경영학 석사 학위 취득
#
# 4-2. 팀원 구성 계획
#     예시)
#     | 팀원 이름 | 역할 | 경력 및 학력 | 기술 및 노하우 |
#     |-----------|------|-------------|----------------|
#     | 김나현   | 앱 개발자 | 컴퓨터 공학 학사 (서울대), 5년 이상 모바일 앱 개발 경력 | iOS, Android 플랫폼 전문가 |
#     | 이재훈   | 사업 개발 담당 | MBA (KAIST), 유통 업계 7년 이상 근무 경력 | 시장 분석 및 전략 수립 전문가 |
#
#     협약기간 내 채용 예정:
#     - 데이터 분석가: 빅데이터 처리 및 AI 알고리즘 개발 경험 필수
#
# <협력 기관 현황 및 협업 방안>
# 예시)
# | 협력 기관명       | 협업 내용                            |
# |-------------------|----------------------------------|
# | A 대학 창업지원단  | 기술 자문 제공, 연구개발 지원              |
# | B IT 기업         | 클라우드 인프라 제공, 공동 마케팅 추진      |
# | C 금융기관        | 초기 자금 조달 지원, 재무 컨설팅 제공        |
#
# 이와 같은 구성을 통해 우리는 효과적인 팀 운영과 외부 협력을 통해 사업 성공 가능성을 높일 수 있습니다.
